# %%
import pandas as pd
import numpy as np
import mlflow

# uv add xgboost
from xgboost import XGBClassifier
# uv add lightgbm
from lightgbm import LGBMClassifier
# uv add catboost
from catboost import CatBoostClassifier

from sklearn.linear_model import LogisticRegression
from sklearn.ensemble import StackingClassifier, BaggingClassifier, RandomForestClassifier, VotingClassifier
from sklearn.dummy import DummyClassifier
from sklearn.tree import DecisionTreeClassifier
from sklearn.model_selection import train_test_split
from sklearn.pipeline import Pipeline
from sklearn.impute import SimpleImputer

from sklearn.metrics import accuracy_score, f1_score
# Out:
# 2025/07/22 13:39:56 WARNING mlflow.utils.autologging_utils: MLflow xgboost autologging is known to be compatible with 1.4.2 <= xgboost <= 3.0.0, but the installed version is 3.0.2. If you encounter errors during autologging, try upgrading / downgrading xgboost to a compatible version, or try upgrading MLflow.
# 2025/07/22 13:39:56 INFO mlflow.tracking.fluent: Autologging successfully enabled for xgboost.
# 2025/07/22 13:39:57 INFO mlflow.tracking.fluent: Autologging successfully enabled for lightgbm.

# %%
# Importa la librería dagshub para integrar el seguimiento de experimentos con DagsHub
import dagshub

# Inicializa la integración con DagsHub, especificando el propietario y nombre del repositorio,
# y habilita la integración con MLflow para registrar experimentos en DagsHub
dagshub.init(
  repo_owner='edynsoncoronado',
  repo_name='ml_supervisado_avanzado',
  mlflow=True
)

# Importa la librería mlflow para el seguimiento de experimentos de machine learning
import mlflow

# Inicia una nueva ejecución de MLflow
with mlflow.start_run():
  # Registra un parámetro personalizado en el experimento de MLflow
  mlflow.log_param('parameter name', 'value')
  # Registra una métrica personalizada en el experimento de MLflow
  mlflow.log_metric('metric name', 1)
# Out:
# Initialized MLflow to track repo "edynsoncoronado/ml_supervisado_avanzado"
# Repository edynsoncoronado/ml_supervisado_avanzado initialized!
# 🏃 View run wise-calf-996 at: https://dagshub.com/edynsoncoronado/ml_supervisado_avanzado.mlflow/#/experiments/0/runs/1abf4ae6f9ca4e3787b2785892bbeaec
# 🧪 View experiment at: https://dagshub.com/edynsoncoronado/ml_supervisado_avanzado.mlflow/#/experiments/0

# %%
df = pd.read_csv("../data/raw/hotel_bookings.csv")
df.head()
# Out:
#           hotel  is_canceled  lead_time  arrival_date_year arrival_date_month  \
# 0  Resort Hotel            0        342               2015               July
# 1  Resort Hotel            0        737               2015               July
# 2  Resort Hotel            0          7               2015               July
# 3  Resort Hotel            0         13               2015               July
# 4  Resort Hotel            0         14               2015               July
#
#    arrival_date_week_number  arrival_date_day_of_month  \
# 0                        27                          1
# 1                        27                          1
# 2                        27                          1
# 3                        27                          1
# 4                        27                          1
#
#    stays_in_weekend_nights  stays_in_week_nights  adults  ...  deposit_type  \
# 0                        0                     0       2  ...    No Deposit
# 1                        0                     0       2  ...    No Deposit
# 2                        0                     1       1  ...    No Deposit
# 3                        0                     1       1  ...    No Deposit
# 4                        0                     2       2  ...    No Deposit
#
#    agent company days_in_waiting_list customer_type   adr  \
# 0    NaN     NaN                    0     Transient   0.0
# 1    NaN     NaN                    0     Transient   0.0
# 2    NaN     NaN                    0     Transient  75.0
# 3  304.0     NaN                    0     Transient  75.0
# 4  240.0     NaN                    0     Transient  98.0
#
#    required_car_parking_spaces  total_of_special_requests  reservation_status  \
# 0                            0                          0           Check-Out
# 1                            0                          0           Check-Out
# 2                            0                          0           Check-Out
# 3                            0                          0           Check-Out
# 4                            0                          1           Check-Out
#
#   reservation_status_date
# 0              2015-07-01
# 1              2015-07-01
# 2              2015-07-02
# 3              2015-07-02
# 4              2015-07-03
#
# [5 rows x 32 columns]

# %%
FEATURES = ["lead_time", "stays_in_week_nights", "children", "adr", "booking_changes" ]
X, y = df[FEATURES], df["is_canceled"]

X_train, X_test, y_train, y_test = train_test_split(X, y, random_state=100)

# %%
# Establece la URI de seguimiento de MLflow para que apunte al servidor remoto de DagsHub,
# permitiendo así registrar y visualizar experimentos de MLflow en esa plataforma.
mlflow.set_tracking_uri("https://dagshub.com/edynsoncoronado/ml_supervisado_avanzado.mlflow")

# %%
# Crea un nuevo experimento en MLflow llamado "hotel_bookings_experiment"
mlflow.create_experiment("hotel_bookings_experiment")
# Out:
# '1'

# %%
# Establece el experimento actual de MLflow en "hotel_bookings_experiment"
mlflow.set_experiment("hotel_bookings_experiment")
# Out:
# <Experiment: artifact_location='mlflow-artifacts:/b4797be1712a4b8a913e111c78516646', creation_time=1753205160284, experiment_id='1', last_update_time=1753205160284, lifecycle_stage='active', name='hotel_bookings_experiment', tags={}>

# %% [markdown]
# # Baseline

# %%
# Activa el registro automático de parámetros, métricas y artefactos de modelos compatibles con MLflow
mlflow.autolog()

# Inicia una nueva ejecución de MLflow con el nombre especificado
with mlflow.start_run(run_name="Baseline - Dummy Classifier - Con métricas") as run:

    # Crea una instancia del clasificador Dummy usando la estrategia "most_frequent"
    algorithm = DummyClassifier(strategy="most_frequent")
    # Ajusta el clasificador Dummy con los datos de entrenamiento
    algorithm.fit(X_train, y_train)

    # Realiza predicciones sobre el conjunto de prueba
    predictions = algorithm.predict(X_test)

    # Calcula la métrica de exactitud (accuracy) usando las etiquetas verdaderas y las predichas
    _accuracy_score = accuracy_score(y_test, predictions)
    # Calcula la métrica F1 usando las etiquetas verdaderas y las predichas
    _f1_score = f1_score(y_test, predictions)
    
    # Registra las métricas calculadas en MLflow
    mlflow.log_metrics(
        {
            "accuracy": _accuracy_score,
            "f1": _f1_score
        }
    )
# Out:
# 2025/07/22 12:29:39 WARNING mlflow.utils.autologging_utils: MLflow sklearn autologging is known to be compatible with 0.24.1 <= scikit-learn <= 1.6.1, but the installed version is 1.7.1. If you encounter errors during autologging, try upgrading / downgrading scikit-learn to a compatible version, or try upgrading MLflow.
# 2025/07/22 12:29:40 INFO mlflow.tracking.fluent: Autologging successfully enabled for sklearn.
# 2025/07/22 12:29:40 WARNING mlflow.utils.autologging_utils: MLflow autologging encountered a warning: "/home/edyn/Documentos/obsidian-doc/Projects/MachineLearningEngineer/Curso2/Proyecto/Repo/ml2_class4_mlsupervisadoavanzado/.venv/lib/python3.12/site-packages/mlflow/types/utils.py:452: UserWarning: Hint: Inferred schema contains integer column(s). Integer columns in Python cannot represent missing values. If your input data contains missing values at inference time, it will be encoded as floats and will cause a schema enforcement error. The best way to avoid this problem is to infer the model schema based on a realistic data sample (training dataset) that includes missing values. Alternatively, you can declare integer columns as doubles (float64) whenever these columns may have missing values. See `Handling Integers With Missing Values <https://www.mlflow.org/docs/latest/models.html#handling-integers-with-missing-values>`_ for more details."
# /home/edyn/Documentos/obsidian-doc/Projects/MachineLearningEngineer/Curso2/Proyecto/Repo/ml2_class4_mlsupervisadoavanzado/.venv/lib/python3.12/site-packages/sklearn/metrics/_classification.py:1731: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", result.shape[0])
# 2025/07/22 12:29:45 WARNING mlflow.utils.autologging_utils: MLflow autologging encountered a warning: "/home/edyn/Documentos/obsidian-doc/Projects/MachineLearningEngineer/Curso2/Proyecto/Repo/ml2_class4_mlsupervisadoavanzado/.venv/lib/python3.12/site-packages/mlflow/types/utils.py:452: UserWarning: Hint: Inferred schema contains integer column(s). Integer columns in Python cannot represent missing values. If your input data contains missing values at inference time, it will be encoded as floats and will cause a schema enforcement error. The best way to avoid this problem is to infer the model schema based on a realistic data sample (training dataset) that includes missing values. Alternatively, you can declare integer columns as doubles (float64) whenever these columns may have missing values. See `Handling Integers With Missing Values <https://www.mlflow.org/docs/latest/models.html#handling-integers-with-missing-values>`_ for more details."
# 2025/07/22 12:29:52 WARNING mlflow.utils.autologging_utils: MLflow autologging encountered a warning: "/home/edyn/Documentos/obsidian-doc/Projects/MachineLearningEngineer/Curso2/Proyecto/Repo/ml2_class4_mlsupervisadoavanzado/.venv/lib/python3.12/site-packages/mlflow/types/utils.py:452: UserWarning: Hint: Inferred schema contains integer column(s). Integer columns in Python cannot represent missing values. If your input data contains missing values at inference time, it will be encoded as floats and will cause a schema enforcement error. The best way to avoid this problem is to infer the model schema based on a realistic data sample (training dataset) that includes missing values. Alternatively, you can declare integer columns as doubles (float64) whenever these columns may have missing values. See `Handling Integers With Missing Values <https://www.mlflow.org/docs/latest/models.html#handling-integers-with-missing-values>`_ for more details."
# 🏃 View run Baseline - Dummy Classifier - Con métricas at: https://dagshub.com/edynsoncoronado/ml_supervisado_avanzado.mlflow/#/experiments/1/runs/258b84a471be4b6ea4ca6a278c2bf835
# 🧪 View experiment at: https://dagshub.com/edynsoncoronado/ml_supervisado_avanzado.mlflow/#/experiments/1

# %% [markdown]
# # Regresión Logística

# %%
# Inicia una nueva ejecución de MLflow con el nombre "Regresión logistica"
with mlflow.start_run(run_name="Regresión logistica") as run:

    # Crea una instancia del modelo de Regresión Logística
    algorithm = LogisticRegression()
    # Define un pipeline que primero imputa valores faltantes y luego aplica la regresión logística
    pipeline = Pipeline(
        steps=[
            ("imputer", SimpleImputer(strategy="mean")),  # Imputa valores faltantes usando la media
            ("reg_logistica", algorithm)                  # Aplica el modelo de regresión logística
        ]
    )
    # Ajusta el pipeline con los datos de entrenamiento
    pipeline.fit(X_train, y_train)

    # Realiza predicciones sobre el conjunto de prueba
    predictions = pipeline.predict(X_test)

    # Calcula la métrica de exactitud (accuracy) usando las etiquetas verdaderas y las predichas
    _accuracy_score = accuracy_score(y_test, predictions)
    # Calcula la métrica F1 usando las etiquetas verdaderas y las predichas
    _f1_score = f1_score(y_test, predictions)
    
    # Registra las métricas calculadas en MLflow
    mlflow.log_metrics(
        {
            "accuracy": _accuracy_score,
            "f1": _f1_score
        }
    )
# Out:
# 2025/07/22 13:14:45 WARNING mlflow.utils.autologging_utils: MLflow autologging encountered a warning: "/home/edyn/Documentos/obsidian-doc/Projects/MachineLearningEngineer/Curso2/Proyecto/Repo/ml2_class4_mlsupervisadoavanzado/.venv/lib/python3.12/site-packages/mlflow/types/utils.py:452: UserWarning: Hint: Inferred schema contains integer column(s). Integer columns in Python cannot represent missing values. If your input data contains missing values at inference time, it will be encoded as floats and will cause a schema enforcement error. The best way to avoid this problem is to infer the model schema based on a realistic data sample (training dataset) that includes missing values. Alternatively, you can declare integer columns as doubles (float64) whenever these columns may have missing values. See `Handling Integers With Missing Values <https://www.mlflow.org/docs/latest/models.html#handling-integers-with-missing-values>`_ for more details."
# 2025/07/22 13:14:48 WARNING mlflow.utils.autologging_utils: MLflow autologging encountered a warning: "/home/edyn/Documentos/obsidian-doc/Projects/MachineLearningEngineer/Curso2/Proyecto/Repo/ml2_class4_mlsupervisadoavanzado/.venv/lib/python3.12/site-packages/mlflow/types/utils.py:452: UserWarning: Hint: Inferred schema contains integer column(s). Integer columns in Python cannot represent missing values. If your input data contains missing values at inference time, it will be encoded as floats and will cause a schema enforcement error. The best way to avoid this problem is to infer the model schema based on a realistic data sample (training dataset) that includes missing values. Alternatively, you can declare integer columns as doubles (float64) whenever these columns may have missing values. See `Handling Integers With Missing Values <https://www.mlflow.org/docs/latest/models.html#handling-integers-with-missing-values>`_ for more details."
# 2025/07/22 13:14:55 WARNING mlflow.utils.autologging_utils: MLflow autologging encountered a warning: "/home/edyn/Documentos/obsidian-doc/Projects/MachineLearningEngineer/Curso2/Proyecto/Repo/ml2_class4_mlsupervisadoavanzado/.venv/lib/python3.12/site-packages/mlflow/types/utils.py:452: UserWarning: Hint: Inferred schema contains integer column(s). Integer columns in Python cannot represent missing values. If your input data contains missing values at inference time, it will be encoded as floats and will cause a schema enforcement error. The best way to avoid this problem is to infer the model schema based on a realistic data sample (training dataset) that includes missing values. Alternatively, you can declare integer columns as doubles (float64) whenever these columns may have missing values. See `Handling Integers With Missing Values <https://www.mlflow.org/docs/latest/models.html#handling-integers-with-missing-values>`_ for more details."
# 🏃 View run Regresión logistica at: https://dagshub.com/edynsoncoronado/ml_supervisado_avanzado.mlflow/#/experiments/1/runs/d1e91a41508c4c0aa8f9fc8c01d2f120
# 🧪 View experiment at: https://dagshub.com/edynsoncoronado/ml_supervisado_avanzado.mlflow/#/experiments/1

# %% [markdown]
# # Ensamble 1: Bagging

# %%
# Inicia una nueva ejecución de MLflow con el nombre "Bagging"
with mlflow.start_run(run_name="Bagging") as run:

    # Crea una instancia del clasificador Bagging
    algorithm = BaggingClassifier()
    # Define un pipeline que primero imputa valores faltantes y luego aplica el clasificador Bagging
    pipeline = Pipeline(
        steps=[
            ("imputer", SimpleImputer(strategy="mean")),  # Imputa valores faltantes usando la media
            ("bagging", algorithm)                        # Aplica el modelo Bagging
        ]
    )
    # Ajusta el pipeline con los datos de entrenamiento
    pipeline.fit(X_train, y_train)

    # Realiza predicciones sobre el conjunto de prueba
    predictions = pipeline.predict(X_test)

    # Calcula la métrica de exactitud (accuracy) usando las etiquetas verdaderas y las predichas
    _accuracy_score = accuracy_score(y_test, predictions)
    # Calcula la métrica F1 usando las etiquetas verdaderas y las predichas
    _f1_score = f1_score(y_test, predictions)
    
    # Registra las métricas calculadas en MLflow
    mlflow.log_metrics(
        {
            "accuracy": _accuracy_score,
            "f1": _f1_score
        }
    )
# Out:
# 2025/07/22 13:18:41 WARNING mlflow.utils.autologging_utils: MLflow autologging encountered a warning: "/home/edyn/Documentos/obsidian-doc/Projects/MachineLearningEngineer/Curso2/Proyecto/Repo/ml2_class4_mlsupervisadoavanzado/.venv/lib/python3.12/site-packages/mlflow/types/utils.py:452: UserWarning: Hint: Inferred schema contains integer column(s). Integer columns in Python cannot represent missing values. If your input data contains missing values at inference time, it will be encoded as floats and will cause a schema enforcement error. The best way to avoid this problem is to infer the model schema based on a realistic data sample (training dataset) that includes missing values. Alternatively, you can declare integer columns as doubles (float64) whenever these columns may have missing values. See `Handling Integers With Missing Values <https://www.mlflow.org/docs/latest/models.html#handling-integers-with-missing-values>`_ for more details."
# 2025/07/22 13:18:46 WARNING mlflow.utils.autologging_utils: MLflow autologging encountered a warning: "/home/edyn/Documentos/obsidian-doc/Projects/MachineLearningEngineer/Curso2/Proyecto/Repo/ml2_class4_mlsupervisadoavanzado/.venv/lib/python3.12/site-packages/mlflow/types/utils.py:452: UserWarning: Hint: Inferred schema contains integer column(s). Integer columns in Python cannot represent missing values. If your input data contains missing values at inference time, it will be encoded as floats and will cause a schema enforcement error. The best way to avoid this problem is to infer the model schema based on a realistic data sample (training dataset) that includes missing values. Alternatively, you can declare integer columns as doubles (float64) whenever these columns may have missing values. See `Handling Integers With Missing Values <https://www.mlflow.org/docs/latest/models.html#handling-integers-with-missing-values>`_ for more details."
# 2025/07/22 13:19:05 WARNING mlflow.utils.autologging_utils: MLflow autologging encountered a warning: "/home/edyn/Documentos/obsidian-doc/Projects/MachineLearningEngineer/Curso2/Proyecto/Repo/ml2_class4_mlsupervisadoavanzado/.venv/lib/python3.12/site-packages/mlflow/types/utils.py:452: UserWarning: Hint: Inferred schema contains integer column(s). Integer columns in Python cannot represent missing values. If your input data contains missing values at inference time, it will be encoded as floats and will cause a schema enforcement error. The best way to avoid this problem is to infer the model schema based on a realistic data sample (training dataset) that includes missing values. Alternatively, you can declare integer columns as doubles (float64) whenever these columns may have missing values. See `Handling Integers With Missing Values <https://www.mlflow.org/docs/latest/models.html#handling-integers-with-missing-values>`_ for more details."
# 🏃 View run Bagging at: https://dagshub.com/edynsoncoronado/ml_supervisado_avanzado.mlflow/#/experiments/1/runs/7b2a52e56b4a498a89919a3d5ced0f2e
# 🧪 View experiment at: https://dagshub.com/edynsoncoronado/ml_supervisado_avanzado.mlflow/#/experiments/1

# %% [markdown]
# # Ensamble 2: Random Forest

# %%
# Inicia una nueva ejecución de MLflow con el nombre "Random Forest"
with mlflow.start_run(run_name="Random Forest") as run:

    # Crea una instancia del clasificador Random Forest
    algorithm = RandomForestClassifier()
    # Define un pipeline que primero imputa valores faltantes y luego aplica el clasificador Random Forest
    pipeline = Pipeline(
        steps=[
            ("imputer", SimpleImputer(strategy="mean")),  # Imputa valores faltantes usando la media
            ("rf", algorithm)                             # Aplica el modelo Random Forest
        ]
    )
    # Ajusta el pipeline con los datos de entrenamiento
    pipeline.fit(X_train, y_train)

    # Realiza predicciones sobre el conjunto de prueba
    predictions = pipeline.predict(X_test)

    # Calcula la métrica de exactitud (accuracy) usando las etiquetas verdaderas y las predichas
    _accuracy_score = accuracy_score(y_test, predictions)
    # Calcula la métrica F1 usando las etiquetas verdaderas y las predichas
    _f1_score = f1_score(y_test, predictions)
    
    # Registra las métricas calculadas en MLflow
    mlflow.log_metrics(
        {
            "accuracy": _accuracy_score,
            "f1": _f1_score
        }
    )
# Out:
# 2025/07/22 13:21:45 WARNING mlflow.utils.autologging_utils: MLflow autologging encountered a warning: "/home/edyn/Documentos/obsidian-doc/Projects/MachineLearningEngineer/Curso2/Proyecto/Repo/ml2_class4_mlsupervisadoavanzado/.venv/lib/python3.12/site-packages/mlflow/types/utils.py:452: UserWarning: Hint: Inferred schema contains integer column(s). Integer columns in Python cannot represent missing values. If your input data contains missing values at inference time, it will be encoded as floats and will cause a schema enforcement error. The best way to avoid this problem is to infer the model schema based on a realistic data sample (training dataset) that includes missing values. Alternatively, you can declare integer columns as doubles (float64) whenever these columns may have missing values. See `Handling Integers With Missing Values <https://www.mlflow.org/docs/latest/models.html#handling-integers-with-missing-values>`_ for more details."
# 2025/07/22 13:22:05 WARNING mlflow.utils.autologging_utils: MLflow autologging encountered a warning: "/home/edyn/Documentos/obsidian-doc/Projects/MachineLearningEngineer/Curso2/Proyecto/Repo/ml2_class4_mlsupervisadoavanzado/.venv/lib/python3.12/site-packages/mlflow/types/utils.py:452: UserWarning: Hint: Inferred schema contains integer column(s). Integer columns in Python cannot represent missing values. If your input data contains missing values at inference time, it will be encoded as floats and will cause a schema enforcement error. The best way to avoid this problem is to infer the model schema based on a realistic data sample (training dataset) that includes missing values. Alternatively, you can declare integer columns as doubles (float64) whenever these columns may have missing values. See `Handling Integers With Missing Values <https://www.mlflow.org/docs/latest/models.html#handling-integers-with-missing-values>`_ for more details."
# 2025/07/22 13:24:34 WARNING mlflow.utils.autologging_utils: MLflow autologging encountered a warning: "/home/edyn/Documentos/obsidian-doc/Projects/MachineLearningEngineer/Curso2/Proyecto/Repo/ml2_class4_mlsupervisadoavanzado/.venv/lib/python3.12/site-packages/mlflow/types/utils.py:452: UserWarning: Hint: Inferred schema contains integer column(s). Integer columns in Python cannot represent missing values. If your input data contains missing values at inference time, it will be encoded as floats and will cause a schema enforcement error. The best way to avoid this problem is to infer the model schema based on a realistic data sample (training dataset) that includes missing values. Alternatively, you can declare integer columns as doubles (float64) whenever these columns may have missing values. See `Handling Integers With Missing Values <https://www.mlflow.org/docs/latest/models.html#handling-integers-with-missing-values>`_ for more details."
# 🏃 View run Random Forest at: https://dagshub.com/edynsoncoronado/ml_supervisado_avanzado.mlflow/#/experiments/1/runs/ec5ca5e9a2f24d9dad64ff6cb86acec8
# 🧪 View experiment at: https://dagshub.com/edynsoncoronado/ml_supervisado_avanzado.mlflow/#/experiments/1

# %% [markdown]
# # Ensamble 3: XGboost

# %%
# Inicia una nueva ejecución de MLflow con el nombre "XGboost"
with mlflow.start_run(run_name="XGboost") as run:

    # Crea una instancia del clasificador XGBoost con profundidad máxima de 5 y 101 árboles
    algorithm = XGBClassifier(
        max_depth=5,         # Establece la profundidad máxima de cada árbol en 5
        n_estimators=101     # Establece el número de árboles en el modelo en 101
    )
    # Define un pipeline que primero imputa valores faltantes y luego aplica el clasificador XGBoost
    pipeline = Pipeline(
        steps=[
            ("imputer", SimpleImputer(strategy="mean")),  # Imputa valores faltantes usando la media
            ("xgb", algorithm)                            # Aplica el modelo XGBoost
        ]
    )
    # Ajusta el pipeline con los datos de entrenamiento
    pipeline.fit(X_train, y_train)

    # Realiza predicciones sobre el conjunto de prueba
    predictions = pipeline.predict(X_test)

    # Calcula la métrica de exactitud (accuracy) usando las etiquetas verdaderas y las predichas
    _accuracy_score = accuracy_score(y_test, predictions)
    # Calcula la métrica F1 usando las etiquetas verdaderas y las predichas
    _f1_score = f1_score(y_test, predictions)
    
    # Registra las métricas calculadas en MLflow
    mlflow.log_metrics(
        {
            "accuracy": _accuracy_score,
            "f1": _f1_score
        }
    )
# Out:
# 2025/07/22 13:42:59 WARNING mlflow.utils.autologging_utils: MLflow autologging encountered a warning: "/home/edyn/Documentos/obsidian-doc/Projects/MachineLearningEngineer/Curso2/Proyecto/Repo/ml2_class4_mlsupervisadoavanzado/.venv/lib/python3.12/site-packages/mlflow/types/utils.py:452: UserWarning: Hint: Inferred schema contains integer column(s). Integer columns in Python cannot represent missing values. If your input data contains missing values at inference time, it will be encoded as floats and will cause a schema enforcement error. The best way to avoid this problem is to infer the model schema based on a realistic data sample (training dataset) that includes missing values. Alternatively, you can declare integer columns as doubles (float64) whenever these columns may have missing values. See `Handling Integers With Missing Values <https://www.mlflow.org/docs/latest/models.html#handling-integers-with-missing-values>`_ for more details."
# 2025/07/22 13:43:02 WARNING mlflow.utils.autologging_utils: MLflow autologging encountered a warning: "/home/edyn/Documentos/obsidian-doc/Projects/MachineLearningEngineer/Curso2/Proyecto/Repo/ml2_class4_mlsupervisadoavanzado/.venv/lib/python3.12/site-packages/mlflow/types/utils.py:452: UserWarning: Hint: Inferred schema contains integer column(s). Integer columns in Python cannot represent missing values. If your input data contains missing values at inference time, it will be encoded as floats and will cause a schema enforcement error. The best way to avoid this problem is to infer the model schema based on a realistic data sample (training dataset) that includes missing values. Alternatively, you can declare integer columns as doubles (float64) whenever these columns may have missing values. See `Handling Integers With Missing Values <https://www.mlflow.org/docs/latest/models.html#handling-integers-with-missing-values>`_ for more details."
# 2025/07/22 13:43:09 WARNING mlflow.utils.autologging_utils: MLflow autologging encountered a warning: "/home/edyn/Documentos/obsidian-doc/Projects/MachineLearningEngineer/Curso2/Proyecto/Repo/ml2_class4_mlsupervisadoavanzado/.venv/lib/python3.12/site-packages/mlflow/types/utils.py:452: UserWarning: Hint: Inferred schema contains integer column(s). Integer columns in Python cannot represent missing values. If your input data contains missing values at inference time, it will be encoded as floats and will cause a schema enforcement error. The best way to avoid this problem is to infer the model schema based on a realistic data sample (training dataset) that includes missing values. Alternatively, you can declare integer columns as doubles (float64) whenever these columns may have missing values. See `Handling Integers With Missing Values <https://www.mlflow.org/docs/latest/models.html#handling-integers-with-missing-values>`_ for more details."
# 🏃 View run XGboost at: https://dagshub.com/edynsoncoronado/ml_supervisado_avanzado.mlflow/#/experiments/1/runs/1a971708734d4528aad107a92a44725f
# 🧪 View experiment at: https://dagshub.com/edynsoncoronado/ml_supervisado_avanzado.mlflow/#/experiments/1

# %% [markdown]
# # Ensamble 4: LGBM

# %%
# Inicia una nueva ejecución de MLflow con el nombre "LGBM"
with mlflow.start_run(run_name="LGBM") as run:
    
    # Crea una instancia del clasificador LightGBM
    algorithm = LGBMClassifier()
    
    # Define un pipeline que primero imputa valores faltantes y luego aplica el clasificador LightGBM
    pipeline = Pipeline(
        steps=[
            ("imputer", SimpleImputer(strategy="mean")),  # Imputa valores faltantes usando la media
            ("lgbm", algorithm)                           # Aplica el modelo LightGBM
        ]
    )
    
    # Ajusta el pipeline con los datos de entrenamiento
    pipeline.fit(X_train, y_train)
    
    # Realiza predicciones sobre el conjunto de prueba
    predictions = pipeline.predict(X_test)
    
    # Calcula la métrica de exactitud (accuracy) usando las etiquetas verdaderas y las predichas
    _accuracy_score = accuracy_score(y_test, predictions)
    # Calcula la métrica F1 usando las etiquetas verdaderas y las predichas
    _f1_score = f1_score(y_test, predictions)
    
    # Registra las métricas calculadas en MLflow
    mlflow.log_metrics(
        {
            "accuracy": _accuracy_score,
            "f1": _f1_score
        }   
    )
# Out:
# 2025/07/22 13:44:35 WARNING mlflow.utils.autologging_utils: MLflow autologging encountered a warning: "/home/edyn/Documentos/obsidian-doc/Projects/MachineLearningEngineer/Curso2/Proyecto/Repo/ml2_class4_mlsupervisadoavanzado/.venv/lib/python3.12/site-packages/mlflow/types/utils.py:452: UserWarning: Hint: Inferred schema contains integer column(s). Integer columns in Python cannot represent missing values. If your input data contains missing values at inference time, it will be encoded as floats and will cause a schema enforcement error. The best way to avoid this problem is to infer the model schema based on a realistic data sample (training dataset) that includes missing values. Alternatively, you can declare integer columns as doubles (float64) whenever these columns may have missing values. See `Handling Integers With Missing Values <https://www.mlflow.org/docs/latest/models.html#handling-integers-with-missing-values>`_ for more details."
# /home/edyn/Documentos/obsidian-doc/Projects/MachineLearningEngineer/Curso2/Proyecto/Repo/ml2_class4_mlsupervisadoavanzado/.venv/lib/python3.12/site-packages/sklearn/utils/validation.py:2749: UserWarning: X does not have valid feature names, but LGBMClassifier was fitted with feature names
#   warnings.warn(
# [LightGBM] [Info] Number of positive: 33167, number of negative: 56375
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.001351 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 555
# [LightGBM] [Info] Number of data points in the train set: 89542, number of used features: 5
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.370407 -> initscore=-0.530470
# [LightGBM] [Info] Start training from score -0.530470
# /home/edyn/Documentos/obsidian-doc/Projects/MachineLearningEngineer/Curso2/Proyecto/Repo/ml2_class4_mlsupervisadoavanzado/.venv/lib/python3.12/site-packages/sklearn/utils/validation.py:2749: UserWarning: X does not have valid feature names, but LGBMClassifier was fitted with feature names
#   warnings.warn(
# /home/edyn/Documentos/obsidian-doc/Projects/MachineLearningEngineer/Curso2/Proyecto/Repo/ml2_class4_mlsupervisadoavanzado/.venv/lib/python3.12/site-packages/sklearn/utils/validation.py:2749: UserWarning: X does not have valid feature names, but LGBMClassifier was fitted with feature names
#   warnings.warn(
# /home/edyn/Documentos/obsidian-doc/Projects/MachineLearningEngineer/Curso2/Proyecto/Repo/ml2_class4_mlsupervisadoavanzado/.venv/lib/python3.12/site-packages/sklearn/utils/validation.py:2749: UserWarning: X does not have valid feature names, but LGBMClassifier was fitted with feature names
#   warnings.warn(
# /home/edyn/Documentos/obsidian-doc/Projects/MachineLearningEngineer/Curso2/Proyecto/Repo/ml2_class4_mlsupervisadoavanzado/.venv/lib/python3.12/site-packages/sklearn/utils/validation.py:2749: UserWarning: X does not have valid feature names, but LGBMClassifier was fitted with feature names
#   warnings.warn(
# /home/edyn/Documentos/obsidian-doc/Projects/MachineLearningEngineer/Curso2/Proyecto/Repo/ml2_class4_mlsupervisadoavanzado/.venv/lib/python3.12/site-packages/sklearn/utils/validation.py:2749: UserWarning: X does not have valid feature names, but LGBMClassifier was fitted with feature names
#   warnings.warn(
# /home/edyn/Documentos/obsidian-doc/Projects/MachineLearningEngineer/Curso2/Proyecto/Repo/ml2_class4_mlsupervisadoavanzado/.venv/lib/python3.12/site-packages/sklearn/utils/validation.py:2749: UserWarning: X does not have valid feature names, but LGBMClassifier was fitted with feature names
#   warnings.warn(
# 2025/07/22 13:44:39 WARNING mlflow.utils.autologging_utils: MLflow autologging encountered a warning: "/home/edyn/Documentos/obsidian-doc/Projects/MachineLearningEngineer/Curso2/Proyecto/Repo/ml2_class4_mlsupervisadoavanzado/.venv/lib/python3.12/site-packages/mlflow/types/utils.py:452: UserWarning: Hint: Inferred schema contains integer column(s). Integer columns in Python cannot represent missing values. If your input data contains missing values at inference time, it will be encoded as floats and will cause a schema enforcement error. The best way to avoid this problem is to infer the model schema based on a realistic data sample (training dataset) that includes missing values. Alternatively, you can declare integer columns as doubles (float64) whenever these columns may have missing values. See `Handling Integers With Missing Values <https://www.mlflow.org/docs/latest/models.html#handling-integers-with-missing-values>`_ for more details."
# /home/edyn/Documentos/obsidian-doc/Projects/MachineLearningEngineer/Curso2/Proyecto/Repo/ml2_class4_mlsupervisadoavanzado/.venv/lib/python3.12/site-packages/sklearn/utils/validation.py:2749: UserWarning: X does not have valid feature names, but LGBMClassifier was fitted with feature names
#   warnings.warn(
# 2025/07/22 13:44:46 WARNING mlflow.utils.autologging_utils: MLflow autologging encountered a warning: "/home/edyn/Documentos/obsidian-doc/Projects/MachineLearningEngineer/Curso2/Proyecto/Repo/ml2_class4_mlsupervisadoavanzado/.venv/lib/python3.12/site-packages/mlflow/types/utils.py:452: UserWarning: Hint: Inferred schema contains integer column(s). Integer columns in Python cannot represent missing values. If your input data contains missing values at inference time, it will be encoded as floats and will cause a schema enforcement error. The best way to avoid this problem is to infer the model schema based on a realistic data sample (training dataset) that includes missing values. Alternatively, you can declare integer columns as doubles (float64) whenever these columns may have missing values. See `Handling Integers With Missing Values <https://www.mlflow.org/docs/latest/models.html#handling-integers-with-missing-values>`_ for more details."
# 🏃 View run LGBM at: https://dagshub.com/edynsoncoronado/ml_supervisado_avanzado.mlflow/#/experiments/1/runs/96d82616a85e4fb798c0e885e8ad5695
# 🧪 View experiment at: https://dagshub.com/edynsoncoronado/ml_supervisado_avanzado.mlflow/#/experiments/1

# %% [markdown]
# # Ensamble 5: Catboost

# %%
# Inicia una nueva ejecución de MLflow con el nombre "CatBoost"
with mlflow.start_run(run_name="CatBoost") as run:

    # Crea una instancia del clasificador CatBoost
    algorithm = CatBoostClassifier()
    
    # Define un pipeline que primero imputa valores faltantes y luego aplica el clasificador CatBoost
    pipeline = Pipeline(
        steps=[
            ("imputer", SimpleImputer(strategy="mean")),  # Imputa valores faltantes usando la media
            ("catboost", algorithm)                       # Aplica el modelo CatBoost
        ]
    )
    
    # Ajusta el pipeline con los datos de entrenamiento
    pipeline.fit(X_train, y_train)

    # Realiza predicciones sobre el conjunto de prueba
    predictions = pipeline.predict(X_test)

    # Calcula la métrica de exactitud (accuracy) usando las etiquetas verdaderas y las predichas
    _accuracy_score = accuracy_score(y_test, predictions)
    # Calcula la métrica F1 usando las etiquetas verdaderas y las predichas
    _f1_score = f1_score(y_test, predictions)
    
    # Registra las métricas calculadas en MLflow
    mlflow.log_metrics(
        {
            "accuracy": _accuracy_score,
            "f1": _f1_score
        }        
    )
# Out:
# 2025/07/22 13:46:17 WARNING mlflow.utils.autologging_utils: MLflow autologging encountered a warning: "/home/edyn/Documentos/obsidian-doc/Projects/MachineLearningEngineer/Curso2/Proyecto/Repo/ml2_class4_mlsupervisadoavanzado/.venv/lib/python3.12/site-packages/mlflow/types/utils.py:452: UserWarning: Hint: Inferred schema contains integer column(s). Integer columns in Python cannot represent missing values. If your input data contains missing values at inference time, it will be encoded as floats and will cause a schema enforcement error. The best way to avoid this problem is to infer the model schema based on a realistic data sample (training dataset) that includes missing values. Alternatively, you can declare integer columns as doubles (float64) whenever these columns may have missing values. See `Handling Integers With Missing Values <https://www.mlflow.org/docs/latest/models.html#handling-integers-with-missing-values>`_ for more details."
# Learning rate set to 0.070218
# 0:	learn: 0.6738091	total: 52.5ms	remaining: 52.5s
# 1:	learn: 0.6577196	total: 57.3ms	remaining: 28.6s
# 2:	learn: 0.6435688	total: 63.7ms	remaining: 21.2s
# 3:	learn: 0.6321461	total: 71.1ms	remaining: 17.7s
# 4:	learn: 0.6222567	total: 76.5ms	remaining: 15.2s
# 5:	learn: 0.6132893	total: 83ms	remaining: 13.7s
# 6:	learn: 0.6055982	total: 89.5ms	remaining: 12.7s
# 7:	learn: 0.5995170	total: 96.2ms	remaining: 11.9s
# 8:	learn: 0.5937286	total: 105ms	remaining: 11.5s
# 9:	learn: 0.5890019	total: 116ms	remaining: 11.4s
# 10:	learn: 0.5846239	total: 121ms	remaining: 10.9s
# 11:	learn: 0.5811667	total: 128ms	remaining: 10.5s
# 12:	learn: 0.5778450	total: 135ms	remaining: 10.3s
# 13:	learn: 0.5752667	total: 142ms	remaining: 9.98s
# 14:	learn: 0.5728444	total: 149ms	remaining: 9.81s
# 15:	learn: 0.5706692	total: 155ms	remaining: 9.56s
# 16:	learn: 0.5687932	total: 163ms	remaining: 9.4s
# 17:	learn: 0.5673718	total: 168ms	remaining: 9.18s
# 18:	learn: 0.5658373	total: 175ms	remaining: 9.03s
# 19:	learn: 0.5646682	total: 182ms	remaining: 8.89s
# 20:	learn: 0.5634752	total: 188ms	remaining: 8.75s
# 21:	learn: 0.5625968	total: 195ms	remaining: 8.68s
# 22:	learn: 0.5617194	total: 206ms	remaining: 8.77s
# 23:	learn: 0.5603407	total: 215ms	remaining: 8.75s
# 24:	learn: 0.5595529	total: 225ms	remaining: 8.76s
# 25:	learn: 0.5589838	total: 232ms	remaining: 8.7s
# 26:	learn: 0.5578744	total: 238ms	remaining: 8.58s
# 27:	learn: 0.5574359	total: 246ms	remaining: 8.53s
# 28:	learn: 0.5563687	total: 256ms	remaining: 8.58s
# 29:	learn: 0.5555224	total: 270ms	remaining: 8.72s
# 30:	learn: 0.5547934	total: 279ms	remaining: 8.72s
# 31:	learn: 0.5539811	total: 287ms	remaining: 8.69s
# 32:	learn: 0.5534522	total: 301ms	remaining: 8.82s
# 33:	learn: 0.5529575	total: 318ms	remaining: 9.03s
# 34:	learn: 0.5525878	total: 335ms	remaining: 9.23s
# 35:	learn: 0.5522278	total: 351ms	remaining: 9.4s
# 36:	learn: 0.5518975	total: 368ms	remaining: 9.58s
# 37:	learn: 0.5514938	total: 379ms	remaining: 9.6s
# 38:	learn: 0.5509941	total: 389ms	remaining: 9.59s
# 39:	learn: 0.5507952	total: 403ms	remaining: 9.67s
# 40:	learn: 0.5502762	total: 413ms	remaining: 9.66s
# 41:	learn: 0.5500638	total: 421ms	remaining: 9.59s
# 42:	learn: 0.5494699	total: 427ms	remaining: 9.5s
# 43:	learn: 0.5493196	total: 435ms	remaining: 9.46s
# 44:	learn: 0.5489611	total: 442ms	remaining: 9.38s
# 45:	learn: 0.5484715	total: 450ms	remaining: 9.33s
# 46:	learn: 0.5481746	total: 456ms	remaining: 9.24s
# 47:	learn: 0.5479264	total: 464ms	remaining: 9.2s
# 48:	learn: 0.5476823	total: 471ms	remaining: 9.14s
# 49:	learn: 0.5474421	total: 478ms	remaining: 9.07s
# 50:	learn: 0.5472060	total: 484ms	remaining: 9.01s
# 51:	learn: 0.5468837	total: 490ms	remaining: 8.92s
# 52:	learn: 0.5463759	total: 497ms	remaining: 8.88s
# 53:	learn: 0.5460722	total: 503ms	remaining: 8.81s
# 54:	learn: 0.5459709	total: 510ms	remaining: 8.76s
# 55:	learn: 0.5455037	total: 517ms	remaining: 8.72s
# 56:	learn: 0.5450632	total: 524ms	remaining: 8.67s
# 57:	learn: 0.5449021	total: 532ms	remaining: 8.63s
# 58:	learn: 0.5447871	total: 540ms	remaining: 8.62s
# 59:	learn: 0.5445962	total: 547ms	remaining: 8.58s
# 60:	learn: 0.5444582	total: 557ms	remaining: 8.57s
# 61:	learn: 0.5439663	total: 564ms	remaining: 8.53s
# 62:	learn: 0.5437579	total: 570ms	remaining: 8.48s
# 63:	learn: 0.5434623	total: 580ms	remaining: 8.47s
# 64:	learn: 0.5431449	total: 590ms	remaining: 8.49s
# 65:	learn: 0.5428683	total: 597ms	remaining: 8.45s
# 66:	learn: 0.5427729	total: 606ms	remaining: 8.44s
# 67:	learn: 0.5427015	total: 613ms	remaining: 8.4s
# 68:	learn: 0.5424063	total: 622ms	remaining: 8.39s
# 69:	learn: 0.5422560	total: 628ms	remaining: 8.34s
# 70:	learn: 0.5419692	total: 636ms	remaining: 8.33s
# 71:	learn: 0.5418715	total: 644ms	remaining: 8.3s
# 72:	learn: 0.5417152	total: 652ms	remaining: 8.28s
# 73:	learn: 0.5413805	total: 658ms	remaining: 8.24s
# 74:	learn: 0.5411410	total: 666ms	remaining: 8.21s
# 75:	learn: 0.5408846	total: 678ms	remaining: 8.24s
# 76:	learn: 0.5405545	total: 687ms	remaining: 8.23s
# 77:	learn: 0.5401894	total: 694ms	remaining: 8.2s
# 78:	learn: 0.5401504	total: 704ms	remaining: 8.2s
# 79:	learn: 0.5400497	total: 710ms	remaining: 8.17s
# 80:	learn: 0.5399743	total: 721ms	remaining: 8.18s
# 81:	learn: 0.5398184	total: 729ms	remaining: 8.16s
# 82:	learn: 0.5395765	total: 742ms	remaining: 8.2s
# 83:	learn: 0.5392679	total: 756ms	remaining: 8.24s
# 84:	learn: 0.5390865	total: 763ms	remaining: 8.21s
# 85:	learn: 0.5386677	total: 770ms	remaining: 8.18s
# 86:	learn: 0.5385269	total: 782ms	remaining: 8.21s
# 87:	learn: 0.5382655	total: 792ms	remaining: 8.2s
# 88:	learn: 0.5381127	total: 799ms	remaining: 8.18s
# 89:	learn: 0.5378263	total: 805ms	remaining: 8.14s
# 90:	learn: 0.5376093	total: 813ms	remaining: 8.12s
# 91:	learn: 0.5373396	total: 819ms	remaining: 8.08s
# 92:	learn: 0.5371846	total: 825ms	remaining: 8.05s
# 93:	learn: 0.5371293	total: 835ms	remaining: 8.04s
# 94:	learn: 0.5370116	total: 840ms	remaining: 8s
# 95:	learn: 0.5367793	total: 848ms	remaining: 7.99s
# 96:	learn: 0.5366387	total: 857ms	remaining: 7.98s
# 97:	learn: 0.5363829	total: 864ms	remaining: 7.96s
# 98:	learn: 0.5362807	total: 870ms	remaining: 7.91s
# 99:	learn: 0.5361594	total: 878ms	remaining: 7.9s
# 100:	learn: 0.5360774	total: 883ms	remaining: 7.86s
# 101:	learn: 0.5359789	total: 891ms	remaining: 7.85s
# 102:	learn: 0.5358153	total: 897ms	remaining: 7.81s
# 103:	learn: 0.5356398	total: 903ms	remaining: 7.78s
# 104:	learn: 0.5354815	total: 910ms	remaining: 7.76s
# 105:	learn: 0.5352540	total: 916ms	remaining: 7.72s
# 106:	learn: 0.5351598	total: 923ms	remaining: 7.71s
# 107:	learn: 0.5351231	total: 929ms	remaining: 7.68s
# 108:	learn: 0.5350739	total: 935ms	remaining: 7.65s
# 109:	learn: 0.5349222	total: 942ms	remaining: 7.62s
# 110:	learn: 0.5347762	total: 948ms	remaining: 7.59s
# 111:	learn: 0.5345218	total: 956ms	remaining: 7.58s
# 112:	learn: 0.5344764	total: 962ms	remaining: 7.55s
# 113:	learn: 0.5344258	total: 969ms	remaining: 7.53s
# 114:	learn: 0.5344049	total: 976ms	remaining: 7.51s
# 115:	learn: 0.5343385	total: 985ms	remaining: 7.51s
# 116:	learn: 0.5342430	total: 993ms	remaining: 7.49s
# 117:	learn: 0.5341841	total: 999ms	remaining: 7.46s
# 118:	learn: 0.5340791	total: 1.01s	remaining: 7.46s
# 119:	learn: 0.5338623	total: 1.01s	remaining: 7.43s
# 120:	learn: 0.5337191	total: 1.02s	remaining: 7.42s
# 121:	learn: 0.5334027	total: 1.03s	remaining: 7.4s
# 122:	learn: 0.5331806	total: 1.04s	remaining: 7.39s
# 123:	learn: 0.5330272	total: 1.04s	remaining: 7.36s
# 124:	learn: 0.5329142	total: 1.05s	remaining: 7.36s
# 125:	learn: 0.5327357	total: 1.06s	remaining: 7.34s
# 126:	learn: 0.5326471	total: 1.07s	remaining: 7.33s
# 127:	learn: 0.5325645	total: 1.07s	remaining: 7.31s
# 128:	learn: 0.5324515	total: 1.08s	remaining: 7.29s
# 129:	learn: 0.5324019	total: 1.09s	remaining: 7.28s
# 130:	learn: 0.5321295	total: 1.1s	remaining: 7.28s
# 131:	learn: 0.5320616	total: 1.1s	remaining: 7.26s
# 132:	learn: 0.5317878	total: 1.11s	remaining: 7.24s
# 133:	learn: 0.5317633	total: 1.12s	remaining: 7.22s
# 134:	learn: 0.5315552	total: 1.12s	remaining: 7.2s
# 135:	learn: 0.5315382	total: 1.13s	remaining: 7.19s
# 136:	learn: 0.5312897	total: 1.14s	remaining: 7.17s
# 137:	learn: 0.5311512	total: 1.15s	remaining: 7.16s
# 138:	learn: 0.5310911	total: 1.16s	remaining: 7.16s
# 139:	learn: 0.5309502	total: 1.17s	remaining: 7.18s
# 140:	learn: 0.5308071	total: 1.18s	remaining: 7.2s
# 141:	learn: 0.5307255	total: 1.19s	remaining: 7.22s
# 142:	learn: 0.5306572	total: 1.2s	remaining: 7.21s
# 143:	learn: 0.5304292	total: 1.21s	remaining: 7.21s
# 144:	learn: 0.5303169	total: 1.22s	remaining: 7.18s
# 145:	learn: 0.5301340	total: 1.23s	remaining: 7.17s
# 146:	learn: 0.5300460	total: 1.23s	remaining: 7.15s
# 147:	learn: 0.5298032	total: 1.24s	remaining: 7.13s
# 148:	learn: 0.5297653	total: 1.25s	remaining: 7.13s
# 149:	learn: 0.5296789	total: 1.25s	remaining: 7.11s
# 150:	learn: 0.5295721	total: 1.26s	remaining: 7.09s
# 151:	learn: 0.5295068	total: 1.27s	remaining: 7.08s
# 152:	learn: 0.5294477	total: 1.28s	remaining: 7.07s
# 153:	learn: 0.5293559	total: 1.28s	remaining: 7.04s
# 154:	learn: 0.5293085	total: 1.29s	remaining: 7.05s
# 155:	learn: 0.5292371	total: 1.3s	remaining: 7.03s
# 156:	learn: 0.5291776	total: 1.31s	remaining: 7.02s
# 157:	learn: 0.5291337	total: 1.31s	remaining: 7.01s
# 158:	learn: 0.5289750	total: 1.33s	remaining: 7.03s
# 159:	learn: 0.5287439	total: 1.33s	remaining: 7.01s
# 160:	learn: 0.5284720	total: 1.34s	remaining: 7s
# 161:	learn: 0.5283536	total: 1.35s	remaining: 6.98s
# 162:	learn: 0.5282082	total: 1.36s	remaining: 6.97s
# 163:	learn: 0.5281411	total: 1.36s	remaining: 6.96s
# 164:	learn: 0.5280409	total: 1.37s	remaining: 6.95s
# 165:	learn: 0.5278632	total: 1.38s	remaining: 6.93s
# 166:	learn: 0.5278181	total: 1.38s	remaining: 6.9s
# 167:	learn: 0.5276296	total: 1.39s	remaining: 6.89s
# 168:	learn: 0.5275481	total: 1.4s	remaining: 6.87s
# 169:	learn: 0.5273079	total: 1.4s	remaining: 6.85s
# 170:	learn: 0.5270704	total: 1.41s	remaining: 6.84s
# 171:	learn: 0.5268535	total: 1.42s	remaining: 6.83s
# 172:	learn: 0.5267480	total: 1.43s	remaining: 6.83s
# 173:	learn: 0.5266670	total: 1.44s	remaining: 6.85s
# 174:	learn: 0.5266142	total: 1.45s	remaining: 6.85s
# 175:	learn: 0.5264349	total: 1.46s	remaining: 6.83s
# 176:	learn: 0.5262728	total: 1.47s	remaining: 6.83s
# 177:	learn: 0.5260840	total: 1.47s	remaining: 6.8s
# 178:	learn: 0.5259459	total: 1.48s	remaining: 6.78s
# 179:	learn: 0.5258721	total: 1.49s	remaining: 6.77s
# 180:	learn: 0.5258008	total: 1.49s	remaining: 6.75s
# 181:	learn: 0.5257314	total: 1.5s	remaining: 6.75s
# 182:	learn: 0.5256839	total: 1.51s	remaining: 6.74s
# 183:	learn: 0.5255035	total: 1.52s	remaining: 6.73s
# 184:	learn: 0.5254140	total: 1.52s	remaining: 6.72s
# 185:	learn: 0.5253148	total: 1.53s	remaining: 6.71s
# 186:	learn: 0.5251390	total: 1.54s	remaining: 6.69s
# 187:	learn: 0.5250636	total: 1.55s	remaining: 6.7s
# 188:	learn: 0.5248768	total: 1.56s	remaining: 6.68s
# 189:	learn: 0.5247201	total: 1.57s	remaining: 6.69s
# 190:	learn: 0.5246463	total: 1.58s	remaining: 6.71s
# 191:	learn: 0.5244814	total: 1.6s	remaining: 6.73s
# 192:	learn: 0.5242867	total: 1.61s	remaining: 6.72s
# 193:	learn: 0.5241889	total: 1.62s	remaining: 6.72s
# 194:	learn: 0.5241018	total: 1.62s	remaining: 6.7s
# 195:	learn: 0.5240168	total: 1.63s	remaining: 6.69s
# 196:	learn: 0.5237648	total: 1.64s	remaining: 6.68s
# 197:	learn: 0.5237094	total: 1.65s	remaining: 6.67s
# 198:	learn: 0.5236287	total: 1.65s	remaining: 6.66s
# 199:	learn: 0.5235044	total: 1.66s	remaining: 6.64s
# 200:	learn: 0.5233885	total: 1.67s	remaining: 6.62s
# 201:	learn: 0.5231854	total: 1.67s	remaining: 6.61s
# 202:	learn: 0.5229853	total: 1.68s	remaining: 6.6s
# 203:	learn: 0.5228315	total: 1.69s	remaining: 6.58s
# 204:	learn: 0.5226548	total: 1.69s	remaining: 6.57s
# 205:	learn: 0.5225193	total: 1.7s	remaining: 6.55s
# 206:	learn: 0.5224484	total: 1.71s	remaining: 6.54s
# 207:	learn: 0.5222655	total: 1.72s	remaining: 6.54s
# 208:	learn: 0.5220643	total: 1.73s	remaining: 6.53s
# 209:	learn: 0.5219125	total: 1.73s	remaining: 6.51s
# 210:	learn: 0.5218701	total: 1.74s	remaining: 6.51s
# 211:	learn: 0.5217195	total: 1.75s	remaining: 6.49s
# 212:	learn: 0.5215435	total: 1.76s	remaining: 6.5s
# 213:	learn: 0.5214770	total: 1.77s	remaining: 6.51s
# 214:	learn: 0.5212733	total: 1.78s	remaining: 6.5s
# 215:	learn: 0.5211149	total: 1.79s	remaining: 6.5s
# 216:	learn: 0.5208956	total: 1.8s	remaining: 6.48s
# 217:	learn: 0.5207642	total: 1.8s	remaining: 6.47s
# 218:	learn: 0.5206847	total: 1.81s	remaining: 6.46s
# 219:	learn: 0.5205855	total: 1.82s	remaining: 6.45s
# 220:	learn: 0.5205229	total: 1.82s	remaining: 6.43s
# 221:	learn: 0.5204361	total: 1.83s	remaining: 6.42s
# 222:	learn: 0.5203395	total: 1.84s	remaining: 6.41s
# 223:	learn: 0.5202072	total: 1.84s	remaining: 6.39s
# 224:	learn: 0.5201336	total: 1.85s	remaining: 6.39s
# 225:	learn: 0.5199994	total: 1.86s	remaining: 6.38s
# 226:	learn: 0.5197615	total: 1.87s	remaining: 6.38s
# 227:	learn: 0.5195919	total: 1.88s	remaining: 6.37s
# 228:	learn: 0.5194573	total: 1.89s	remaining: 6.37s
# 229:	learn: 0.5193540	total: 1.9s	remaining: 6.36s
# 230:	learn: 0.5192622	total: 1.91s	remaining: 6.34s
# 231:	learn: 0.5191694	total: 1.91s	remaining: 6.33s
# 232:	learn: 0.5190966	total: 1.92s	remaining: 6.33s
# 233:	learn: 0.5189914	total: 1.93s	remaining: 6.32s
# 234:	learn: 0.5188320	total: 1.94s	remaining: 6.31s
# 235:	learn: 0.5187097	total: 1.95s	remaining: 6.32s
# 236:	learn: 0.5184611	total: 1.96s	remaining: 6.32s
# 237:	learn: 0.5184044	total: 1.97s	remaining: 6.32s
# 238:	learn: 0.5182942	total: 1.99s	remaining: 6.34s
# 239:	learn: 0.5181636	total: 2s	remaining: 6.33s
# 240:	learn: 0.5181083	total: 2.01s	remaining: 6.33s
# 241:	learn: 0.5179976	total: 2.02s	remaining: 6.33s
# 242:	learn: 0.5178847	total: 2.03s	remaining: 6.34s
# 243:	learn: 0.5176583	total: 2.05s	remaining: 6.34s
# 244:	learn: 0.5175738	total: 2.06s	remaining: 6.33s
# 245:	learn: 0.5173974	total: 2.06s	remaining: 6.33s
# 246:	learn: 0.5173137	total: 2.07s	remaining: 6.31s
# 247:	learn: 0.5172291	total: 2.08s	remaining: 6.31s
# 248:	learn: 0.5171755	total: 2.09s	remaining: 6.3s
# 249:	learn: 0.5170468	total: 2.1s	remaining: 6.29s
# 250:	learn: 0.5170072	total: 2.1s	remaining: 6.28s
# 251:	learn: 0.5168255	total: 2.11s	remaining: 6.27s
# 252:	learn: 0.5167291	total: 2.12s	remaining: 6.27s
# 253:	learn: 0.5166623	total: 2.13s	remaining: 6.26s
# 254:	learn: 0.5165749	total: 2.14s	remaining: 6.25s
# 255:	learn: 0.5164671	total: 2.15s	remaining: 6.24s
# 256:	learn: 0.5163888	total: 2.16s	remaining: 6.24s
# 257:	learn: 0.5163399	total: 2.16s	remaining: 6.22s
# 258:	learn: 0.5162075	total: 2.18s	remaining: 6.22s
# 259:	learn: 0.5161405	total: 2.19s	remaining: 6.23s
# 260:	learn: 0.5159468	total: 2.19s	remaining: 6.22s
# 261:	learn: 0.5157663	total: 2.2s	remaining: 6.21s
# 262:	learn: 0.5156172	total: 2.21s	remaining: 6.19s
# 263:	learn: 0.5154903	total: 2.22s	remaining: 6.19s
# 264:	learn: 0.5154443	total: 2.23s	remaining: 6.17s
# 265:	learn: 0.5153927	total: 2.23s	remaining: 6.16s
# 266:	learn: 0.5153052	total: 2.24s	remaining: 6.15s
# 267:	learn: 0.5151503	total: 2.25s	remaining: 6.13s
# 268:	learn: 0.5150198	total: 2.25s	remaining: 6.12s
# 269:	learn: 0.5149535	total: 2.26s	remaining: 6.11s
# 270:	learn: 0.5148251	total: 2.27s	remaining: 6.09s
# 271:	learn: 0.5146647	total: 2.27s	remaining: 6.08s
# 272:	learn: 0.5145871	total: 2.28s	remaining: 6.07s
# 273:	learn: 0.5142949	total: 2.29s	remaining: 6.05s
# 274:	learn: 0.5142030	total: 2.29s	remaining: 6.04s
# 275:	learn: 0.5139264	total: 2.3s	remaining: 6.03s
# 276:	learn: 0.5138545	total: 2.3s	remaining: 6.01s
# 277:	learn: 0.5137699	total: 2.31s	remaining: 6.01s
# 278:	learn: 0.5137080	total: 2.32s	remaining: 5.99s
# 279:	learn: 0.5134907	total: 2.32s	remaining: 5.98s
# 280:	learn: 0.5133738	total: 2.33s	remaining: 5.97s
# 281:	learn: 0.5132638	total: 2.34s	remaining: 5.96s
# 282:	learn: 0.5132239	total: 2.35s	remaining: 5.95s
# 283:	learn: 0.5131404	total: 2.35s	remaining: 5.93s
# 284:	learn: 0.5130438	total: 2.36s	remaining: 5.92s
# 285:	learn: 0.5129292	total: 2.37s	remaining: 5.91s
# 286:	learn: 0.5128743	total: 2.38s	remaining: 5.91s
# 287:	learn: 0.5127998	total: 2.39s	remaining: 5.91s
# 288:	learn: 0.5126506	total: 2.4s	remaining: 5.9s
# 289:	learn: 0.5125215	total: 2.41s	remaining: 5.89s
# 290:	learn: 0.5124202	total: 2.42s	remaining: 5.88s
# 291:	learn: 0.5123443	total: 2.42s	remaining: 5.87s
# 292:	learn: 0.5121998	total: 2.43s	remaining: 5.86s
# 293:	learn: 0.5120072	total: 2.44s	remaining: 5.85s
# 294:	learn: 0.5119180	total: 2.45s	remaining: 5.85s
# 295:	learn: 0.5118540	total: 2.46s	remaining: 5.84s
# 296:	learn: 0.5117145	total: 2.46s	remaining: 5.83s
# 297:	learn: 0.5115797	total: 2.47s	remaining: 5.82s
# 298:	learn: 0.5114858	total: 2.48s	remaining: 5.81s
# 299:	learn: 0.5113667	total: 2.49s	remaining: 5.8s
# 300:	learn: 0.5112269	total: 2.49s	remaining: 5.79s
# 301:	learn: 0.5109666	total: 2.5s	remaining: 5.78s
# 302:	learn: 0.5108058	total: 2.51s	remaining: 5.77s
# 303:	learn: 0.5107511	total: 2.52s	remaining: 5.76s
# 304:	learn: 0.5106121	total: 2.52s	remaining: 5.75s
# 305:	learn: 0.5104509	total: 2.53s	remaining: 5.74s
# 306:	learn: 0.5103643	total: 2.54s	remaining: 5.73s
# 307:	learn: 0.5102548	total: 2.55s	remaining: 5.72s
# 308:	learn: 0.5102040	total: 2.56s	remaining: 5.71s
# 309:	learn: 0.5100902	total: 2.56s	remaining: 5.7s
# 310:	learn: 0.5099231	total: 2.57s	remaining: 5.69s
# 311:	learn: 0.5098335	total: 2.58s	remaining: 5.68s
# 312:	learn: 0.5097367	total: 2.59s	remaining: 5.68s
# 313:	learn: 0.5095930	total: 2.59s	remaining: 5.66s
# 314:	learn: 0.5094873	total: 2.6s	remaining: 5.66s
# 315:	learn: 0.5093922	total: 2.61s	remaining: 5.64s
# 316:	learn: 0.5093253	total: 2.62s	remaining: 5.64s
# 317:	learn: 0.5092649	total: 2.62s	remaining: 5.63s
# 318:	learn: 0.5091962	total: 2.63s	remaining: 5.62s
# 319:	learn: 0.5091319	total: 2.64s	remaining: 5.61s
# 320:	learn: 0.5090218	total: 2.65s	remaining: 5.6s
# 321:	learn: 0.5089238	total: 2.65s	remaining: 5.59s
# 322:	learn: 0.5088558	total: 2.66s	remaining: 5.58s
# 323:	learn: 0.5087282	total: 2.67s	remaining: 5.57s
# 324:	learn: 0.5086565	total: 2.68s	remaining: 5.56s
# 325:	learn: 0.5085618	total: 2.69s	remaining: 5.55s
# 326:	learn: 0.5085080	total: 2.69s	remaining: 5.55s
# 327:	learn: 0.5083851	total: 2.7s	remaining: 5.54s
# 328:	learn: 0.5082999	total: 2.71s	remaining: 5.53s
# 329:	learn: 0.5082498	total: 2.72s	remaining: 5.51s
# 330:	learn: 0.5082080	total: 2.72s	remaining: 5.51s
# 331:	learn: 0.5081254	total: 2.73s	remaining: 5.5s
# 332:	learn: 0.5080519	total: 2.74s	remaining: 5.49s
# 333:	learn: 0.5079769	total: 2.75s	remaining: 5.48s
# 334:	learn: 0.5079449	total: 2.75s	remaining: 5.46s
# 335:	learn: 0.5078360	total: 2.76s	remaining: 5.46s
# 336:	learn: 0.5077468	total: 2.77s	remaining: 5.44s
# 337:	learn: 0.5076172	total: 2.78s	remaining: 5.44s
# 338:	learn: 0.5075827	total: 2.79s	remaining: 5.43s
# 339:	learn: 0.5075102	total: 2.8s	remaining: 5.43s
# 340:	learn: 0.5073550	total: 2.81s	remaining: 5.43s
# 341:	learn: 0.5072986	total: 2.82s	remaining: 5.42s
# 342:	learn: 0.5071948	total: 2.84s	remaining: 5.44s
# 343:	learn: 0.5070778	total: 2.86s	remaining: 5.45s
# 344:	learn: 0.5070162	total: 2.86s	remaining: 5.44s
# 345:	learn: 0.5069164	total: 2.87s	remaining: 5.43s
# 346:	learn: 0.5068455	total: 2.88s	remaining: 5.42s
# 347:	learn: 0.5067546	total: 2.89s	remaining: 5.42s
# 348:	learn: 0.5066894	total: 2.9s	remaining: 5.41s
# 349:	learn: 0.5066256	total: 2.92s	remaining: 5.42s
# 350:	learn: 0.5065544	total: 2.93s	remaining: 5.42s
# 351:	learn: 0.5064825	total: 2.94s	remaining: 5.41s
# 352:	learn: 0.5063943	total: 2.95s	remaining: 5.4s
# 353:	learn: 0.5063132	total: 2.96s	remaining: 5.39s
# 354:	learn: 0.5062232	total: 2.96s	remaining: 5.38s
# 355:	learn: 0.5061981	total: 2.97s	remaining: 5.38s
# 356:	learn: 0.5061524	total: 2.98s	remaining: 5.37s
# 357:	learn: 0.5061023	total: 3s	remaining: 5.37s
# 358:	learn: 0.5060357	total: 3.01s	remaining: 5.38s
# 359:	learn: 0.5058463	total: 3.02s	remaining: 5.37s
# 360:	learn: 0.5057235	total: 3.03s	remaining: 5.37s
# 361:	learn: 0.5055866	total: 3.04s	remaining: 5.36s
# 362:	learn: 0.5055280	total: 3.05s	remaining: 5.36s
# 363:	learn: 0.5054841	total: 3.06s	remaining: 5.35s
# 364:	learn: 0.5054308	total: 3.07s	remaining: 5.34s
# 365:	learn: 0.5053100	total: 3.08s	remaining: 5.33s
# 366:	learn: 0.5052796	total: 3.09s	remaining: 5.33s
# 367:	learn: 0.5051467	total: 3.1s	remaining: 5.32s
# 368:	learn: 0.5051015	total: 3.11s	remaining: 5.32s
# 369:	learn: 0.5049731	total: 3.12s	remaining: 5.31s
# 370:	learn: 0.5048905	total: 3.13s	remaining: 5.31s
# 371:	learn: 0.5047709	total: 3.14s	remaining: 5.3s
# 372:	learn: 0.5046735	total: 3.15s	remaining: 5.29s
# 373:	learn: 0.5046318	total: 3.15s	remaining: 5.28s
# 374:	learn: 0.5045839	total: 3.17s	remaining: 5.28s
# 375:	learn: 0.5045438	total: 3.18s	remaining: 5.29s
# 376:	learn: 0.5044808	total: 3.19s	remaining: 5.28s
# 377:	learn: 0.5044102	total: 3.21s	remaining: 5.27s
# 378:	learn: 0.5043454	total: 3.21s	remaining: 5.27s
# 379:	learn: 0.5042941	total: 3.23s	remaining: 5.27s
# 380:	learn: 0.5042316	total: 3.24s	remaining: 5.26s
# 381:	learn: 0.5042004	total: 3.24s	remaining: 5.25s
# 382:	learn: 0.5041095	total: 3.25s	remaining: 5.24s
# 383:	learn: 0.5040612	total: 3.26s	remaining: 5.23s
# 384:	learn: 0.5038904	total: 3.27s	remaining: 5.22s
# 385:	learn: 0.5038208	total: 3.28s	remaining: 5.21s
# 386:	learn: 0.5037300	total: 3.29s	remaining: 5.2s
# 387:	learn: 0.5036528	total: 3.29s	remaining: 5.19s
# 388:	learn: 0.5035745	total: 3.3s	remaining: 5.18s
# 389:	learn: 0.5035076	total: 3.3s	remaining: 5.17s
# 390:	learn: 0.5034202	total: 3.31s	remaining: 5.16s
# 391:	learn: 0.5033254	total: 3.32s	remaining: 5.14s
# 392:	learn: 0.5032685	total: 3.32s	remaining: 5.13s
# 393:	learn: 0.5031740	total: 3.33s	remaining: 5.12s
# 394:	learn: 0.5030800	total: 3.33s	remaining: 5.11s
# 395:	learn: 0.5030264	total: 3.34s	remaining: 5.1s
# 396:	learn: 0.5029560	total: 3.35s	remaining: 5.09s
# 397:	learn: 0.5029037	total: 3.35s	remaining: 5.07s
# 398:	learn: 0.5028082	total: 3.36s	remaining: 5.07s
# 399:	learn: 0.5026724	total: 3.37s	remaining: 5.06s
# 400:	learn: 0.5026034	total: 3.38s	remaining: 5.05s
# 401:	learn: 0.5025421	total: 3.39s	remaining: 5.04s
# 402:	learn: 0.5025036	total: 3.39s	remaining: 5.03s
# 403:	learn: 0.5024260	total: 3.4s	remaining: 5.02s
# 404:	learn: 0.5023811	total: 3.41s	remaining: 5.01s
# 405:	learn: 0.5023028	total: 3.42s	remaining: 5s
# 406:	learn: 0.5022283	total: 3.42s	remaining: 4.99s
# 407:	learn: 0.5020701	total: 3.43s	remaining: 4.98s
# 408:	learn: 0.5020131	total: 3.44s	remaining: 4.97s
# 409:	learn: 0.5019586	total: 3.44s	remaining: 4.96s
# 410:	learn: 0.5019122	total: 3.45s	remaining: 4.94s
# 411:	learn: 0.5018320	total: 3.46s	remaining: 4.93s
# 412:	learn: 0.5017822	total: 3.46s	remaining: 4.92s
# 413:	learn: 0.5016931	total: 3.47s	remaining: 4.92s
# 414:	learn: 0.5016424	total: 3.48s	remaining: 4.9s
# 415:	learn: 0.5015423	total: 3.49s	remaining: 4.9s
# 416:	learn: 0.5014679	total: 3.5s	remaining: 4.89s
# 417:	learn: 0.5013571	total: 3.5s	remaining: 4.88s
# 418:	learn: 0.5012948	total: 3.51s	remaining: 4.87s
# 419:	learn: 0.5012288	total: 3.52s	remaining: 4.86s
# 420:	learn: 0.5011767	total: 3.52s	remaining: 4.85s
# 421:	learn: 0.5011502	total: 3.53s	remaining: 4.83s
# 422:	learn: 0.5010941	total: 3.54s	remaining: 4.82s
# 423:	learn: 0.5010354	total: 3.54s	remaining: 4.81s
# 424:	learn: 0.5008866	total: 3.55s	remaining: 4.8s
# 425:	learn: 0.5007568	total: 3.56s	remaining: 4.79s
# 426:	learn: 0.5007074	total: 3.56s	remaining: 4.79s
# 427:	learn: 0.5006489	total: 3.57s	remaining: 4.78s
# 428:	learn: 0.5005712	total: 3.58s	remaining: 4.76s
# 429:	learn: 0.5005029	total: 3.59s	remaining: 4.75s
# 430:	learn: 0.5004303	total: 3.59s	remaining: 4.74s
# 431:	learn: 0.5003653	total: 3.6s	remaining: 4.74s
# 432:	learn: 0.5003136	total: 3.61s	remaining: 4.73s
# 433:	learn: 0.5002546	total: 3.62s	remaining: 4.72s
# 434:	learn: 0.5001983	total: 3.63s	remaining: 4.71s
# 435:	learn: 0.5000494	total: 3.63s	remaining: 4.7s
# 436:	learn: 0.4999830	total: 3.64s	remaining: 4.69s
# 437:	learn: 0.4999105	total: 3.65s	remaining: 4.68s
# 438:	learn: 0.4998452	total: 3.66s	remaining: 4.67s
# 439:	learn: 0.4997691	total: 3.67s	remaining: 4.67s
# 440:	learn: 0.4996079	total: 3.68s	remaining: 4.66s
# 441:	learn: 0.4995513	total: 3.69s	remaining: 4.66s
# 442:	learn: 0.4995089	total: 3.7s	remaining: 4.65s
# 443:	learn: 0.4994654	total: 3.71s	remaining: 4.65s
# 444:	learn: 0.4994191	total: 3.73s	remaining: 4.65s
# 445:	learn: 0.4993447	total: 3.74s	remaining: 4.64s
# 446:	learn: 0.4992742	total: 3.74s	remaining: 4.63s
# 447:	learn: 0.4992442	total: 3.75s	remaining: 4.62s
# 448:	learn: 0.4990002	total: 3.76s	remaining: 4.61s
# 449:	learn: 0.4989588	total: 3.76s	remaining: 4.6s
# 450:	learn: 0.4989213	total: 3.77s	remaining: 4.59s
# 451:	learn: 0.4988478	total: 3.78s	remaining: 4.58s
# 452:	learn: 0.4987996	total: 3.79s	remaining: 4.58s
# 453:	learn: 0.4987563	total: 3.8s	remaining: 4.57s
# 454:	learn: 0.4986942	total: 3.8s	remaining: 4.55s
# 455:	learn: 0.4986300	total: 3.81s	remaining: 4.54s
# 456:	learn: 0.4985421	total: 3.81s	remaining: 4.53s
# 457:	learn: 0.4984828	total: 3.82s	remaining: 4.52s
# 458:	learn: 0.4984216	total: 3.83s	remaining: 4.51s
# 459:	learn: 0.4983340	total: 3.83s	remaining: 4.5s
# 460:	learn: 0.4983036	total: 3.84s	remaining: 4.49s
# 461:	learn: 0.4982381	total: 3.85s	remaining: 4.48s
# 462:	learn: 0.4981727	total: 3.86s	remaining: 4.47s
# 463:	learn: 0.4981043	total: 3.87s	remaining: 4.47s
# 464:	learn: 0.4980575	total: 3.87s	remaining: 4.46s
# 465:	learn: 0.4980218	total: 3.88s	remaining: 4.45s
# 466:	learn: 0.4979732	total: 3.89s	remaining: 4.44s
# 467:	learn: 0.4979254	total: 3.9s	remaining: 4.43s
# 468:	learn: 0.4978595	total: 3.9s	remaining: 4.42s
# 469:	learn: 0.4977924	total: 3.91s	remaining: 4.41s
# 470:	learn: 0.4977414	total: 3.92s	remaining: 4.4s
# 471:	learn: 0.4976656	total: 3.92s	remaining: 4.39s
# 472:	learn: 0.4975481	total: 3.93s	remaining: 4.38s
# 473:	learn: 0.4975055	total: 3.94s	remaining: 4.37s
# 474:	learn: 0.4974140	total: 3.94s	remaining: 4.36s
# 475:	learn: 0.4972854	total: 3.95s	remaining: 4.35s
# 476:	learn: 0.4972118	total: 3.96s	remaining: 4.35s
# 477:	learn: 0.4971476	total: 3.98s	remaining: 4.34s
# 478:	learn: 0.4971277	total: 3.98s	remaining: 4.33s
# 479:	learn: 0.4970757	total: 4s	remaining: 4.33s
# 480:	learn: 0.4970274	total: 4s	remaining: 4.32s
# 481:	learn: 0.4968746	total: 4.01s	remaining: 4.31s
# 482:	learn: 0.4967868	total: 4.03s	remaining: 4.31s
# 483:	learn: 0.4967607	total: 4.03s	remaining: 4.3s
# 484:	learn: 0.4965861	total: 4.04s	remaining: 4.29s
# 485:	learn: 0.4965065	total: 4.06s	remaining: 4.29s
# 486:	learn: 0.4964605	total: 4.06s	remaining: 4.28s
# 487:	learn: 0.4963709	total: 4.08s	remaining: 4.28s
# 488:	learn: 0.4962458	total: 4.08s	remaining: 4.27s
# 489:	learn: 0.4960705	total: 4.09s	remaining: 4.26s
# 490:	learn: 0.4960156	total: 4.1s	remaining: 4.25s
# 491:	learn: 0.4959679	total: 4.11s	remaining: 4.24s
# 492:	learn: 0.4959089	total: 4.12s	remaining: 4.23s
# 493:	learn: 0.4958788	total: 4.12s	remaining: 4.22s
# 494:	learn: 0.4957740	total: 4.13s	remaining: 4.21s
# 495:	learn: 0.4957096	total: 4.14s	remaining: 4.21s
# 496:	learn: 0.4956707	total: 4.14s	remaining: 4.2s
# 497:	learn: 0.4956395	total: 4.15s	remaining: 4.19s
# 498:	learn: 0.4955941	total: 4.16s	remaining: 4.18s
# 499:	learn: 0.4954725	total: 4.17s	remaining: 4.17s
# 500:	learn: 0.4954196	total: 4.18s	remaining: 4.16s
# 501:	learn: 0.4953697	total: 4.18s	remaining: 4.15s
# 502:	learn: 0.4952788	total: 4.2s	remaining: 4.14s
# 503:	learn: 0.4952297	total: 4.2s	remaining: 4.14s
# 504:	learn: 0.4952041	total: 4.21s	remaining: 4.13s
# 505:	learn: 0.4951678	total: 4.22s	remaining: 4.12s
# 506:	learn: 0.4951491	total: 4.23s	remaining: 4.12s
# 507:	learn: 0.4950092	total: 4.24s	remaining: 4.11s
# 508:	learn: 0.4949846	total: 4.25s	remaining: 4.1s
# 509:	learn: 0.4949189	total: 4.26s	remaining: 4.09s
# 510:	learn: 0.4947884	total: 4.27s	remaining: 4.08s
# 511:	learn: 0.4947415	total: 4.28s	remaining: 4.08s
# 512:	learn: 0.4946971	total: 4.29s	remaining: 4.07s
# 513:	learn: 0.4945669	total: 4.3s	remaining: 4.06s
# 514:	learn: 0.4944599	total: 4.31s	remaining: 4.06s
# 515:	learn: 0.4943284	total: 4.32s	remaining: 4.05s
# 516:	learn: 0.4942977	total: 4.33s	remaining: 4.04s
# 517:	learn: 0.4942051	total: 4.33s	remaining: 4.03s
# 518:	learn: 0.4941734	total: 4.34s	remaining: 4.02s
# 519:	learn: 0.4941317	total: 4.35s	remaining: 4.01s
# 520:	learn: 0.4940611	total: 4.36s	remaining: 4.01s
# 521:	learn: 0.4939838	total: 4.37s	remaining: 4s
# 522:	learn: 0.4938770	total: 4.38s	remaining: 3.99s
# 523:	learn: 0.4937824	total: 4.39s	remaining: 3.99s
# 524:	learn: 0.4937229	total: 4.41s	remaining: 3.99s
# 525:	learn: 0.4936854	total: 4.42s	remaining: 3.98s
# 526:	learn: 0.4936580	total: 4.43s	remaining: 3.98s
# 527:	learn: 0.4936229	total: 4.44s	remaining: 3.97s
# 528:	learn: 0.4935570	total: 4.45s	remaining: 3.96s
# 529:	learn: 0.4934693	total: 4.45s	remaining: 3.95s
# 530:	learn: 0.4934032	total: 4.46s	remaining: 3.94s
# 531:	learn: 0.4933521	total: 4.47s	remaining: 3.93s
# 532:	learn: 0.4933002	total: 4.47s	remaining: 3.92s
# 533:	learn: 0.4931880	total: 4.48s	remaining: 3.91s
# 534:	learn: 0.4930542	total: 4.49s	remaining: 3.9s
# 535:	learn: 0.4930124	total: 4.5s	remaining: 3.9s
# 536:	learn: 0.4929649	total: 4.51s	remaining: 3.89s
# 537:	learn: 0.4928476	total: 4.52s	remaining: 3.88s
# 538:	learn: 0.4928038	total: 4.53s	remaining: 3.88s
# 539:	learn: 0.4927419	total: 4.54s	remaining: 3.87s
# 540:	learn: 0.4926600	total: 4.55s	remaining: 3.86s
# 541:	learn: 0.4925730	total: 4.57s	remaining: 3.86s
# 542:	learn: 0.4925299	total: 4.58s	remaining: 3.85s
# 543:	learn: 0.4924765	total: 4.58s	remaining: 3.84s
# 544:	learn: 0.4923881	total: 4.6s	remaining: 3.84s
# 545:	learn: 0.4923170	total: 4.62s	remaining: 3.84s
# 546:	learn: 0.4922790	total: 4.63s	remaining: 3.83s
# 547:	learn: 0.4922310	total: 4.63s	remaining: 3.82s
# 548:	learn: 0.4921990	total: 4.64s	remaining: 3.81s
# 549:	learn: 0.4921629	total: 4.65s	remaining: 3.81s
# 550:	learn: 0.4921171	total: 4.66s	remaining: 3.8s
# 551:	learn: 0.4920348	total: 4.67s	remaining: 3.79s
# 552:	learn: 0.4919924	total: 4.68s	remaining: 3.79s
# 553:	learn: 0.4918912	total: 4.7s	remaining: 3.78s
# 554:	learn: 0.4918514	total: 4.7s	remaining: 3.77s
# 555:	learn: 0.4917579	total: 4.72s	remaining: 3.77s
# 556:	learn: 0.4917037	total: 4.73s	remaining: 3.76s
# 557:	learn: 0.4917037	total: 4.73s	remaining: 3.75s
# 558:	learn: 0.4916557	total: 4.74s	remaining: 3.74s
# 559:	learn: 0.4916144	total: 4.75s	remaining: 3.73s
# 560:	learn: 0.4915813	total: 4.76s	remaining: 3.72s
# 561:	learn: 0.4915324	total: 4.77s	remaining: 3.71s
# 562:	learn: 0.4914831	total: 4.78s	remaining: 3.71s
# 563:	learn: 0.4914401	total: 4.78s	remaining: 3.7s
# 564:	learn: 0.4914029	total: 4.79s	remaining: 3.69s
# 565:	learn: 0.4913651	total: 4.8s	remaining: 3.68s
# 566:	learn: 0.4913100	total: 4.81s	remaining: 3.67s
# 567:	learn: 0.4911852	total: 4.81s	remaining: 3.66s
# 568:	learn: 0.4911485	total: 4.82s	remaining: 3.65s
# 569:	learn: 0.4911133	total: 4.83s	remaining: 3.64s
# 570:	learn: 0.4910175	total: 4.84s	remaining: 3.63s
# 571:	learn: 0.4909229	total: 4.84s	remaining: 3.63s
# 572:	learn: 0.4908734	total: 4.85s	remaining: 3.61s
# 573:	learn: 0.4908354	total: 4.86s	remaining: 3.61s
# 574:	learn: 0.4907809	total: 4.87s	remaining: 3.6s
# 575:	learn: 0.4907172	total: 4.88s	remaining: 3.59s
# 576:	learn: 0.4906454	total: 4.89s	remaining: 3.58s
# 577:	learn: 0.4906108	total: 4.9s	remaining: 3.58s
# 578:	learn: 0.4905473	total: 4.91s	remaining: 3.57s
# 579:	learn: 0.4905305	total: 4.92s	remaining: 3.56s
# 580:	learn: 0.4904857	total: 4.94s	remaining: 3.56s
# 581:	learn: 0.4903971	total: 4.95s	remaining: 3.56s
# 582:	learn: 0.4903507	total: 4.96s	remaining: 3.55s
# 583:	learn: 0.4902936	total: 4.97s	remaining: 3.54s
# 584:	learn: 0.4902218	total: 4.98s	remaining: 3.53s
# 585:	learn: 0.4901774	total: 4.99s	remaining: 3.52s
# 586:	learn: 0.4900984	total: 5s	remaining: 3.52s
# 587:	learn: 0.4900410	total: 5.01s	remaining: 3.51s
# 588:	learn: 0.4899547	total: 5.03s	remaining: 3.51s
# 589:	learn: 0.4899186	total: 5.04s	remaining: 3.5s
# 590:	learn: 0.4899027	total: 5.05s	remaining: 3.49s
# 591:	learn: 0.4898366	total: 5.06s	remaining: 3.49s
# 592:	learn: 0.4898304	total: 5.07s	remaining: 3.48s
# 593:	learn: 0.4897886	total: 5.08s	remaining: 3.47s
# 594:	learn: 0.4897303	total: 5.08s	remaining: 3.46s
# 595:	learn: 0.4896642	total: 5.09s	remaining: 3.45s
# 596:	learn: 0.4896222	total: 5.1s	remaining: 3.44s
# 597:	learn: 0.4895672	total: 5.11s	remaining: 3.43s
# 598:	learn: 0.4895045	total: 5.11s	remaining: 3.42s
# 599:	learn: 0.4893714	total: 5.12s	remaining: 3.41s
# 600:	learn: 0.4893015	total: 5.13s	remaining: 3.4s
# 601:	learn: 0.4892460	total: 5.14s	remaining: 3.4s
# 602:	learn: 0.4892116	total: 5.14s	remaining: 3.39s
# 603:	learn: 0.4891407	total: 5.15s	remaining: 3.38s
# 604:	learn: 0.4890375	total: 5.16s	remaining: 3.37s
# 605:	learn: 0.4889386	total: 5.17s	remaining: 3.36s
# 606:	learn: 0.4889167	total: 5.18s	remaining: 3.35s
# 607:	learn: 0.4888745	total: 5.18s	remaining: 3.34s
# 608:	learn: 0.4888525	total: 5.19s	remaining: 3.33s
# 609:	learn: 0.4888151	total: 5.2s	remaining: 3.32s
# 610:	learn: 0.4887119	total: 5.21s	remaining: 3.31s
# 611:	learn: 0.4886824	total: 5.21s	remaining: 3.31s
# 612:	learn: 0.4886255	total: 5.22s	remaining: 3.3s
# 613:	learn: 0.4885733	total: 5.23s	remaining: 3.29s
# 614:	learn: 0.4885385	total: 5.24s	remaining: 3.28s
# 615:	learn: 0.4884904	total: 5.25s	remaining: 3.27s
# 616:	learn: 0.4884692	total: 5.25s	remaining: 3.26s
# 617:	learn: 0.4884218	total: 5.26s	remaining: 3.25s
# 618:	learn: 0.4883437	total: 5.27s	remaining: 3.24s
# 619:	learn: 0.4883017	total: 5.27s	remaining: 3.23s
# 620:	learn: 0.4882732	total: 5.28s	remaining: 3.22s
# 621:	learn: 0.4882559	total: 5.29s	remaining: 3.21s
# 622:	learn: 0.4882317	total: 5.29s	remaining: 3.2s
# 623:	learn: 0.4881438	total: 5.3s	remaining: 3.19s
# 624:	learn: 0.4881183	total: 5.31s	remaining: 3.18s
# 625:	learn: 0.4880477	total: 5.31s	remaining: 3.17s
# 626:	learn: 0.4879701	total: 5.32s	remaining: 3.17s
# 627:	learn: 0.4879317	total: 5.33s	remaining: 3.16s
# 628:	learn: 0.4878701	total: 5.34s	remaining: 3.15s
# 629:	learn: 0.4878138	total: 5.35s	remaining: 3.14s
# 630:	learn: 0.4877899	total: 5.36s	remaining: 3.13s
# 631:	learn: 0.4877536	total: 5.37s	remaining: 3.12s
# 632:	learn: 0.4877242	total: 5.37s	remaining: 3.11s
# 633:	learn: 0.4876800	total: 5.38s	remaining: 3.11s
# 634:	learn: 0.4876785	total: 5.39s	remaining: 3.1s
# 635:	learn: 0.4876515	total: 5.39s	remaining: 3.09s
# 636:	learn: 0.4875940	total: 5.4s	remaining: 3.08s
# 637:	learn: 0.4875351	total: 5.41s	remaining: 3.07s
# 638:	learn: 0.4874783	total: 5.42s	remaining: 3.06s
# 639:	learn: 0.4874561	total: 5.42s	remaining: 3.05s
# 640:	learn: 0.4874114	total: 5.43s	remaining: 3.04s
# 641:	learn: 0.4873744	total: 5.44s	remaining: 3.03s
# 642:	learn: 0.4873312	total: 5.45s	remaining: 3.03s
# 643:	learn: 0.4872978	total: 5.46s	remaining: 3.02s
# 644:	learn: 0.4872463	total: 5.48s	remaining: 3.01s
# 645:	learn: 0.4871880	total: 5.48s	remaining: 3s
# 646:	learn: 0.4871422	total: 5.49s	remaining: 3s
# 647:	learn: 0.4870945	total: 5.5s	remaining: 2.99s
# 648:	learn: 0.4870648	total: 5.51s	remaining: 2.98s
# 649:	learn: 0.4870261	total: 5.51s	remaining: 2.97s
# 650:	learn: 0.4869498	total: 5.52s	remaining: 2.96s
# 651:	learn: 0.4869027	total: 5.53s	remaining: 2.95s
# 652:	learn: 0.4868839	total: 5.54s	remaining: 2.94s
# 653:	learn: 0.4868420	total: 5.54s	remaining: 2.93s
# 654:	learn: 0.4866735	total: 5.55s	remaining: 2.92s
# 655:	learn: 0.4866171	total: 5.56s	remaining: 2.92s
# 656:	learn: 0.4864865	total: 5.57s	remaining: 2.91s
# 657:	learn: 0.4864392	total: 5.58s	remaining: 2.9s
# 658:	learn: 0.4863871	total: 5.58s	remaining: 2.89s
# 659:	learn: 0.4863736	total: 5.59s	remaining: 2.88s
# 660:	learn: 0.4863152	total: 5.59s	remaining: 2.87s
# 661:	learn: 0.4862370	total: 5.6s	remaining: 2.86s
# 662:	learn: 0.4861934	total: 5.61s	remaining: 2.85s
# 663:	learn: 0.4861674	total: 5.62s	remaining: 2.84s
# 664:	learn: 0.4861320	total: 5.63s	remaining: 2.83s
# 665:	learn: 0.4860907	total: 5.63s	remaining: 2.82s
# 666:	learn: 0.4860711	total: 5.64s	remaining: 2.81s
# 667:	learn: 0.4859973	total: 5.65s	remaining: 2.81s
# 668:	learn: 0.4859967	total: 5.66s	remaining: 2.8s
# 669:	learn: 0.4859909	total: 5.66s	remaining: 2.79s
# 670:	learn: 0.4859549	total: 5.67s	remaining: 2.78s
# 671:	learn: 0.4858560	total: 5.68s	remaining: 2.77s
# 672:	learn: 0.4858269	total: 5.69s	remaining: 2.76s
# 673:	learn: 0.4858084	total: 5.7s	remaining: 2.75s
# 674:	learn: 0.4857649	total: 5.7s	remaining: 2.75s
# 675:	learn: 0.4857227	total: 5.71s	remaining: 2.74s
# 676:	learn: 0.4856195	total: 5.72s	remaining: 2.73s
# 677:	learn: 0.4855678	total: 5.73s	remaining: 2.72s
# 678:	learn: 0.4855096	total: 5.74s	remaining: 2.71s
# 679:	learn: 0.4854265	total: 5.75s	remaining: 2.71s
# 680:	learn: 0.4853896	total: 5.76s	remaining: 2.7s
# 681:	learn: 0.4853104	total: 5.78s	remaining: 2.69s
# 682:	learn: 0.4852254	total: 5.79s	remaining: 2.69s
# 683:	learn: 0.4852103	total: 5.8s	remaining: 2.68s
# 684:	learn: 0.4851361	total: 5.81s	remaining: 2.67s
# 685:	learn: 0.4850763	total: 5.82s	remaining: 2.66s
# 686:	learn: 0.4850377	total: 5.83s	remaining: 2.65s
# 687:	learn: 0.4849965	total: 5.84s	remaining: 2.65s
# 688:	learn: 0.4849476	total: 5.85s	remaining: 2.64s
# 689:	learn: 0.4849140	total: 5.86s	remaining: 2.63s
# 690:	learn: 0.4848783	total: 5.86s	remaining: 2.62s
# 691:	learn: 0.4848040	total: 5.87s	remaining: 2.61s
# 692:	learn: 0.4847650	total: 5.88s	remaining: 2.6s
# 693:	learn: 0.4847181	total: 5.89s	remaining: 2.6s
# 694:	learn: 0.4846290	total: 5.89s	remaining: 2.59s
# 695:	learn: 0.4846095	total: 5.9s	remaining: 2.58s
# 696:	learn: 0.4845672	total: 5.91s	remaining: 2.57s
# 697:	learn: 0.4845138	total: 5.92s	remaining: 2.56s
# 698:	learn: 0.4844188	total: 5.93s	remaining: 2.55s
# 699:	learn: 0.4843794	total: 5.93s	remaining: 2.54s
# 700:	learn: 0.4843458	total: 5.94s	remaining: 2.54s
# 701:	learn: 0.4843108	total: 5.95s	remaining: 2.53s
# 702:	learn: 0.4842717	total: 5.96s	remaining: 2.52s
# 703:	learn: 0.4842152	total: 5.96s	remaining: 2.51s
# 704:	learn: 0.4841842	total: 5.97s	remaining: 2.5s
# 705:	learn: 0.4841527	total: 5.98s	remaining: 2.49s
# 706:	learn: 0.4840943	total: 5.99s	remaining: 2.48s
# 707:	learn: 0.4840586	total: 5.99s	remaining: 2.47s
# 708:	learn: 0.4840017	total: 6s	remaining: 2.46s
# 709:	learn: 0.4839511	total: 6.01s	remaining: 2.46s
# 710:	learn: 0.4839147	total: 6.02s	remaining: 2.45s
# 711:	learn: 0.4838870	total: 6.03s	remaining: 2.44s
# 712:	learn: 0.4838294	total: 6.04s	remaining: 2.43s
# 713:	learn: 0.4837455	total: 6.05s	remaining: 2.42s
# 714:	learn: 0.4837173	total: 6.05s	remaining: 2.41s
# 715:	learn: 0.4836861	total: 6.06s	remaining: 2.4s
# 716:	learn: 0.4836345	total: 6.08s	remaining: 2.4s
# 717:	learn: 0.4835794	total: 6.09s	remaining: 2.39s
# 718:	learn: 0.4834860	total: 6.1s	remaining: 2.38s
# 719:	learn: 0.4834473	total: 6.11s	remaining: 2.38s
# 720:	learn: 0.4833448	total: 6.12s	remaining: 2.37s
# 721:	learn: 0.4833133	total: 6.13s	remaining: 2.36s
# 722:	learn: 0.4832775	total: 6.14s	remaining: 2.35s
# 723:	learn: 0.4832164	total: 6.15s	remaining: 2.34s
# 724:	learn: 0.4831930	total: 6.16s	remaining: 2.33s
# 725:	learn: 0.4830951	total: 6.16s	remaining: 2.33s
# 726:	learn: 0.4830663	total: 6.17s	remaining: 2.32s
# 727:	learn: 0.4830656	total: 6.18s	remaining: 2.31s
# 728:	learn: 0.4830456	total: 6.19s	remaining: 2.3s
# 729:	learn: 0.4830202	total: 6.19s	remaining: 2.29s
# 730:	learn: 0.4829896	total: 6.2s	remaining: 2.28s
# 731:	learn: 0.4829416	total: 6.21s	remaining: 2.27s
# 732:	learn: 0.4829070	total: 6.21s	remaining: 2.26s
# 733:	learn: 0.4828782	total: 6.22s	remaining: 2.25s
# 734:	learn: 0.4828446	total: 6.23s	remaining: 2.25s
# 735:	learn: 0.4827943	total: 6.24s	remaining: 2.24s
# 736:	learn: 0.4827705	total: 6.25s	remaining: 2.23s
# 737:	learn: 0.4827028	total: 6.26s	remaining: 2.22s
# 738:	learn: 0.4826663	total: 6.27s	remaining: 2.21s
# 739:	learn: 0.4826056	total: 6.28s	remaining: 2.21s
# 740:	learn: 0.4825881	total: 6.29s	remaining: 2.2s
# 741:	learn: 0.4825349	total: 6.3s	remaining: 2.19s
# 742:	learn: 0.4824849	total: 6.31s	remaining: 2.18s
# 743:	learn: 0.4824399	total: 6.32s	remaining: 2.17s
# 744:	learn: 0.4823442	total: 6.33s	remaining: 2.17s
# 745:	learn: 0.4822704	total: 6.34s	remaining: 2.16s
# 746:	learn: 0.4822218	total: 6.35s	remaining: 2.15s
# 747:	learn: 0.4821489	total: 6.36s	remaining: 2.14s
# 748:	learn: 0.4821024	total: 6.37s	remaining: 2.13s
# 749:	learn: 0.4820306	total: 6.38s	remaining: 2.13s
# 750:	learn: 0.4819776	total: 6.38s	remaining: 2.12s
# 751:	learn: 0.4819187	total: 6.39s	remaining: 2.11s
# 752:	learn: 0.4818925	total: 6.4s	remaining: 2.1s
# 753:	learn: 0.4818577	total: 6.41s	remaining: 2.09s
# 754:	learn: 0.4818209	total: 6.41s	remaining: 2.08s
# 755:	learn: 0.4817282	total: 6.42s	remaining: 2.07s
# 756:	learn: 0.4816700	total: 6.43s	remaining: 2.06s
# 757:	learn: 0.4816283	total: 6.44s	remaining: 2.06s
# 758:	learn: 0.4815810	total: 6.45s	remaining: 2.05s
# 759:	learn: 0.4815558	total: 6.45s	remaining: 2.04s
# 760:	learn: 0.4815423	total: 6.46s	remaining: 2.03s
# 761:	learn: 0.4815328	total: 6.46s	remaining: 2.02s
# 762:	learn: 0.4814986	total: 6.47s	remaining: 2.01s
# 763:	learn: 0.4814652	total: 6.48s	remaining: 2s
# 764:	learn: 0.4814112	total: 6.49s	remaining: 1.99s
# 765:	learn: 0.4813375	total: 6.49s	remaining: 1.98s
# 766:	learn: 0.4812828	total: 6.5s	remaining: 1.97s
# 767:	learn: 0.4811134	total: 6.51s	remaining: 1.97s
# 768:	learn: 0.4810637	total: 6.53s	remaining: 1.96s
# 769:	learn: 0.4810574	total: 6.54s	remaining: 1.95s
# 770:	learn: 0.4810251	total: 6.55s	remaining: 1.95s
# 771:	learn: 0.4810139	total: 6.56s	remaining: 1.94s
# 772:	learn: 0.4809742	total: 6.57s	remaining: 1.93s
# 773:	learn: 0.4809425	total: 6.59s	remaining: 1.92s
# 774:	learn: 0.4808889	total: 6.6s	remaining: 1.92s
# 775:	learn: 0.4808643	total: 6.61s	remaining: 1.91s
# 776:	learn: 0.4808358	total: 6.62s	remaining: 1.9s
# 777:	learn: 0.4808056	total: 6.63s	remaining: 1.89s
# 778:	learn: 0.4807087	total: 6.64s	remaining: 1.88s
# 779:	learn: 0.4806700	total: 6.64s	remaining: 1.87s
# 780:	learn: 0.4805725	total: 6.66s	remaining: 1.87s
# 781:	learn: 0.4805306	total: 6.67s	remaining: 1.86s
# 782:	learn: 0.4804793	total: 6.68s	remaining: 1.85s
# 783:	learn: 0.4804205	total: 6.69s	remaining: 1.84s
# 784:	learn: 0.4803743	total: 6.71s	remaining: 1.84s
# 785:	learn: 0.4803550	total: 6.72s	remaining: 1.83s
# 786:	learn: 0.4803405	total: 6.73s	remaining: 1.82s
# 787:	learn: 0.4802943	total: 6.74s	remaining: 1.81s
# 788:	learn: 0.4802614	total: 6.76s	remaining: 1.81s
# 789:	learn: 0.4802192	total: 6.76s	remaining: 1.8s
# 790:	learn: 0.4801705	total: 6.78s	remaining: 1.79s
# 791:	learn: 0.4801509	total: 6.79s	remaining: 1.78s
# 792:	learn: 0.4801006	total: 6.79s	remaining: 1.77s
# 793:	learn: 0.4800448	total: 6.8s	remaining: 1.76s
# 794:	learn: 0.4799548	total: 6.82s	remaining: 1.76s
# 795:	learn: 0.4799117	total: 6.83s	remaining: 1.75s
# 796:	learn: 0.4798837	total: 6.84s	remaining: 1.74s
# 797:	learn: 0.4798813	total: 6.85s	remaining: 1.73s
# 798:	learn: 0.4798420	total: 6.86s	remaining: 1.73s
# 799:	learn: 0.4798156	total: 6.87s	remaining: 1.72s
# 800:	learn: 0.4797919	total: 6.88s	remaining: 1.71s
# 801:	learn: 0.4797630	total: 6.89s	remaining: 1.7s
# 802:	learn: 0.4797487	total: 6.9s	remaining: 1.69s
# 803:	learn: 0.4797276	total: 6.91s	remaining: 1.68s
# 804:	learn: 0.4797008	total: 6.92s	remaining: 1.68s
# 805:	learn: 0.4796502	total: 6.93s	remaining: 1.67s
# 806:	learn: 0.4796102	total: 6.96s	remaining: 1.66s
# 807:	learn: 0.4795521	total: 6.97s	remaining: 1.66s
# 808:	learn: 0.4795208	total: 6.99s	remaining: 1.65s
# 809:	learn: 0.4793753	total: 7s	remaining: 1.64s
# 810:	learn: 0.4793521	total: 7.01s	remaining: 1.63s
# 811:	learn: 0.4793078	total: 7.02s	remaining: 1.63s
# 812:	learn: 0.4792808	total: 7.03s	remaining: 1.62s
# 813:	learn: 0.4792530	total: 7.05s	remaining: 1.61s
# 814:	learn: 0.4792377	total: 7.07s	remaining: 1.6s
# 815:	learn: 0.4791515	total: 7.08s	remaining: 1.6s
# 816:	learn: 0.4791325	total: 7.09s	remaining: 1.59s
# 817:	learn: 0.4790925	total: 7.09s	remaining: 1.58s
# 818:	learn: 0.4790490	total: 7.11s	remaining: 1.57s
# 819:	learn: 0.4790068	total: 7.13s	remaining: 1.56s
# 820:	learn: 0.4789785	total: 7.15s	remaining: 1.56s
# 821:	learn: 0.4789361	total: 7.16s	remaining: 1.55s
# 822:	learn: 0.4788981	total: 7.17s	remaining: 1.54s
# 823:	learn: 0.4788396	total: 7.19s	remaining: 1.54s
# 824:	learn: 0.4788084	total: 7.21s	remaining: 1.53s
# 825:	learn: 0.4787688	total: 7.23s	remaining: 1.52s
# 826:	learn: 0.4786827	total: 7.25s	remaining: 1.52s
# 827:	learn: 0.4786460	total: 7.27s	remaining: 1.51s
# 828:	learn: 0.4786108	total: 7.29s	remaining: 1.5s
# 829:	learn: 0.4785629	total: 7.31s	remaining: 1.5s
# 830:	learn: 0.4785315	total: 7.32s	remaining: 1.49s
# 831:	learn: 0.4784789	total: 7.34s	remaining: 1.48s
# 832:	learn: 0.4784428	total: 7.35s	remaining: 1.47s
# 833:	learn: 0.4784142	total: 7.36s	remaining: 1.47s
# 834:	learn: 0.4783980	total: 7.37s	remaining: 1.46s
# 835:	learn: 0.4783411	total: 7.38s	remaining: 1.45s
# 836:	learn: 0.4783177	total: 7.39s	remaining: 1.44s
# 837:	learn: 0.4782693	total: 7.4s	remaining: 1.43s
# 838:	learn: 0.4782396	total: 7.41s	remaining: 1.42s
# 839:	learn: 0.4782100	total: 7.41s	remaining: 1.41s
# 840:	learn: 0.4781686	total: 7.42s	remaining: 1.4s
# 841:	learn: 0.4781200	total: 7.42s	remaining: 1.39s
# 842:	learn: 0.4780764	total: 7.44s	remaining: 1.39s
# 843:	learn: 0.4780616	total: 7.44s	remaining: 1.38s
# 844:	learn: 0.4780463	total: 7.45s	remaining: 1.37s
# 845:	learn: 0.4779807	total: 7.46s	remaining: 1.36s
# 846:	learn: 0.4779572	total: 7.46s	remaining: 1.35s
# 847:	learn: 0.4779254	total: 7.47s	remaining: 1.34s
# 848:	learn: 0.4778826	total: 7.48s	remaining: 1.33s
# 849:	learn: 0.4778764	total: 7.49s	remaining: 1.32s
# 850:	learn: 0.4778280	total: 7.5s	remaining: 1.31s
# 851:	learn: 0.4777851	total: 7.5s	remaining: 1.3s
# 852:	learn: 0.4777404	total: 7.51s	remaining: 1.29s
# 853:	learn: 0.4777209	total: 7.52s	remaining: 1.29s
# 854:	learn: 0.4776823	total: 7.54s	remaining: 1.28s
# 855:	learn: 0.4776335	total: 7.55s	remaining: 1.27s
# 856:	learn: 0.4776074	total: 7.56s	remaining: 1.26s
# 857:	learn: 0.4775317	total: 7.58s	remaining: 1.25s
# 858:	learn: 0.4775012	total: 7.59s	remaining: 1.25s
# 859:	learn: 0.4774395	total: 7.6s	remaining: 1.24s
# 860:	learn: 0.4773974	total: 7.61s	remaining: 1.23s
# 861:	learn: 0.4773234	total: 7.62s	remaining: 1.22s
# 862:	learn: 0.4772832	total: 7.63s	remaining: 1.21s
# 863:	learn: 0.4772076	total: 7.64s	remaining: 1.2s
# 864:	learn: 0.4771880	total: 7.65s	remaining: 1.19s
# 865:	learn: 0.4771581	total: 7.67s	remaining: 1.19s
# 866:	learn: 0.4771233	total: 7.68s	remaining: 1.18s
# 867:	learn: 0.4770944	total: 7.69s	remaining: 1.17s
# 868:	learn: 0.4770721	total: 7.7s	remaining: 1.16s
# 869:	learn: 0.4770532	total: 7.71s	remaining: 1.15s
# 870:	learn: 0.4769940	total: 7.72s	remaining: 1.14s
# 871:	learn: 0.4769931	total: 7.73s	remaining: 1.14s
# 872:	learn: 0.4769573	total: 7.75s	remaining: 1.13s
# 873:	learn: 0.4769239	total: 7.77s	remaining: 1.12s
# 874:	learn: 0.4768845	total: 7.78s	remaining: 1.11s
# 875:	learn: 0.4768507	total: 7.79s	remaining: 1.1s
# 876:	learn: 0.4768380	total: 7.81s	remaining: 1.09s
# 877:	learn: 0.4768068	total: 7.82s	remaining: 1.09s
# 878:	learn: 0.4767603	total: 7.83s	remaining: 1.08s
# 879:	learn: 0.4767307	total: 7.84s	remaining: 1.07s
# 880:	learn: 0.4767092	total: 7.86s	remaining: 1.06s
# 881:	learn: 0.4766729	total: 7.87s	remaining: 1.05s
# 882:	learn: 0.4766445	total: 7.88s	remaining: 1.04s
# 883:	learn: 0.4765722	total: 7.88s	remaining: 1.03s
# 884:	learn: 0.4765332	total: 7.9s	remaining: 1.03s
# 885:	learn: 0.4764422	total: 7.91s	remaining: 1.02s
# 886:	learn: 0.4764088	total: 7.92s	remaining: 1.01s
# 887:	learn: 0.4763863	total: 7.93s	remaining: 1s
# 888:	learn: 0.4763484	total: 7.94s	remaining: 992ms
# 889:	learn: 0.4763174	total: 7.95s	remaining: 983ms
# 890:	learn: 0.4763001	total: 7.96s	remaining: 974ms
# 891:	learn: 0.4762235	total: 7.97s	remaining: 965ms
# 892:	learn: 0.4761958	total: 7.98s	remaining: 956ms
# 893:	learn: 0.4761507	total: 7.99s	remaining: 947ms
# 894:	learn: 0.4761277	total: 8s	remaining: 938ms
# 895:	learn: 0.4760885	total: 8.01s	remaining: 930ms
# 896:	learn: 0.4759965	total: 8.02s	remaining: 921ms
# 897:	learn: 0.4759751	total: 8.03s	remaining: 912ms
# 898:	learn: 0.4759565	total: 8.04s	remaining: 903ms
# 899:	learn: 0.4759291	total: 8.05s	remaining: 895ms
# 900:	learn: 0.4759041	total: 8.07s	remaining: 887ms
# 901:	learn: 0.4758748	total: 8.07s	remaining: 877ms
# 902:	learn: 0.4758454	total: 8.08s	remaining: 868ms
# 903:	learn: 0.4757396	total: 8.09s	remaining: 859ms
# 904:	learn: 0.4757240	total: 8.09s	remaining: 850ms
# 905:	learn: 0.4756601	total: 8.11s	remaining: 841ms
# 906:	learn: 0.4756371	total: 8.11s	remaining: 832ms
# 907:	learn: 0.4755574	total: 8.12s	remaining: 823ms
# 908:	learn: 0.4755304	total: 8.13s	remaining: 814ms
# 909:	learn: 0.4754875	total: 8.13s	remaining: 805ms
# 910:	learn: 0.4754685	total: 8.14s	remaining: 796ms
# 911:	learn: 0.4754389	total: 8.16s	remaining: 787ms
# 912:	learn: 0.4754055	total: 8.18s	remaining: 779ms
# 913:	learn: 0.4753679	total: 8.19s	remaining: 771ms
# 914:	learn: 0.4753027	total: 8.21s	remaining: 762ms
# 915:	learn: 0.4752485	total: 8.22s	remaining: 754ms
# 916:	learn: 0.4751925	total: 8.24s	remaining: 746ms
# 917:	learn: 0.4751536	total: 8.25s	remaining: 737ms
# 918:	learn: 0.4750877	total: 8.26s	remaining: 728ms
# 919:	learn: 0.4750600	total: 8.28s	remaining: 720ms
# 920:	learn: 0.4749968	total: 8.29s	remaining: 711ms
# 921:	learn: 0.4749341	total: 8.3s	remaining: 702ms
# 922:	learn: 0.4748987	total: 8.31s	remaining: 693ms
# 923:	learn: 0.4748882	total: 8.31s	remaining: 684ms
# 924:	learn: 0.4748565	total: 8.32s	remaining: 675ms
# 925:	learn: 0.4748284	total: 8.33s	remaining: 666ms
# 926:	learn: 0.4747748	total: 8.34s	remaining: 657ms
# 927:	learn: 0.4747258	total: 8.35s	remaining: 648ms
# 928:	learn: 0.4746591	total: 8.35s	remaining: 638ms
# 929:	learn: 0.4746238	total: 8.36s	remaining: 629ms
# 930:	learn: 0.4746009	total: 8.37s	remaining: 620ms
# 931:	learn: 0.4745755	total: 8.37s	remaining: 611ms
# 932:	learn: 0.4745337	total: 8.38s	remaining: 602ms
# 933:	learn: 0.4745036	total: 8.39s	remaining: 593ms
# 934:	learn: 0.4744753	total: 8.39s	remaining: 583ms
# 935:	learn: 0.4744452	total: 8.4s	remaining: 574ms
# 936:	learn: 0.4744055	total: 8.41s	remaining: 565ms
# 937:	learn: 0.4743467	total: 8.41s	remaining: 556ms
# 938:	learn: 0.4743217	total: 8.42s	remaining: 547ms
# 939:	learn: 0.4742807	total: 8.43s	remaining: 538ms
# 940:	learn: 0.4742674	total: 8.43s	remaining: 529ms
# 941:	learn: 0.4742389	total: 8.44s	remaining: 520ms
# 942:	learn: 0.4742175	total: 8.45s	remaining: 511ms
# 943:	learn: 0.4741820	total: 8.46s	remaining: 502ms
# 944:	learn: 0.4741409	total: 8.46s	remaining: 493ms
# 945:	learn: 0.4741139	total: 8.47s	remaining: 483ms
# 946:	learn: 0.4740943	total: 8.47s	remaining: 474ms
# 947:	learn: 0.4740768	total: 8.48s	remaining: 465ms
# 948:	learn: 0.4740047	total: 8.49s	remaining: 456ms
# 949:	learn: 0.4739516	total: 8.49s	remaining: 447ms
# 950:	learn: 0.4739210	total: 8.51s	remaining: 438ms
# 951:	learn: 0.4738995	total: 8.52s	remaining: 429ms
# 952:	learn: 0.4738096	total: 8.53s	remaining: 420ms
# 953:	learn: 0.4737696	total: 8.53s	remaining: 411ms
# 954:	learn: 0.4737504	total: 8.54s	remaining: 402ms
# 955:	learn: 0.4737235	total: 8.54s	remaining: 393ms
# 956:	learn: 0.4736892	total: 8.55s	remaining: 384ms
# 957:	learn: 0.4736867	total: 8.56s	remaining: 375ms
# 958:	learn: 0.4736645	total: 8.57s	remaining: 366ms
# 959:	learn: 0.4735884	total: 8.57s	remaining: 357ms
# 960:	learn: 0.4735482	total: 8.58s	remaining: 348ms
# 961:	learn: 0.4735110	total: 8.59s	remaining: 339ms
# 962:	learn: 0.4734393	total: 8.59s	remaining: 330ms
# 963:	learn: 0.4734116	total: 8.6s	remaining: 321ms
# 964:	learn: 0.4733447	total: 8.61s	remaining: 312ms
# 965:	learn: 0.4733146	total: 8.62s	remaining: 303ms
# 966:	learn: 0.4732818	total: 8.63s	remaining: 294ms
# 967:	learn: 0.4732478	total: 8.63s	remaining: 285ms
# 968:	learn: 0.4732197	total: 8.65s	remaining: 277ms
# 969:	learn: 0.4731955	total: 8.66s	remaining: 268ms
# 970:	learn: 0.4731593	total: 8.67s	remaining: 259ms
# 971:	learn: 0.4730741	total: 8.68s	remaining: 250ms
# 972:	learn: 0.4730208	total: 8.69s	remaining: 241ms
# 973:	learn: 0.4729821	total: 8.7s	remaining: 232ms
# 974:	learn: 0.4729606	total: 8.7s	remaining: 223ms
# 975:	learn: 0.4729264	total: 8.71s	remaining: 214ms
# 976:	learn: 0.4728781	total: 8.72s	remaining: 205ms
# 977:	learn: 0.4728257	total: 8.73s	remaining: 196ms
# 978:	learn: 0.4727920	total: 8.74s	remaining: 187ms
# 979:	learn: 0.4727737	total: 8.75s	remaining: 179ms
# 980:	learn: 0.4727311	total: 8.76s	remaining: 170ms
# 981:	learn: 0.4726818	total: 8.76s	remaining: 161ms
# 982:	learn: 0.4726612	total: 8.77s	remaining: 152ms
# 983:	learn: 0.4726446	total: 8.77s	remaining: 143ms
# 984:	learn: 0.4726251	total: 8.78s	remaining: 134ms
# 985:	learn: 0.4725853	total: 8.79s	remaining: 125ms
# 986:	learn: 0.4725666	total: 8.79s	remaining: 116ms
# 987:	learn: 0.4725352	total: 8.8s	remaining: 107ms
# 988:	learn: 0.4724765	total: 8.81s	remaining: 98ms
# 989:	learn: 0.4724369	total: 8.82s	remaining: 89.1ms
# 990:	learn: 0.4724145	total: 8.83s	remaining: 80.2ms
# 991:	learn: 0.4723792	total: 8.84s	remaining: 71.3ms
# 992:	learn: 0.4723428	total: 8.85s	remaining: 62.4ms
# 993:	learn: 0.4722982	total: 8.86s	remaining: 53.5ms
# 994:	learn: 0.4722835	total: 8.87s	remaining: 44.6ms
# 995:	learn: 0.4722785	total: 8.87s	remaining: 35.6ms
# 996:	learn: 0.4722584	total: 8.88s	remaining: 26.7ms
# 997:	learn: 0.4722266	total: 8.89s	remaining: 17.8ms
# 998:	learn: 0.4721700	total: 8.9s	remaining: 8.91ms
# 999:	learn: 0.4721429	total: 8.91s	remaining: 0us
# 2025/07/22 13:46:29 WARNING mlflow.utils.autologging_utils: MLflow autologging encountered a warning: "/home/edyn/Documentos/obsidian-doc/Projects/MachineLearningEngineer/Curso2/Proyecto/Repo/ml2_class4_mlsupervisadoavanzado/.venv/lib/python3.12/site-packages/mlflow/types/utils.py:452: UserWarning: Hint: Inferred schema contains integer column(s). Integer columns in Python cannot represent missing values. If your input data contains missing values at inference time, it will be encoded as floats and will cause a schema enforcement error. The best way to avoid this problem is to infer the model schema based on a realistic data sample (training dataset) that includes missing values. Alternatively, you can declare integer columns as doubles (float64) whenever these columns may have missing values. See `Handling Integers With Missing Values <https://www.mlflow.org/docs/latest/models.html#handling-integers-with-missing-values>`_ for more details."
# 2025/07/22 13:46:37 WARNING mlflow.utils.autologging_utils: MLflow autologging encountered a warning: "/home/edyn/Documentos/obsidian-doc/Projects/MachineLearningEngineer/Curso2/Proyecto/Repo/ml2_class4_mlsupervisadoavanzado/.venv/lib/python3.12/site-packages/mlflow/types/utils.py:452: UserWarning: Hint: Inferred schema contains integer column(s). Integer columns in Python cannot represent missing values. If your input data contains missing values at inference time, it will be encoded as floats and will cause a schema enforcement error. The best way to avoid this problem is to infer the model schema based on a realistic data sample (training dataset) that includes missing values. Alternatively, you can declare integer columns as doubles (float64) whenever these columns may have missing values. See `Handling Integers With Missing Values <https://www.mlflow.org/docs/latest/models.html#handling-integers-with-missing-values>`_ for more details."
# 🏃 View run CatBoost at: https://dagshub.com/edynsoncoronado/ml_supervisado_avanzado.mlflow/#/experiments/1/runs/8b546e07ce8b4964acefe81bfb27e228
# 🧪 View experiment at: https://dagshub.com/edynsoncoronado/ml_supervisado_avanzado.mlflow/#/experiments/1

# %% [markdown]
# # Ensamble 7: Stacking

# %%
# Inicia una nueva ejecución de MLflow con el nombre "Ensamble de Pilas"
with mlflow.start_run(run_name="Ensamble de Pilas") as run:
    
    # Crea una instancia del clasificador CatBoost
    algorithm1 = CatBoostClassifier()
    # Crea una instancia del clasificador XGBoost
    algorithm2 = XGBClassifier()
    # Crea una instancia del clasificador LightGBM
    algorithm3 = LGBMClassifier()

    # Define el clasificador de ensamble Stacking, usando los tres modelos anteriores como base
    # y RandomForestClassifier como estimador final
    stacking_clf = StackingClassifier(
        estimators=[
            ("catboost", algorithm1),  # Primer modelo base: CatBoost
            ("xgb", algorithm2),       # Segundo modelo base: XGBoost
            ("lgbm", algorithm3),      # Tercer modelo base: LightGBM
        ],
        final_estimator=RandomForestClassifier()  # Modelo final: Random Forest
    )
    # Define un pipeline que primero imputa valores faltantes y luego aplica el clasificador Stacking
    pipeline = Pipeline(
        steps=[
            ("imputer", SimpleImputer(strategy="mean")),  # Imputa valores faltantes usando la media
            ("staking", stacking_clf)                     # Aplica el modelo Stacking
        ]
    )
    # Ajusta el pipeline con los datos de entrenamiento
    pipeline.fit(X_train, y_train)

    # Realiza predicciones sobre el conjunto de prueba
    predictions = pipeline.predict(X_test)

    # Calcula la métrica de exactitud (accuracy) usando las etiquetas verdaderas y las predichas
    _accuracy_score = accuracy_score(y_test, predictions)
    # Calcula la métrica F1 usando las etiquetas verdaderas y las predichas
    _f1_score = f1_score(y_test, predictions)
    
    # Registra las métricas calculadas en MLflow
    mlflow.log_metrics(
        {
            "accuracy": _accuracy_score,
            "f1": _f1_score
        }   
    )
# Out:
# 2025/07/22 13:47:50 WARNING mlflow.utils.autologging_utils: MLflow autologging encountered a warning: "/home/edyn/Documentos/obsidian-doc/Projects/MachineLearningEngineer/Curso2/Proyecto/Repo/ml2_class4_mlsupervisadoavanzado/.venv/lib/python3.12/site-packages/mlflow/types/utils.py:452: UserWarning: Hint: Inferred schema contains integer column(s). Integer columns in Python cannot represent missing values. If your input data contains missing values at inference time, it will be encoded as floats and will cause a schema enforcement error. The best way to avoid this problem is to infer the model schema based on a realistic data sample (training dataset) that includes missing values. Alternatively, you can declare integer columns as doubles (float64) whenever these columns may have missing values. See `Handling Integers With Missing Values <https://www.mlflow.org/docs/latest/models.html#handling-integers-with-missing-values>`_ for more details."
# Learning rate set to 0.070218
# 0:	learn: 0.6738091	total: 7.09ms	remaining: 7.08s
# 1:	learn: 0.6577196	total: 11.8ms	remaining: 5.88s
# 2:	learn: 0.6435688	total: 18.6ms	remaining: 6.17s
# 3:	learn: 0.6321461	total: 24.2ms	remaining: 6.02s
# 4:	learn: 0.6222567	total: 30.4ms	remaining: 6.04s
# 5:	learn: 0.6132893	total: 38ms	remaining: 6.29s
# 6:	learn: 0.6055982	total: 43.3ms	remaining: 6.14s
# 7:	learn: 0.5995170	total: 50.1ms	remaining: 6.22s
# 8:	learn: 0.5937286	total: 55.7ms	remaining: 6.13s
# 9:	learn: 0.5890019	total: 61.9ms	remaining: 6.13s
# 10:	learn: 0.5846239	total: 66.9ms	remaining: 6.02s
# 11:	learn: 0.5811667	total: 72.4ms	remaining: 5.96s
# 12:	learn: 0.5778450	total: 78.6ms	remaining: 5.97s
# 13:	learn: 0.5752667	total: 86.6ms	remaining: 6.1s
# 14:	learn: 0.5728444	total: 94ms	remaining: 6.17s
# 15:	learn: 0.5706692	total: 102ms	remaining: 6.26s
# 16:	learn: 0.5687932	total: 108ms	remaining: 6.26s
# 17:	learn: 0.5673718	total: 115ms	remaining: 6.27s
# 18:	learn: 0.5658373	total: 121ms	remaining: 6.25s
# 19:	learn: 0.5646682	total: 127ms	remaining: 6.24s
# 20:	learn: 0.5634752	total: 134ms	remaining: 6.23s
# 21:	learn: 0.5625968	total: 139ms	remaining: 6.17s
# 22:	learn: 0.5617194	total: 148ms	remaining: 6.31s
# 23:	learn: 0.5603407	total: 154ms	remaining: 6.27s
# 24:	learn: 0.5595529	total: 161ms	remaining: 6.29s
# 25:	learn: 0.5589838	total: 168ms	remaining: 6.28s
# 26:	learn: 0.5578744	total: 174ms	remaining: 6.26s
# 27:	learn: 0.5574359	total: 180ms	remaining: 6.25s
# 28:	learn: 0.5563687	total: 186ms	remaining: 6.24s
# 29:	learn: 0.5555224	total: 196ms	remaining: 6.34s
# 30:	learn: 0.5547934	total: 203ms	remaining: 6.35s
# 31:	learn: 0.5539811	total: 211ms	remaining: 6.37s
# 32:	learn: 0.5534522	total: 220ms	remaining: 6.43s
# 33:	learn: 0.5529575	total: 229ms	remaining: 6.49s
# 34:	learn: 0.5525878	total: 235ms	remaining: 6.48s
# 35:	learn: 0.5522278	total: 244ms	remaining: 6.52s
# 36:	learn: 0.5518975	total: 252ms	remaining: 6.56s
# 37:	learn: 0.5514938	total: 259ms	remaining: 6.55s
# 38:	learn: 0.5509941	total: 270ms	remaining: 6.64s
# 39:	learn: 0.5507952	total: 275ms	remaining: 6.61s
# 40:	learn: 0.5502762	total: 285ms	remaining: 6.68s
# 41:	learn: 0.5500638	total: 292ms	remaining: 6.65s
# 42:	learn: 0.5494699	total: 297ms	remaining: 6.62s
# 43:	learn: 0.5493196	total: 305ms	remaining: 6.62s
# 44:	learn: 0.5489611	total: 312ms	remaining: 6.63s
# 45:	learn: 0.5484715	total: 318ms	remaining: 6.6s
# 46:	learn: 0.5481746	total: 324ms	remaining: 6.58s
# 47:	learn: 0.5479264	total: 331ms	remaining: 6.57s
# 48:	learn: 0.5476823	total: 339ms	remaining: 6.57s
# 49:	learn: 0.5474421	total: 344ms	remaining: 6.54s
# 50:	learn: 0.5472060	total: 351ms	remaining: 6.53s
# 51:	learn: 0.5468837	total: 357ms	remaining: 6.5s
# 52:	learn: 0.5463759	total: 363ms	remaining: 6.49s
# 53:	learn: 0.5460722	total: 369ms	remaining: 6.47s
# 54:	learn: 0.5459709	total: 378ms	remaining: 6.49s
# 55:	learn: 0.5455037	total: 384ms	remaining: 6.47s
# 56:	learn: 0.5450632	total: 391ms	remaining: 6.46s
# 57:	learn: 0.5449021	total: 397ms	remaining: 6.44s
# 58:	learn: 0.5447871	total: 404ms	remaining: 6.45s
# 59:	learn: 0.5445962	total: 411ms	remaining: 6.44s
# 60:	learn: 0.5444582	total: 417ms	remaining: 6.42s
# 61:	learn: 0.5439663	total: 426ms	remaining: 6.44s
# 62:	learn: 0.5437579	total: 435ms	remaining: 6.47s
# 63:	learn: 0.5434623	total: 441ms	remaining: 6.44s
# 64:	learn: 0.5431449	total: 449ms	remaining: 6.45s
# 65:	learn: 0.5428683	total: 456ms	remaining: 6.45s
# 66:	learn: 0.5427729	total: 463ms	remaining: 6.45s
# 67:	learn: 0.5427015	total: 469ms	remaining: 6.43s
# 68:	learn: 0.5424063	total: 476ms	remaining: 6.42s
# 69:	learn: 0.5422560	total: 484ms	remaining: 6.43s
# 70:	learn: 0.5419692	total: 491ms	remaining: 6.42s
# 71:	learn: 0.5418715	total: 497ms	remaining: 6.4s
# 72:	learn: 0.5417152	total: 504ms	remaining: 6.4s
# 73:	learn: 0.5413805	total: 510ms	remaining: 6.38s
# 74:	learn: 0.5411410	total: 515ms	remaining: 6.36s
# 75:	learn: 0.5408846	total: 523ms	remaining: 6.36s
# 76:	learn: 0.5405545	total: 528ms	remaining: 6.33s
# 77:	learn: 0.5401894	total: 535ms	remaining: 6.32s
# 78:	learn: 0.5401504	total: 541ms	remaining: 6.3s
# 79:	learn: 0.5400497	total: 551ms	remaining: 6.33s
# 80:	learn: 0.5399743	total: 556ms	remaining: 6.31s
# 81:	learn: 0.5398184	total: 563ms	remaining: 6.3s
# 82:	learn: 0.5395765	total: 574ms	remaining: 6.34s
# 83:	learn: 0.5392679	total: 584ms	remaining: 6.37s
# 84:	learn: 0.5390865	total: 590ms	remaining: 6.35s
# 85:	learn: 0.5386677	total: 598ms	remaining: 6.36s
# 86:	learn: 0.5385269	total: 607ms	remaining: 6.37s
# 87:	learn: 0.5382655	total: 614ms	remaining: 6.37s
# 88:	learn: 0.5381127	total: 620ms	remaining: 6.35s
# 89:	learn: 0.5378263	total: 627ms	remaining: 6.34s
# 90:	learn: 0.5376093	total: 633ms	remaining: 6.32s
# 91:	learn: 0.5373396	total: 641ms	remaining: 6.33s
# 92:	learn: 0.5371846	total: 648ms	remaining: 6.32s
# 93:	learn: 0.5371293	total: 655ms	remaining: 6.31s
# 94:	learn: 0.5370116	total: 663ms	remaining: 6.31s
# 95:	learn: 0.5367793	total: 670ms	remaining: 6.31s
# 96:	learn: 0.5366387	total: 676ms	remaining: 6.29s
# 97:	learn: 0.5363829	total: 682ms	remaining: 6.28s
# 98:	learn: 0.5362807	total: 689ms	remaining: 6.27s
# 99:	learn: 0.5361594	total: 695ms	remaining: 6.26s
# 100:	learn: 0.5360774	total: 702ms	remaining: 6.25s
# 101:	learn: 0.5359789	total: 708ms	remaining: 6.23s
# 102:	learn: 0.5358153	total: 713ms	remaining: 6.21s
# 103:	learn: 0.5356398	total: 720ms	remaining: 6.2s
# 104:	learn: 0.5354815	total: 726ms	remaining: 6.19s
# 105:	learn: 0.5352540	total: 733ms	remaining: 6.18s
# 106:	learn: 0.5351598	total: 738ms	remaining: 6.16s
# 107:	learn: 0.5351231	total: 744ms	remaining: 6.14s
# 108:	learn: 0.5350739	total: 750ms	remaining: 6.13s
# 109:	learn: 0.5349222	total: 758ms	remaining: 6.13s
# 110:	learn: 0.5347762	total: 766ms	remaining: 6.14s
# 111:	learn: 0.5345218	total: 773ms	remaining: 6.13s
# 112:	learn: 0.5344764	total: 778ms	remaining: 6.11s
# 113:	learn: 0.5344258	total: 786ms	remaining: 6.11s
# 114:	learn: 0.5344049	total: 792ms	remaining: 6.09s
# 115:	learn: 0.5343385	total: 799ms	remaining: 6.09s
# 116:	learn: 0.5342430	total: 805ms	remaining: 6.07s
# 117:	learn: 0.5341841	total: 811ms	remaining: 6.06s
# 118:	learn: 0.5340791	total: 818ms	remaining: 6.05s
# 119:	learn: 0.5338623	total: 825ms	remaining: 6.05s
# 120:	learn: 0.5337191	total: 834ms	remaining: 6.06s
# 121:	learn: 0.5334027	total: 840ms	remaining: 6.05s
# 122:	learn: 0.5331806	total: 848ms	remaining: 6.05s
# 123:	learn: 0.5330272	total: 854ms	remaining: 6.04s
# 124:	learn: 0.5329142	total: 863ms	remaining: 6.04s
# 125:	learn: 0.5327357	total: 869ms	remaining: 6.03s
# 126:	learn: 0.5326471	total: 876ms	remaining: 6.02s
# 127:	learn: 0.5325645	total: 887ms	remaining: 6.04s
# 128:	learn: 0.5324515	total: 896ms	remaining: 6.05s
# 129:	learn: 0.5324019	total: 903ms	remaining: 6.04s
# 130:	learn: 0.5321295	total: 910ms	remaining: 6.04s
# 131:	learn: 0.5320616	total: 917ms	remaining: 6.03s
# 132:	learn: 0.5317878	total: 924ms	remaining: 6.03s
# 133:	learn: 0.5317633	total: 930ms	remaining: 6.01s
# 134:	learn: 0.5315552	total: 937ms	remaining: 6s
# 135:	learn: 0.5315382	total: 944ms	remaining: 6s
# 136:	learn: 0.5312897	total: 950ms	remaining: 5.98s
# 137:	learn: 0.5311512	total: 956ms	remaining: 5.97s
# 138:	learn: 0.5310911	total: 964ms	remaining: 5.97s
# 139:	learn: 0.5309502	total: 973ms	remaining: 5.98s
# 140:	learn: 0.5308071	total: 990ms	remaining: 6.03s
# 141:	learn: 0.5307255	total: 1s	remaining: 6.07s
# 142:	learn: 0.5306572	total: 1.01s	remaining: 6.06s
# 143:	learn: 0.5304292	total: 1.02s	remaining: 6.05s
# 144:	learn: 0.5303169	total: 1.02s	remaining: 6.05s
# 145:	learn: 0.5301340	total: 1.03s	remaining: 6.03s
# 146:	learn: 0.5300460	total: 1.04s	remaining: 6.03s
# 147:	learn: 0.5298032	total: 1.04s	remaining: 6.02s
# 148:	learn: 0.5297653	total: 1.05s	remaining: 6.01s
# 149:	learn: 0.5296789	total: 1.06s	remaining: 6s
# 150:	learn: 0.5295721	total: 1.07s	remaining: 6s
# 151:	learn: 0.5295068	total: 1.07s	remaining: 5.98s
# 152:	learn: 0.5294477	total: 1.08s	remaining: 5.98s
# 153:	learn: 0.5293559	total: 1.09s	remaining: 5.97s
# 154:	learn: 0.5293085	total: 1.09s	remaining: 5.96s
# 155:	learn: 0.5292371	total: 1.1s	remaining: 5.95s
# 156:	learn: 0.5291776	total: 1.11s	remaining: 5.94s
# 157:	learn: 0.5291337	total: 1.12s	remaining: 5.95s
# 158:	learn: 0.5289750	total: 1.13s	remaining: 5.97s
# 159:	learn: 0.5287439	total: 1.14s	remaining: 5.98s
# 160:	learn: 0.5284720	total: 1.15s	remaining: 6s
# 161:	learn: 0.5283536	total: 1.16s	remaining: 6.01s
# 162:	learn: 0.5282082	total: 1.17s	remaining: 6s
# 163:	learn: 0.5281411	total: 1.18s	remaining: 5.99s
# 164:	learn: 0.5280409	total: 1.18s	remaining: 5.99s
# 165:	learn: 0.5278632	total: 1.19s	remaining: 5.98s
# 166:	learn: 0.5278181	total: 1.2s	remaining: 5.97s
# 167:	learn: 0.5276296	total: 1.2s	remaining: 5.96s
# 168:	learn: 0.5275481	total: 1.21s	remaining: 5.97s
# 169:	learn: 0.5273079	total: 1.22s	remaining: 5.96s
# 170:	learn: 0.5270704	total: 1.23s	remaining: 5.96s
# 171:	learn: 0.5268535	total: 1.23s	remaining: 5.94s
# 172:	learn: 0.5267480	total: 1.24s	remaining: 5.94s
# 173:	learn: 0.5266670	total: 1.25s	remaining: 5.93s
# 174:	learn: 0.5266142	total: 1.25s	remaining: 5.92s
# 175:	learn: 0.5264349	total: 1.26s	remaining: 5.91s
# 176:	learn: 0.5262728	total: 1.27s	remaining: 5.9s
# 177:	learn: 0.5260840	total: 1.28s	remaining: 5.89s
# 178:	learn: 0.5259459	total: 1.28s	remaining: 5.89s
# 179:	learn: 0.5258721	total: 1.29s	remaining: 5.88s
# 180:	learn: 0.5258008	total: 1.3s	remaining: 5.87s
# 181:	learn: 0.5257314	total: 1.3s	remaining: 5.87s
# 182:	learn: 0.5256839	total: 1.31s	remaining: 5.85s
# 183:	learn: 0.5255035	total: 1.32s	remaining: 5.86s
# 184:	learn: 0.5254140	total: 1.33s	remaining: 5.86s
# 185:	learn: 0.5253148	total: 1.34s	remaining: 5.86s
# 186:	learn: 0.5251390	total: 1.34s	remaining: 5.85s
# 187:	learn: 0.5250636	total: 1.35s	remaining: 5.84s
# 188:	learn: 0.5248768	total: 1.36s	remaining: 5.83s
# 189:	learn: 0.5247201	total: 1.37s	remaining: 5.84s
# 190:	learn: 0.5246463	total: 1.38s	remaining: 5.83s
# 191:	learn: 0.5244814	total: 1.38s	remaining: 5.83s
# 192:	learn: 0.5242867	total: 1.39s	remaining: 5.81s
# 193:	learn: 0.5241889	total: 1.4s	remaining: 5.8s
# 194:	learn: 0.5241018	total: 1.4s	remaining: 5.79s
# 195:	learn: 0.5240168	total: 1.41s	remaining: 5.78s
# 196:	learn: 0.5237648	total: 1.42s	remaining: 5.77s
# 197:	learn: 0.5237094	total: 1.42s	remaining: 5.76s
# 198:	learn: 0.5236287	total: 1.44s	remaining: 5.78s
# 199:	learn: 0.5235044	total: 1.44s	remaining: 5.76s
# 200:	learn: 0.5233885	total: 1.45s	remaining: 5.75s
# 201:	learn: 0.5231854	total: 1.45s	remaining: 5.74s
# 202:	learn: 0.5229853	total: 1.46s	remaining: 5.73s
# 203:	learn: 0.5228315	total: 1.47s	remaining: 5.73s
# 204:	learn: 0.5226548	total: 1.47s	remaining: 5.72s
# 205:	learn: 0.5225193	total: 1.48s	remaining: 5.71s
# 206:	learn: 0.5224484	total: 1.49s	remaining: 5.7s
# 207:	learn: 0.5222655	total: 1.5s	remaining: 5.69s
# 208:	learn: 0.5220643	total: 1.5s	remaining: 5.68s
# 209:	learn: 0.5219125	total: 1.51s	remaining: 5.68s
# 210:	learn: 0.5218701	total: 1.52s	remaining: 5.67s
# 211:	learn: 0.5217195	total: 1.52s	remaining: 5.66s
# 212:	learn: 0.5215435	total: 1.53s	remaining: 5.65s
# 213:	learn: 0.5214770	total: 1.54s	remaining: 5.64s
# 214:	learn: 0.5212733	total: 1.55s	remaining: 5.65s
# 215:	learn: 0.5211149	total: 1.56s	remaining: 5.66s
# 216:	learn: 0.5208956	total: 1.57s	remaining: 5.67s
# 217:	learn: 0.5207642	total: 1.58s	remaining: 5.68s
# 218:	learn: 0.5206847	total: 1.59s	remaining: 5.67s
# 219:	learn: 0.5205855	total: 1.6s	remaining: 5.67s
# 220:	learn: 0.5205229	total: 1.6s	remaining: 5.66s
# 221:	learn: 0.5204361	total: 1.61s	remaining: 5.66s
# 222:	learn: 0.5203395	total: 1.62s	remaining: 5.66s
# 223:	learn: 0.5202072	total: 1.63s	remaining: 5.65s
# 224:	learn: 0.5201336	total: 1.65s	remaining: 5.67s
# 225:	learn: 0.5199994	total: 1.66s	remaining: 5.67s
# 226:	learn: 0.5197615	total: 1.67s	remaining: 5.67s
# 227:	learn: 0.5195919	total: 1.67s	remaining: 5.66s
# 228:	learn: 0.5194573	total: 1.68s	remaining: 5.65s
# 229:	learn: 0.5193540	total: 1.69s	remaining: 5.64s
# 230:	learn: 0.5192622	total: 1.69s	remaining: 5.63s
# 231:	learn: 0.5191694	total: 1.7s	remaining: 5.63s
# 232:	learn: 0.5190966	total: 1.71s	remaining: 5.62s
# 233:	learn: 0.5189914	total: 1.72s	remaining: 5.63s
# 234:	learn: 0.5188320	total: 1.73s	remaining: 5.63s
# 235:	learn: 0.5187097	total: 1.73s	remaining: 5.62s
# 236:	learn: 0.5184611	total: 1.74s	remaining: 5.61s
# 237:	learn: 0.5184044	total: 1.75s	remaining: 5.6s
# 238:	learn: 0.5182942	total: 1.76s	remaining: 5.59s
# 239:	learn: 0.5181636	total: 1.76s	remaining: 5.58s
# 240:	learn: 0.5181083	total: 1.77s	remaining: 5.58s
# 241:	learn: 0.5179976	total: 1.78s	remaining: 5.57s
# 242:	learn: 0.5178847	total: 1.78s	remaining: 5.56s
# 243:	learn: 0.5176583	total: 1.79s	remaining: 5.55s
# 244:	learn: 0.5175738	total: 1.8s	remaining: 5.54s
# 245:	learn: 0.5173974	total: 1.8s	remaining: 5.53s
# 246:	learn: 0.5173137	total: 1.81s	remaining: 5.52s
# 247:	learn: 0.5172291	total: 1.82s	remaining: 5.51s
# 248:	learn: 0.5171755	total: 1.82s	remaining: 5.5s
# 249:	learn: 0.5170468	total: 1.83s	remaining: 5.5s
# 250:	learn: 0.5170072	total: 1.84s	remaining: 5.48s
# 251:	learn: 0.5168255	total: 1.84s	remaining: 5.48s
# 252:	learn: 0.5167291	total: 1.85s	remaining: 5.47s
# 253:	learn: 0.5166623	total: 1.86s	remaining: 5.46s
# 254:	learn: 0.5165749	total: 1.87s	remaining: 5.45s
# 255:	learn: 0.5164671	total: 1.88s	remaining: 5.45s
# 256:	learn: 0.5163888	total: 1.88s	remaining: 5.44s
# 257:	learn: 0.5163399	total: 1.89s	remaining: 5.43s
# 258:	learn: 0.5162075	total: 1.89s	remaining: 5.42s
# 259:	learn: 0.5161405	total: 1.9s	remaining: 5.41s
# 260:	learn: 0.5159468	total: 1.91s	remaining: 5.4s
# 261:	learn: 0.5157663	total: 1.92s	remaining: 5.39s
# 262:	learn: 0.5156172	total: 1.92s	remaining: 5.38s
# 263:	learn: 0.5154903	total: 1.93s	remaining: 5.38s
# 264:	learn: 0.5154443	total: 1.94s	remaining: 5.37s
# 265:	learn: 0.5153927	total: 1.95s	remaining: 5.37s
# 266:	learn: 0.5153052	total: 1.96s	remaining: 5.37s
# 267:	learn: 0.5151503	total: 1.97s	remaining: 5.38s
# 268:	learn: 0.5150198	total: 1.98s	remaining: 5.37s
# 269:	learn: 0.5149535	total: 1.98s	remaining: 5.37s
# 270:	learn: 0.5148251	total: 1.99s	remaining: 5.36s
# 271:	learn: 0.5146647	total: 2s	remaining: 5.36s
# 272:	learn: 0.5145871	total: 2.01s	remaining: 5.35s
# 273:	learn: 0.5142949	total: 2.02s	remaining: 5.34s
# 274:	learn: 0.5142030	total: 2.02s	remaining: 5.34s
# 275:	learn: 0.5139264	total: 2.03s	remaining: 5.33s
# 276:	learn: 0.5138545	total: 2.04s	remaining: 5.32s
# 277:	learn: 0.5137699	total: 2.04s	remaining: 5.31s
# 278:	learn: 0.5137080	total: 2.05s	remaining: 5.3s
# 279:	learn: 0.5134907	total: 2.06s	remaining: 5.29s
# 280:	learn: 0.5133738	total: 2.06s	remaining: 5.29s
# 281:	learn: 0.5132638	total: 2.07s	remaining: 5.27s
# 282:	learn: 0.5132239	total: 2.08s	remaining: 5.27s
# 283:	learn: 0.5131404	total: 2.09s	remaining: 5.26s
# 284:	learn: 0.5130438	total: 2.09s	remaining: 5.25s
# 285:	learn: 0.5129292	total: 2.1s	remaining: 5.24s
# 286:	learn: 0.5128743	total: 2.11s	remaining: 5.23s
# 287:	learn: 0.5127998	total: 2.11s	remaining: 5.22s
# 288:	learn: 0.5126506	total: 2.12s	remaining: 5.21s
# 289:	learn: 0.5125215	total: 2.13s	remaining: 5.21s
# 290:	learn: 0.5124202	total: 2.13s	remaining: 5.2s
# 291:	learn: 0.5123443	total: 2.14s	remaining: 5.18s
# 292:	learn: 0.5121998	total: 2.15s	remaining: 5.18s
# 293:	learn: 0.5120072	total: 2.15s	remaining: 5.17s
# 294:	learn: 0.5119180	total: 2.16s	remaining: 5.16s
# 295:	learn: 0.5118540	total: 2.17s	remaining: 5.15s
# 296:	learn: 0.5117145	total: 2.17s	remaining: 5.15s
# 297:	learn: 0.5115797	total: 2.18s	remaining: 5.14s
# 298:	learn: 0.5114858	total: 2.19s	remaining: 5.13s
# 299:	learn: 0.5113667	total: 2.2s	remaining: 5.12s
# 300:	learn: 0.5112269	total: 2.2s	remaining: 5.12s
# 301:	learn: 0.5109666	total: 2.21s	remaining: 5.11s
# 302:	learn: 0.5108058	total: 2.22s	remaining: 5.1s
# 303:	learn: 0.5107511	total: 2.23s	remaining: 5.1s
# 304:	learn: 0.5106121	total: 2.23s	remaining: 5.09s
# 305:	learn: 0.5104509	total: 2.24s	remaining: 5.08s
# 306:	learn: 0.5103643	total: 2.25s	remaining: 5.07s
# 307:	learn: 0.5102548	total: 2.25s	remaining: 5.06s
# 308:	learn: 0.5102040	total: 2.26s	remaining: 5.05s
# 309:	learn: 0.5100902	total: 2.27s	remaining: 5.04s
# 310:	learn: 0.5099231	total: 2.27s	remaining: 5.03s
# 311:	learn: 0.5098335	total: 2.28s	remaining: 5.03s
# 312:	learn: 0.5097367	total: 2.29s	remaining: 5.02s
# 313:	learn: 0.5095930	total: 2.29s	remaining: 5.01s
# 314:	learn: 0.5094873	total: 2.3s	remaining: 5s
# 315:	learn: 0.5093922	total: 2.31s	remaining: 4.99s
# 316:	learn: 0.5093253	total: 2.31s	remaining: 4.99s
# 317:	learn: 0.5092649	total: 2.32s	remaining: 4.98s
# 318:	learn: 0.5091962	total: 2.33s	remaining: 4.97s
# 319:	learn: 0.5091319	total: 2.33s	remaining: 4.96s
# 320:	learn: 0.5090218	total: 2.34s	remaining: 4.95s
# 321:	learn: 0.5089238	total: 2.35s	remaining: 4.94s
# 322:	learn: 0.5088558	total: 2.35s	remaining: 4.94s
# 323:	learn: 0.5087282	total: 2.36s	remaining: 4.93s
# 324:	learn: 0.5086565	total: 2.37s	remaining: 4.92s
# 325:	learn: 0.5085618	total: 2.38s	remaining: 4.92s
# 326:	learn: 0.5085080	total: 2.39s	remaining: 4.91s
# 327:	learn: 0.5083851	total: 2.39s	remaining: 4.91s
# 328:	learn: 0.5082999	total: 2.4s	remaining: 4.9s
# 329:	learn: 0.5082498	total: 2.41s	remaining: 4.89s
# 330:	learn: 0.5082080	total: 2.42s	remaining: 4.88s
# 331:	learn: 0.5081254	total: 2.42s	remaining: 4.88s
# 332:	learn: 0.5080519	total: 2.43s	remaining: 4.87s
# 333:	learn: 0.5079769	total: 2.44s	remaining: 4.86s
# 334:	learn: 0.5079449	total: 2.45s	remaining: 4.86s
# 335:	learn: 0.5078360	total: 2.46s	remaining: 4.85s
# 336:	learn: 0.5077468	total: 2.46s	remaining: 4.85s
# 337:	learn: 0.5076172	total: 2.47s	remaining: 4.84s
# 338:	learn: 0.5075827	total: 2.48s	remaining: 4.83s
# 339:	learn: 0.5075102	total: 2.48s	remaining: 4.83s
# 340:	learn: 0.5073550	total: 2.49s	remaining: 4.82s
# 341:	learn: 0.5072986	total: 2.5s	remaining: 4.81s
# 342:	learn: 0.5071948	total: 2.51s	remaining: 4.8s
# 343:	learn: 0.5070778	total: 2.51s	remaining: 4.79s
# 344:	learn: 0.5070162	total: 2.52s	remaining: 4.78s
# 345:	learn: 0.5069164	total: 2.52s	remaining: 4.77s
# 346:	learn: 0.5068455	total: 2.53s	remaining: 4.76s
# 347:	learn: 0.5067546	total: 2.54s	remaining: 4.76s
# 348:	learn: 0.5066894	total: 2.55s	remaining: 4.75s
# 349:	learn: 0.5066256	total: 2.55s	remaining: 4.74s
# 350:	learn: 0.5065544	total: 2.56s	remaining: 4.74s
# 351:	learn: 0.5064825	total: 2.57s	remaining: 4.73s
# 352:	learn: 0.5063943	total: 2.58s	remaining: 4.72s
# 353:	learn: 0.5063132	total: 2.58s	remaining: 4.71s
# 354:	learn: 0.5062232	total: 2.59s	remaining: 4.71s
# 355:	learn: 0.5061981	total: 2.6s	remaining: 4.7s
# 356:	learn: 0.5061524	total: 2.6s	remaining: 4.69s
# 357:	learn: 0.5061023	total: 2.61s	remaining: 4.68s
# 358:	learn: 0.5060357	total: 2.62s	remaining: 4.67s
# 359:	learn: 0.5058463	total: 2.62s	remaining: 4.66s
# 360:	learn: 0.5057235	total: 2.63s	remaining: 4.65s
# 361:	learn: 0.5055866	total: 2.64s	remaining: 4.65s
# 362:	learn: 0.5055280	total: 2.64s	remaining: 4.63s
# 363:	learn: 0.5054841	total: 2.65s	remaining: 4.63s
# 364:	learn: 0.5054308	total: 2.66s	remaining: 4.62s
# 365:	learn: 0.5053100	total: 2.67s	remaining: 4.62s
# 366:	learn: 0.5052796	total: 2.67s	remaining: 4.62s
# 367:	learn: 0.5051467	total: 2.69s	remaining: 4.61s
# 368:	learn: 0.5051015	total: 2.7s	remaining: 4.62s
# 369:	learn: 0.5049731	total: 2.71s	remaining: 4.61s
# 370:	learn: 0.5048905	total: 2.72s	remaining: 4.61s
# 371:	learn: 0.5047709	total: 2.73s	remaining: 4.61s
# 372:	learn: 0.5046735	total: 2.74s	remaining: 4.6s
# 373:	learn: 0.5046318	total: 2.75s	remaining: 4.6s
# 374:	learn: 0.5045839	total: 2.75s	remaining: 4.59s
# 375:	learn: 0.5045438	total: 2.76s	remaining: 4.58s
# 376:	learn: 0.5044808	total: 2.77s	remaining: 4.58s
# 377:	learn: 0.5044102	total: 2.77s	remaining: 4.57s
# 378:	learn: 0.5043454	total: 2.78s	remaining: 4.56s
# 379:	learn: 0.5042941	total: 2.79s	remaining: 4.55s
# 380:	learn: 0.5042316	total: 2.8s	remaining: 4.54s
# 381:	learn: 0.5042004	total: 2.8s	remaining: 4.54s
# 382:	learn: 0.5041095	total: 2.81s	remaining: 4.53s
# 383:	learn: 0.5040612	total: 2.82s	remaining: 4.52s
# 384:	learn: 0.5038904	total: 2.83s	remaining: 4.52s
# 385:	learn: 0.5038208	total: 2.84s	remaining: 4.51s
# 386:	learn: 0.5037300	total: 2.85s	remaining: 4.51s
# 387:	learn: 0.5036528	total: 2.85s	remaining: 4.5s
# 388:	learn: 0.5035745	total: 2.86s	remaining: 4.49s
# 389:	learn: 0.5035076	total: 2.87s	remaining: 4.49s
# 390:	learn: 0.5034202	total: 2.88s	remaining: 4.48s
# 391:	learn: 0.5033254	total: 2.88s	remaining: 4.47s
# 392:	learn: 0.5032685	total: 2.89s	remaining: 4.47s
# 393:	learn: 0.5031740	total: 2.9s	remaining: 4.46s
# 394:	learn: 0.5030800	total: 2.91s	remaining: 4.45s
# 395:	learn: 0.5030264	total: 2.92s	remaining: 4.45s
# 396:	learn: 0.5029560	total: 2.92s	remaining: 4.44s
# 397:	learn: 0.5029037	total: 2.93s	remaining: 4.43s
# 398:	learn: 0.5028082	total: 2.94s	remaining: 4.43s
# 399:	learn: 0.5026724	total: 2.95s	remaining: 4.42s
# 400:	learn: 0.5026034	total: 2.96s	remaining: 4.42s
# 401:	learn: 0.5025421	total: 2.97s	remaining: 4.42s
# 402:	learn: 0.5025036	total: 2.98s	remaining: 4.41s
# 403:	learn: 0.5024260	total: 2.99s	remaining: 4.41s
# 404:	learn: 0.5023811	total: 3s	remaining: 4.4s
# 405:	learn: 0.5023028	total: 3s	remaining: 4.39s
# 406:	learn: 0.5022283	total: 3.01s	remaining: 4.38s
# 407:	learn: 0.5020701	total: 3.02s	remaining: 4.38s
# 408:	learn: 0.5020131	total: 3.02s	remaining: 4.37s
# 409:	learn: 0.5019586	total: 3.03s	remaining: 4.36s
# 410:	learn: 0.5019122	total: 3.04s	remaining: 4.35s
# 411:	learn: 0.5018320	total: 3.04s	remaining: 4.35s
# 412:	learn: 0.5017822	total: 3.05s	remaining: 4.34s
# 413:	learn: 0.5016931	total: 3.06s	remaining: 4.33s
# 414:	learn: 0.5016424	total: 3.06s	remaining: 4.32s
# 415:	learn: 0.5015423	total: 3.07s	remaining: 4.31s
# 416:	learn: 0.5014679	total: 3.08s	remaining: 4.3s
# 417:	learn: 0.5013571	total: 3.08s	remaining: 4.29s
# 418:	learn: 0.5012948	total: 3.09s	remaining: 4.28s
# 419:	learn: 0.5012288	total: 3.1s	remaining: 4.28s
# 420:	learn: 0.5011767	total: 3.1s	remaining: 4.27s
# 421:	learn: 0.5011502	total: 3.11s	remaining: 4.26s
# 422:	learn: 0.5010941	total: 3.12s	remaining: 4.25s
# 423:	learn: 0.5010354	total: 3.13s	remaining: 4.25s
# 424:	learn: 0.5008866	total: 3.13s	remaining: 4.24s
# 425:	learn: 0.5007568	total: 3.14s	remaining: 4.23s
# 426:	learn: 0.5007074	total: 3.15s	remaining: 4.22s
# 427:	learn: 0.5006489	total: 3.15s	remaining: 4.21s
# 428:	learn: 0.5005712	total: 3.16s	remaining: 4.21s
# 429:	learn: 0.5005029	total: 3.17s	remaining: 4.2s
# 430:	learn: 0.5004303	total: 3.17s	remaining: 4.19s
# 431:	learn: 0.5003653	total: 3.18s	remaining: 4.18s
# 432:	learn: 0.5003136	total: 3.19s	remaining: 4.18s
# 433:	learn: 0.5002546	total: 3.2s	remaining: 4.17s
# 434:	learn: 0.5001983	total: 3.21s	remaining: 4.17s
# 435:	learn: 0.5000494	total: 3.21s	remaining: 4.16s
# 436:	learn: 0.4999830	total: 3.22s	remaining: 4.15s
# 437:	learn: 0.4999105	total: 3.23s	remaining: 4.14s
# 438:	learn: 0.4998452	total: 3.23s	remaining: 4.13s
# 439:	learn: 0.4997691	total: 3.24s	remaining: 4.12s
# 440:	learn: 0.4996079	total: 3.25s	remaining: 4.11s
# 441:	learn: 0.4995513	total: 3.25s	remaining: 4.11s
# 442:	learn: 0.4995089	total: 3.26s	remaining: 4.1s
# 443:	learn: 0.4994654	total: 3.27s	remaining: 4.09s
# 444:	learn: 0.4994191	total: 3.27s	remaining: 4.08s
# 445:	learn: 0.4993447	total: 3.28s	remaining: 4.08s
# 446:	learn: 0.4992742	total: 3.29s	remaining: 4.07s
# 447:	learn: 0.4992442	total: 3.29s	remaining: 4.06s
# 448:	learn: 0.4990002	total: 3.3s	remaining: 4.05s
# 449:	learn: 0.4989588	total: 3.31s	remaining: 4.04s
# 450:	learn: 0.4989213	total: 3.31s	remaining: 4.03s
# 451:	learn: 0.4988478	total: 3.32s	remaining: 4.02s
# 452:	learn: 0.4987996	total: 3.33s	remaining: 4.02s
# 453:	learn: 0.4987563	total: 3.33s	remaining: 4.01s
# 454:	learn: 0.4986942	total: 3.34s	remaining: 4s
# 455:	learn: 0.4986300	total: 3.35s	remaining: 4s
# 456:	learn: 0.4985421	total: 3.36s	remaining: 3.99s
# 457:	learn: 0.4984828	total: 3.37s	remaining: 3.98s
# 458:	learn: 0.4984216	total: 3.38s	remaining: 3.98s
# 459:	learn: 0.4983340	total: 3.38s	remaining: 3.97s
# 460:	learn: 0.4983036	total: 3.39s	remaining: 3.96s
# 461:	learn: 0.4982381	total: 3.4s	remaining: 3.96s
# 462:	learn: 0.4981727	total: 3.41s	remaining: 3.95s
# 463:	learn: 0.4981043	total: 3.42s	remaining: 3.95s
# 464:	learn: 0.4980575	total: 3.42s	remaining: 3.94s
# 465:	learn: 0.4980218	total: 3.43s	remaining: 3.93s
# 466:	learn: 0.4979732	total: 3.44s	remaining: 3.92s
# 467:	learn: 0.4979254	total: 3.44s	remaining: 3.92s
# 468:	learn: 0.4978595	total: 3.45s	remaining: 3.91s
# 469:	learn: 0.4977924	total: 3.46s	remaining: 3.9s
# 470:	learn: 0.4977414	total: 3.46s	remaining: 3.89s
# 471:	learn: 0.4976656	total: 3.47s	remaining: 3.88s
# 472:	learn: 0.4975481	total: 3.48s	remaining: 3.88s
# 473:	learn: 0.4975055	total: 3.49s	remaining: 3.87s
# 474:	learn: 0.4974140	total: 3.5s	remaining: 3.86s
# 475:	learn: 0.4972854	total: 3.5s	remaining: 3.85s
# 476:	learn: 0.4972118	total: 3.51s	remaining: 3.85s
# 477:	learn: 0.4971476	total: 3.51s	remaining: 3.84s
# 478:	learn: 0.4971277	total: 3.52s	remaining: 3.83s
# 479:	learn: 0.4970757	total: 3.53s	remaining: 3.82s
# 480:	learn: 0.4970274	total: 3.54s	remaining: 3.82s
# 481:	learn: 0.4968746	total: 3.55s	remaining: 3.81s
# 482:	learn: 0.4967868	total: 3.56s	remaining: 3.81s
# 483:	learn: 0.4967607	total: 3.56s	remaining: 3.8s
# 484:	learn: 0.4965861	total: 3.57s	remaining: 3.79s
# 485:	learn: 0.4965065	total: 3.58s	remaining: 3.79s
# 486:	learn: 0.4964605	total: 3.59s	remaining: 3.78s
# 487:	learn: 0.4963709	total: 3.6s	remaining: 3.78s
# 488:	learn: 0.4962458	total: 3.61s	remaining: 3.77s
# 489:	learn: 0.4960705	total: 3.62s	remaining: 3.76s
# 490:	learn: 0.4960156	total: 3.63s	remaining: 3.76s
# 491:	learn: 0.4959679	total: 3.64s	remaining: 3.76s
# 492:	learn: 0.4959089	total: 3.65s	remaining: 3.75s
# 493:	learn: 0.4958788	total: 3.65s	remaining: 3.74s
# 494:	learn: 0.4957740	total: 3.66s	remaining: 3.74s
# 495:	learn: 0.4957096	total: 3.67s	remaining: 3.73s
# 496:	learn: 0.4956707	total: 3.68s	remaining: 3.73s
# 497:	learn: 0.4956395	total: 3.69s	remaining: 3.72s
# 498:	learn: 0.4955941	total: 3.7s	remaining: 3.71s
# 499:	learn: 0.4954725	total: 3.71s	remaining: 3.71s
# 500:	learn: 0.4954196	total: 3.72s	remaining: 3.7s
# 501:	learn: 0.4953697	total: 3.72s	remaining: 3.69s
# 502:	learn: 0.4952788	total: 3.73s	remaining: 3.69s
# 503:	learn: 0.4952297	total: 3.74s	remaining: 3.68s
# 504:	learn: 0.4952041	total: 3.75s	remaining: 3.67s
# 505:	learn: 0.4951678	total: 3.75s	remaining: 3.66s
# 506:	learn: 0.4951491	total: 3.76s	remaining: 3.66s
# 507:	learn: 0.4950092	total: 3.77s	remaining: 3.65s
# 508:	learn: 0.4949846	total: 3.78s	remaining: 3.64s
# 509:	learn: 0.4949189	total: 3.79s	remaining: 3.64s
# 510:	learn: 0.4947884	total: 3.8s	remaining: 3.63s
# 511:	learn: 0.4947415	total: 3.81s	remaining: 3.63s
# 512:	learn: 0.4946971	total: 3.82s	remaining: 3.63s
# 513:	learn: 0.4945669	total: 3.84s	remaining: 3.63s
# 514:	learn: 0.4944599	total: 3.85s	remaining: 3.63s
# 515:	learn: 0.4943284	total: 3.87s	remaining: 3.63s
# 516:	learn: 0.4942977	total: 3.89s	remaining: 3.63s
# 517:	learn: 0.4942051	total: 3.9s	remaining: 3.63s
# 518:	learn: 0.4941734	total: 3.91s	remaining: 3.62s
# 519:	learn: 0.4941317	total: 3.92s	remaining: 3.62s
# 520:	learn: 0.4940611	total: 3.92s	remaining: 3.61s
# 521:	learn: 0.4939838	total: 3.93s	remaining: 3.6s
# 522:	learn: 0.4938770	total: 3.95s	remaining: 3.6s
# 523:	learn: 0.4937824	total: 3.96s	remaining: 3.59s
# 524:	learn: 0.4937229	total: 3.96s	remaining: 3.59s
# 525:	learn: 0.4936854	total: 3.97s	remaining: 3.58s
# 526:	learn: 0.4936580	total: 3.98s	remaining: 3.57s
# 527:	learn: 0.4936229	total: 3.98s	remaining: 3.56s
# 528:	learn: 0.4935570	total: 4s	remaining: 3.56s
# 529:	learn: 0.4934693	total: 4.01s	remaining: 3.55s
# 530:	learn: 0.4934032	total: 4.02s	remaining: 3.55s
# 531:	learn: 0.4933521	total: 4.03s	remaining: 3.54s
# 532:	learn: 0.4933002	total: 4.04s	remaining: 3.54s
# 533:	learn: 0.4931880	total: 4.04s	remaining: 3.53s
# 534:	learn: 0.4930542	total: 4.05s	remaining: 3.52s
# 535:	learn: 0.4930124	total: 4.06s	remaining: 3.51s
# 536:	learn: 0.4929649	total: 4.07s	remaining: 3.5s
# 537:	learn: 0.4928476	total: 4.07s	remaining: 3.5s
# 538:	learn: 0.4928038	total: 4.08s	remaining: 3.49s
# 539:	learn: 0.4927419	total: 4.09s	remaining: 3.48s
# 540:	learn: 0.4926600	total: 4.09s	remaining: 3.47s
# 541:	learn: 0.4925730	total: 4.1s	remaining: 3.46s
# 542:	learn: 0.4925299	total: 4.11s	remaining: 3.46s
# 543:	learn: 0.4924765	total: 4.11s	remaining: 3.45s
# 544:	learn: 0.4923881	total: 4.12s	remaining: 3.44s
# 545:	learn: 0.4923170	total: 4.13s	remaining: 3.43s
# 546:	learn: 0.4922790	total: 4.14s	remaining: 3.43s
# 547:	learn: 0.4922310	total: 4.14s	remaining: 3.42s
# 548:	learn: 0.4921990	total: 4.15s	remaining: 3.41s
# 549:	learn: 0.4921629	total: 4.16s	remaining: 3.4s
# 550:	learn: 0.4921171	total: 4.17s	remaining: 3.4s
# 551:	learn: 0.4920348	total: 4.18s	remaining: 3.4s
# 552:	learn: 0.4919924	total: 4.19s	remaining: 3.39s
# 553:	learn: 0.4918912	total: 4.2s	remaining: 3.38s
# 554:	learn: 0.4918514	total: 4.21s	remaining: 3.37s
# 555:	learn: 0.4917579	total: 4.21s	remaining: 3.37s
# 556:	learn: 0.4917037	total: 4.22s	remaining: 3.36s
# 557:	learn: 0.4917037	total: 4.23s	remaining: 3.35s
# 558:	learn: 0.4916557	total: 4.23s	remaining: 3.34s
# 559:	learn: 0.4916144	total: 4.24s	remaining: 3.33s
# 560:	learn: 0.4915813	total: 4.25s	remaining: 3.32s
# 561:	learn: 0.4915324	total: 4.25s	remaining: 3.31s
# 562:	learn: 0.4914831	total: 4.26s	remaining: 3.31s
# 563:	learn: 0.4914401	total: 4.27s	remaining: 3.3s
# 564:	learn: 0.4914029	total: 4.28s	remaining: 3.29s
# 565:	learn: 0.4913651	total: 4.28s	remaining: 3.28s
# 566:	learn: 0.4913100	total: 4.29s	remaining: 3.27s
# 567:	learn: 0.4911852	total: 4.3s	remaining: 3.27s
# 568:	learn: 0.4911485	total: 4.3s	remaining: 3.26s
# 569:	learn: 0.4911133	total: 4.31s	remaining: 3.25s
# 570:	learn: 0.4910175	total: 4.32s	remaining: 3.24s
# 571:	learn: 0.4909229	total: 4.33s	remaining: 3.24s
# 572:	learn: 0.4908734	total: 4.33s	remaining: 3.23s
# 573:	learn: 0.4908354	total: 4.34s	remaining: 3.22s
# 574:	learn: 0.4907809	total: 4.35s	remaining: 3.21s
# 575:	learn: 0.4907172	total: 4.36s	remaining: 3.21s
# 576:	learn: 0.4906454	total: 4.36s	remaining: 3.2s
# 577:	learn: 0.4906108	total: 4.37s	remaining: 3.19s
# 578:	learn: 0.4905473	total: 4.38s	remaining: 3.19s
# 579:	learn: 0.4905305	total: 4.39s	remaining: 3.18s
# 580:	learn: 0.4904857	total: 4.4s	remaining: 3.17s
# 581:	learn: 0.4903971	total: 4.41s	remaining: 3.16s
# 582:	learn: 0.4903507	total: 4.41s	remaining: 3.16s
# 583:	learn: 0.4902936	total: 4.42s	remaining: 3.15s
# 584:	learn: 0.4902218	total: 4.43s	remaining: 3.14s
# 585:	learn: 0.4901774	total: 4.43s	remaining: 3.13s
# 586:	learn: 0.4900984	total: 4.44s	remaining: 3.12s
# 587:	learn: 0.4900410	total: 4.45s	remaining: 3.12s
# 588:	learn: 0.4899547	total: 4.45s	remaining: 3.11s
# 589:	learn: 0.4899186	total: 4.46s	remaining: 3.1s
# 590:	learn: 0.4899027	total: 4.47s	remaining: 3.09s
# 591:	learn: 0.4898366	total: 4.47s	remaining: 3.08s
# 592:	learn: 0.4898304	total: 4.48s	remaining: 3.08s
# 593:	learn: 0.4897886	total: 4.49s	remaining: 3.07s
# 594:	learn: 0.4897303	total: 4.5s	remaining: 3.06s
# 595:	learn: 0.4896642	total: 4.5s	remaining: 3.05s
# 596:	learn: 0.4896222	total: 4.51s	remaining: 3.04s
# 597:	learn: 0.4895672	total: 4.51s	remaining: 3.03s
# 598:	learn: 0.4895045	total: 4.52s	remaining: 3.03s
# 599:	learn: 0.4893714	total: 4.53s	remaining: 3.02s
# 600:	learn: 0.4893015	total: 4.54s	remaining: 3.01s
# 601:	learn: 0.4892460	total: 4.55s	remaining: 3.01s
# 602:	learn: 0.4892116	total: 4.55s	remaining: 3s
# 603:	learn: 0.4891407	total: 4.56s	remaining: 2.99s
# 604:	learn: 0.4890375	total: 4.57s	remaining: 2.98s
# 605:	learn: 0.4889386	total: 4.58s	remaining: 2.98s
# 606:	learn: 0.4889167	total: 4.58s	remaining: 2.97s
# 607:	learn: 0.4888745	total: 4.59s	remaining: 2.96s
# 608:	learn: 0.4888525	total: 4.6s	remaining: 2.95s
# 609:	learn: 0.4888151	total: 4.6s	remaining: 2.94s
# 610:	learn: 0.4887119	total: 4.61s	remaining: 2.94s
# 611:	learn: 0.4886824	total: 4.62s	remaining: 2.93s
# 612:	learn: 0.4886255	total: 4.63s	remaining: 2.92s
# 613:	learn: 0.4885733	total: 4.64s	remaining: 2.92s
# 614:	learn: 0.4885385	total: 4.64s	remaining: 2.91s
# 615:	learn: 0.4884904	total: 4.65s	remaining: 2.9s
# 616:	learn: 0.4884692	total: 4.66s	remaining: 2.89s
# 617:	learn: 0.4884218	total: 4.68s	remaining: 2.89s
# 618:	learn: 0.4883437	total: 4.69s	remaining: 2.88s
# 619:	learn: 0.4883017	total: 4.7s	remaining: 2.88s
# 620:	learn: 0.4882732	total: 4.71s	remaining: 2.88s
# 621:	learn: 0.4882559	total: 4.74s	remaining: 2.88s
# 622:	learn: 0.4882317	total: 4.76s	remaining: 2.88s
# 623:	learn: 0.4881438	total: 4.78s	remaining: 2.88s
# 624:	learn: 0.4881183	total: 4.79s	remaining: 2.87s
# 625:	learn: 0.4880477	total: 4.8s	remaining: 2.87s
# 626:	learn: 0.4879701	total: 4.81s	remaining: 2.86s
# 627:	learn: 0.4879317	total: 4.82s	remaining: 2.86s
# 628:	learn: 0.4878701	total: 4.84s	remaining: 2.85s
# 629:	learn: 0.4878138	total: 4.85s	remaining: 2.85s
# 630:	learn: 0.4877899	total: 4.87s	remaining: 2.85s
# 631:	learn: 0.4877536	total: 4.87s	remaining: 2.84s
# 632:	learn: 0.4877242	total: 4.88s	remaining: 2.83s
# 633:	learn: 0.4876800	total: 4.89s	remaining: 2.82s
# 634:	learn: 0.4876785	total: 4.9s	remaining: 2.82s
# 635:	learn: 0.4876515	total: 4.91s	remaining: 2.81s
# 636:	learn: 0.4875940	total: 4.92s	remaining: 2.81s
# 637:	learn: 0.4875351	total: 4.94s	remaining: 2.8s
# 638:	learn: 0.4874783	total: 4.96s	remaining: 2.8s
# 639:	learn: 0.4874561	total: 4.97s	remaining: 2.8s
# 640:	learn: 0.4874114	total: 4.98s	remaining: 2.79s
# 641:	learn: 0.4873744	total: 4.99s	remaining: 2.78s
# 642:	learn: 0.4873312	total: 5s	remaining: 2.78s
# 643:	learn: 0.4872978	total: 5.01s	remaining: 2.77s
# 644:	learn: 0.4872463	total: 5.02s	remaining: 2.76s
# 645:	learn: 0.4871880	total: 5.03s	remaining: 2.76s
# 646:	learn: 0.4871422	total: 5.04s	remaining: 2.75s
# 647:	learn: 0.4870945	total: 5.04s	remaining: 2.74s
# 648:	learn: 0.4870648	total: 5.06s	remaining: 2.73s
# 649:	learn: 0.4870261	total: 5.07s	remaining: 2.73s
# 650:	learn: 0.4869498	total: 5.08s	remaining: 2.72s
# 651:	learn: 0.4869027	total: 5.08s	remaining: 2.71s
# 652:	learn: 0.4868839	total: 5.09s	remaining: 2.71s
# 653:	learn: 0.4868420	total: 5.1s	remaining: 2.7s
# 654:	learn: 0.4866735	total: 5.11s	remaining: 2.69s
# 655:	learn: 0.4866171	total: 5.12s	remaining: 2.68s
# 656:	learn: 0.4864865	total: 5.13s	remaining: 2.68s
# 657:	learn: 0.4864392	total: 5.14s	remaining: 2.67s
# 658:	learn: 0.4863871	total: 5.15s	remaining: 2.67s
# 659:	learn: 0.4863736	total: 5.16s	remaining: 2.66s
# 660:	learn: 0.4863152	total: 5.18s	remaining: 2.65s
# 661:	learn: 0.4862370	total: 5.18s	remaining: 2.65s
# 662:	learn: 0.4861934	total: 5.2s	remaining: 2.64s
# 663:	learn: 0.4861674	total: 5.21s	remaining: 2.63s
# 664:	learn: 0.4861320	total: 5.21s	remaining: 2.63s
# 665:	learn: 0.4860907	total: 5.22s	remaining: 2.62s
# 666:	learn: 0.4860711	total: 5.23s	remaining: 2.61s
# 667:	learn: 0.4859973	total: 5.24s	remaining: 2.6s
# 668:	learn: 0.4859967	total: 5.25s	remaining: 2.6s
# 669:	learn: 0.4859909	total: 5.25s	remaining: 2.59s
# 670:	learn: 0.4859549	total: 5.27s	remaining: 2.58s
# 671:	learn: 0.4858560	total: 5.28s	remaining: 2.58s
# 672:	learn: 0.4858269	total: 5.29s	remaining: 2.57s
# 673:	learn: 0.4858084	total: 5.3s	remaining: 2.56s
# 674:	learn: 0.4857649	total: 5.31s	remaining: 2.55s
# 675:	learn: 0.4857227	total: 5.31s	remaining: 2.55s
# 676:	learn: 0.4856195	total: 5.32s	remaining: 2.54s
# 677:	learn: 0.4855678	total: 5.33s	remaining: 2.53s
# 678:	learn: 0.4855096	total: 5.34s	remaining: 2.52s
# 679:	learn: 0.4854265	total: 5.34s	remaining: 2.52s
# 680:	learn: 0.4853896	total: 5.36s	remaining: 2.51s
# 681:	learn: 0.4853104	total: 5.37s	remaining: 2.5s
# 682:	learn: 0.4852254	total: 5.37s	remaining: 2.49s
# 683:	learn: 0.4852103	total: 5.38s	remaining: 2.48s
# 684:	learn: 0.4851361	total: 5.39s	remaining: 2.48s
# 685:	learn: 0.4850763	total: 5.39s	remaining: 2.47s
# 686:	learn: 0.4850377	total: 5.4s	remaining: 2.46s
# 687:	learn: 0.4849965	total: 5.41s	remaining: 2.45s
# 688:	learn: 0.4849476	total: 5.42s	remaining: 2.44s
# 689:	learn: 0.4849140	total: 5.42s	remaining: 2.44s
# 690:	learn: 0.4848783	total: 5.43s	remaining: 2.43s
# 691:	learn: 0.4848040	total: 5.44s	remaining: 2.42s
# 692:	learn: 0.4847650	total: 5.45s	remaining: 2.41s
# 693:	learn: 0.4847181	total: 5.46s	remaining: 2.41s
# 694:	learn: 0.4846290	total: 5.46s	remaining: 2.4s
# 695:	learn: 0.4846095	total: 5.47s	remaining: 2.39s
# 696:	learn: 0.4845672	total: 5.48s	remaining: 2.38s
# 697:	learn: 0.4845138	total: 5.49s	remaining: 2.38s
# 698:	learn: 0.4844188	total: 5.5s	remaining: 2.37s
# 699:	learn: 0.4843794	total: 5.5s	remaining: 2.36s
# 700:	learn: 0.4843458	total: 5.51s	remaining: 2.35s
# 701:	learn: 0.4843108	total: 5.52s	remaining: 2.34s
# 702:	learn: 0.4842717	total: 5.53s	remaining: 2.34s
# 703:	learn: 0.4842152	total: 5.55s	remaining: 2.33s
# 704:	learn: 0.4841842	total: 5.56s	remaining: 2.33s
# 705:	learn: 0.4841527	total: 5.57s	remaining: 2.32s
# 706:	learn: 0.4840943	total: 5.58s	remaining: 2.31s
# 707:	learn: 0.4840586	total: 5.59s	remaining: 2.3s
# 708:	learn: 0.4840017	total: 5.6s	remaining: 2.3s
# 709:	learn: 0.4839511	total: 5.61s	remaining: 2.29s
# 710:	learn: 0.4839147	total: 5.62s	remaining: 2.29s
# 711:	learn: 0.4838870	total: 5.63s	remaining: 2.28s
# 712:	learn: 0.4838294	total: 5.64s	remaining: 2.27s
# 713:	learn: 0.4837455	total: 5.66s	remaining: 2.27s
# 714:	learn: 0.4837173	total: 5.67s	remaining: 2.26s
# 715:	learn: 0.4836861	total: 5.68s	remaining: 2.25s
# 716:	learn: 0.4836345	total: 5.7s	remaining: 2.25s
# 717:	learn: 0.4835794	total: 5.71s	remaining: 2.24s
# 718:	learn: 0.4834860	total: 5.72s	remaining: 2.24s
# 719:	learn: 0.4834473	total: 5.73s	remaining: 2.23s
# 720:	learn: 0.4833448	total: 5.74s	remaining: 2.22s
# 721:	learn: 0.4833133	total: 5.75s	remaining: 2.21s
# 722:	learn: 0.4832775	total: 5.76s	remaining: 2.21s
# 723:	learn: 0.4832164	total: 5.78s	remaining: 2.2s
# 724:	learn: 0.4831930	total: 5.79s	remaining: 2.19s
# 725:	learn: 0.4830951	total: 5.79s	remaining: 2.19s
# 726:	learn: 0.4830663	total: 5.8s	remaining: 2.18s
# 727:	learn: 0.4830656	total: 5.81s	remaining: 2.17s
# 728:	learn: 0.4830456	total: 5.81s	remaining: 2.16s
# 729:	learn: 0.4830202	total: 5.82s	remaining: 2.15s
# 730:	learn: 0.4829896	total: 5.83s	remaining: 2.15s
# 731:	learn: 0.4829416	total: 5.84s	remaining: 2.14s
# 732:	learn: 0.4829070	total: 5.85s	remaining: 2.13s
# 733:	learn: 0.4828782	total: 5.85s	remaining: 2.12s
# 734:	learn: 0.4828446	total: 5.86s	remaining: 2.11s
# 735:	learn: 0.4827943	total: 5.87s	remaining: 2.11s
# 736:	learn: 0.4827705	total: 5.88s	remaining: 2.1s
# 737:	learn: 0.4827028	total: 5.89s	remaining: 2.09s
# 738:	learn: 0.4826663	total: 5.9s	remaining: 2.08s
# 739:	learn: 0.4826056	total: 5.9s	remaining: 2.07s
# 740:	learn: 0.4825881	total: 5.91s	remaining: 2.07s
# 741:	learn: 0.4825349	total: 5.92s	remaining: 2.06s
# 742:	learn: 0.4824849	total: 5.93s	remaining: 2.05s
# 743:	learn: 0.4824399	total: 5.93s	remaining: 2.04s
# 744:	learn: 0.4823442	total: 5.94s	remaining: 2.03s
# 745:	learn: 0.4822704	total: 5.95s	remaining: 2.03s
# 746:	learn: 0.4822218	total: 5.96s	remaining: 2.02s
# 747:	learn: 0.4821489	total: 5.97s	remaining: 2.01s
# 748:	learn: 0.4821024	total: 5.98s	remaining: 2s
# 749:	learn: 0.4820306	total: 6s	remaining: 2s
# 750:	learn: 0.4819776	total: 6.01s	remaining: 1.99s
# 751:	learn: 0.4819187	total: 6.02s	remaining: 1.99s
# 752:	learn: 0.4818925	total: 6.03s	remaining: 1.98s
# 753:	learn: 0.4818577	total: 6.04s	remaining: 1.97s
# 754:	learn: 0.4818209	total: 6.05s	remaining: 1.96s
# 755:	learn: 0.4817282	total: 6.07s	remaining: 1.96s
# 756:	learn: 0.4816700	total: 6.07s	remaining: 1.95s
# 757:	learn: 0.4816283	total: 6.08s	remaining: 1.94s
# 758:	learn: 0.4815810	total: 6.09s	remaining: 1.93s
# 759:	learn: 0.4815558	total: 6.1s	remaining: 1.93s
# 760:	learn: 0.4815423	total: 6.11s	remaining: 1.92s
# 761:	learn: 0.4815328	total: 6.12s	remaining: 1.91s
# 762:	learn: 0.4814986	total: 6.13s	remaining: 1.91s
# 763:	learn: 0.4814652	total: 6.15s	remaining: 1.9s
# 764:	learn: 0.4814112	total: 6.16s	remaining: 1.89s
# 765:	learn: 0.4813375	total: 6.18s	remaining: 1.89s
# 766:	learn: 0.4812828	total: 6.18s	remaining: 1.88s
# 767:	learn: 0.4811134	total: 6.2s	remaining: 1.87s
# 768:	learn: 0.4810637	total: 6.2s	remaining: 1.86s
# 769:	learn: 0.4810574	total: 6.21s	remaining: 1.85s
# 770:	learn: 0.4810251	total: 6.23s	remaining: 1.85s
# 771:	learn: 0.4810139	total: 6.24s	remaining: 1.84s
# 772:	learn: 0.4809742	total: 6.25s	remaining: 1.84s
# 773:	learn: 0.4809425	total: 6.26s	remaining: 1.83s
# 774:	learn: 0.4808889	total: 6.29s	remaining: 1.82s
# 775:	learn: 0.4808643	total: 6.3s	remaining: 1.82s
# 776:	learn: 0.4808358	total: 6.31s	remaining: 1.81s
# 777:	learn: 0.4808056	total: 6.34s	remaining: 1.81s
# 778:	learn: 0.4807087	total: 6.36s	remaining: 1.8s
# 779:	learn: 0.4806700	total: 6.38s	remaining: 1.8s
# 780:	learn: 0.4805725	total: 6.39s	remaining: 1.79s
# 781:	learn: 0.4805306	total: 6.4s	remaining: 1.78s
# 782:	learn: 0.4804793	total: 6.41s	remaining: 1.77s
# 783:	learn: 0.4804205	total: 6.42s	remaining: 1.77s
# 784:	learn: 0.4803743	total: 6.45s	remaining: 1.76s
# 785:	learn: 0.4803550	total: 6.45s	remaining: 1.76s
# 786:	learn: 0.4803405	total: 6.46s	remaining: 1.75s
# 787:	learn: 0.4802943	total: 6.47s	remaining: 1.74s
# 788:	learn: 0.4802614	total: 6.48s	remaining: 1.73s
# 789:	learn: 0.4802192	total: 6.49s	remaining: 1.73s
# 790:	learn: 0.4801705	total: 6.5s	remaining: 1.72s
# 791:	learn: 0.4801509	total: 6.51s	remaining: 1.71s
# 792:	learn: 0.4801006	total: 6.52s	remaining: 1.7s
# 793:	learn: 0.4800448	total: 6.54s	remaining: 1.7s
# 794:	learn: 0.4799548	total: 6.56s	remaining: 1.69s
# 795:	learn: 0.4799117	total: 6.57s	remaining: 1.68s
# 796:	learn: 0.4798837	total: 6.58s	remaining: 1.68s
# 797:	learn: 0.4798813	total: 6.59s	remaining: 1.67s
# 798:	learn: 0.4798420	total: 6.61s	remaining: 1.66s
# 799:	learn: 0.4798156	total: 6.62s	remaining: 1.66s
# 800:	learn: 0.4797919	total: 6.63s	remaining: 1.65s
# 801:	learn: 0.4797630	total: 6.64s	remaining: 1.64s
# 802:	learn: 0.4797487	total: 6.65s	remaining: 1.63s
# 803:	learn: 0.4797276	total: 6.66s	remaining: 1.62s
# 804:	learn: 0.4797008	total: 6.66s	remaining: 1.61s
# 805:	learn: 0.4796502	total: 6.67s	remaining: 1.6s
# 806:	learn: 0.4796102	total: 6.68s	remaining: 1.6s
# 807:	learn: 0.4795521	total: 6.68s	remaining: 1.59s
# 808:	learn: 0.4795208	total: 6.69s	remaining: 1.58s
# 809:	learn: 0.4793753	total: 6.71s	remaining: 1.57s
# 810:	learn: 0.4793521	total: 6.71s	remaining: 1.56s
# 811:	learn: 0.4793078	total: 6.72s	remaining: 1.56s
# 812:	learn: 0.4792808	total: 6.73s	remaining: 1.55s
# 813:	learn: 0.4792530	total: 6.74s	remaining: 1.54s
# 814:	learn: 0.4792377	total: 6.75s	remaining: 1.53s
# 815:	learn: 0.4791515	total: 6.75s	remaining: 1.52s
# 816:	learn: 0.4791325	total: 6.76s	remaining: 1.51s
# 817:	learn: 0.4790925	total: 6.78s	remaining: 1.51s
# 818:	learn: 0.4790490	total: 6.79s	remaining: 1.5s
# 819:	learn: 0.4790068	total: 6.79s	remaining: 1.49s
# 820:	learn: 0.4789785	total: 6.81s	remaining: 1.48s
# 821:	learn: 0.4789361	total: 6.83s	remaining: 1.48s
# 822:	learn: 0.4788981	total: 6.84s	remaining: 1.47s
# 823:	learn: 0.4788396	total: 6.85s	remaining: 1.46s
# 824:	learn: 0.4788084	total: 6.86s	remaining: 1.46s
# 825:	learn: 0.4787688	total: 6.87s	remaining: 1.45s
# 826:	learn: 0.4786827	total: 6.89s	remaining: 1.44s
# 827:	learn: 0.4786460	total: 6.9s	remaining: 1.43s
# 828:	learn: 0.4786108	total: 6.91s	remaining: 1.42s
# 829:	learn: 0.4785629	total: 6.91s	remaining: 1.42s
# 830:	learn: 0.4785315	total: 6.92s	remaining: 1.41s
# 831:	learn: 0.4784789	total: 6.93s	remaining: 1.4s
# 832:	learn: 0.4784428	total: 6.94s	remaining: 1.39s
# 833:	learn: 0.4784142	total: 6.95s	remaining: 1.38s
# 834:	learn: 0.4783980	total: 6.96s	remaining: 1.38s
# 835:	learn: 0.4783411	total: 6.97s	remaining: 1.37s
# 836:	learn: 0.4783177	total: 6.97s	remaining: 1.36s
# 837:	learn: 0.4782693	total: 6.98s	remaining: 1.35s
# 838:	learn: 0.4782396	total: 6.99s	remaining: 1.34s
# 839:	learn: 0.4782100	total: 7s	remaining: 1.33s
# 840:	learn: 0.4781686	total: 7.01s	remaining: 1.32s
# 841:	learn: 0.4781200	total: 7.02s	remaining: 1.32s
# 842:	learn: 0.4780764	total: 7.03s	remaining: 1.31s
# 843:	learn: 0.4780616	total: 7.03s	remaining: 1.3s
# 844:	learn: 0.4780463	total: 7.04s	remaining: 1.29s
# 845:	learn: 0.4779807	total: 7.04s	remaining: 1.28s
# 846:	learn: 0.4779572	total: 7.05s	remaining: 1.27s
# 847:	learn: 0.4779254	total: 7.06s	remaining: 1.26s
# 848:	learn: 0.4778826	total: 7.07s	remaining: 1.26s
# 849:	learn: 0.4778764	total: 7.08s	remaining: 1.25s
# 850:	learn: 0.4778280	total: 7.09s	remaining: 1.24s
# 851:	learn: 0.4777851	total: 7.1s	remaining: 1.23s
# 852:	learn: 0.4777404	total: 7.12s	remaining: 1.23s
# 853:	learn: 0.4777209	total: 7.14s	remaining: 1.22s
# 854:	learn: 0.4776823	total: 7.15s	remaining: 1.21s
# 855:	learn: 0.4776335	total: 7.17s	remaining: 1.21s
# 856:	learn: 0.4776074	total: 7.18s	remaining: 1.2s
# 857:	learn: 0.4775317	total: 7.2s	remaining: 1.19s
# 858:	learn: 0.4775012	total: 7.21s	remaining: 1.18s
# 859:	learn: 0.4774395	total: 7.22s	remaining: 1.18s
# 860:	learn: 0.4773974	total: 7.23s	remaining: 1.17s
# 861:	learn: 0.4773234	total: 7.24s	remaining: 1.16s
# 862:	learn: 0.4772832	total: 7.26s	remaining: 1.15s
# 863:	learn: 0.4772076	total: 7.28s	remaining: 1.15s
# 864:	learn: 0.4771880	total: 7.29s	remaining: 1.14s
# 865:	learn: 0.4771581	total: 7.3s	remaining: 1.13s
# 866:	learn: 0.4771233	total: 7.32s	remaining: 1.12s
# 867:	learn: 0.4770944	total: 7.32s	remaining: 1.11s
# 868:	learn: 0.4770721	total: 7.33s	remaining: 1.1s
# 869:	learn: 0.4770532	total: 7.34s	remaining: 1.1s
# 870:	learn: 0.4769940	total: 7.35s	remaining: 1.09s
# 871:	learn: 0.4769931	total: 7.36s	remaining: 1.08s
# 872:	learn: 0.4769573	total: 7.37s	remaining: 1.07s
# 873:	learn: 0.4769239	total: 7.38s	remaining: 1.06s
# 874:	learn: 0.4768845	total: 7.39s	remaining: 1.05s
# 875:	learn: 0.4768507	total: 7.4s	remaining: 1.05s
# 876:	learn: 0.4768380	total: 7.41s	remaining: 1.04s
# 877:	learn: 0.4768068	total: 7.42s	remaining: 1.03s
# 878:	learn: 0.4767603	total: 7.43s	remaining: 1.02s
# 879:	learn: 0.4767307	total: 7.44s	remaining: 1.01s
# 880:	learn: 0.4767092	total: 7.45s	remaining: 1.01s
# 881:	learn: 0.4766729	total: 7.46s	remaining: 998ms
# 882:	learn: 0.4766445	total: 7.47s	remaining: 989ms
# 883:	learn: 0.4765722	total: 7.47s	remaining: 981ms
# 884:	learn: 0.4765332	total: 7.48s	remaining: 972ms
# 885:	learn: 0.4764422	total: 7.49s	remaining: 964ms
# 886:	learn: 0.4764088	total: 7.5s	remaining: 956ms
# 887:	learn: 0.4763863	total: 7.52s	remaining: 948ms
# 888:	learn: 0.4763484	total: 7.53s	remaining: 940ms
# 889:	learn: 0.4763174	total: 7.54s	remaining: 931ms
# 890:	learn: 0.4763001	total: 7.55s	remaining: 923ms
# 891:	learn: 0.4762235	total: 7.56s	remaining: 915ms
# 892:	learn: 0.4761958	total: 7.57s	remaining: 907ms
# 893:	learn: 0.4761507	total: 7.59s	remaining: 900ms
# 894:	learn: 0.4761277	total: 7.6s	remaining: 892ms
# 895:	learn: 0.4760885	total: 7.61s	remaining: 883ms
# 896:	learn: 0.4759965	total: 7.62s	remaining: 875ms
# 897:	learn: 0.4759751	total: 7.62s	remaining: 866ms
# 898:	learn: 0.4759565	total: 7.63s	remaining: 857ms
# 899:	learn: 0.4759291	total: 7.64s	remaining: 849ms
# 900:	learn: 0.4759041	total: 7.65s	remaining: 841ms
# 901:	learn: 0.4758748	total: 7.66s	remaining: 833ms
# 902:	learn: 0.4758454	total: 7.67s	remaining: 824ms
# 903:	learn: 0.4757396	total: 7.68s	remaining: 816ms
# 904:	learn: 0.4757240	total: 7.69s	remaining: 808ms
# 905:	learn: 0.4756601	total: 7.7s	remaining: 799ms
# 906:	learn: 0.4756371	total: 7.72s	remaining: 791ms
# 907:	learn: 0.4755574	total: 7.73s	remaining: 784ms
# 908:	learn: 0.4755304	total: 7.74s	remaining: 775ms
# ...
# 865:	learn: 0.4787163	total: 6.09s	remaining: 942ms
# 866:	learn: 0.4786931	total: 6.09s	remaining: 935ms
# 867:	learn: 0.4786585	total: 6.1s	remaining: 928ms
# 868:	learn: 0.4786295	total: 6.11s	remaining: 921ms
# 869:	learn: 0.4785849	total: 6.12s	remaining: 914ms
# 870:	learn: 0.4785537	total: 6.13s	remaining: 907ms
# 871:	learn: 0.4785424	total: 6.13s	remaining: 901ms
# 872:	learn: 0.4784975	total: 6.14s	remaining: 894ms
# 873:	learn: 0.4784328	total: 6.15s	remaining: 886ms
# 874:	learn: 0.4783620	total: 6.15s	remaining: 879ms
# 875:	learn: 0.4783267	total: 6.16s	remaining: 872ms
# 876:	learn: 0.4782981	total: 6.17s	remaining: 865ms
# 877:	learn: 0.4782537	total: 6.17s	remaining: 858ms
# 878:	learn: 0.4781983	total: 6.18s	remaining: 851ms
# 879:	learn: 0.4781713	total: 6.19s	remaining: 844ms
# 880:	learn: 0.4781088	total: 6.19s	remaining: 837ms
# 881:	learn: 0.4780719	total: 6.2s	remaining: 830ms
# 882:	learn: 0.4780406	total: 6.21s	remaining: 823ms
# 883:	learn: 0.4780191	total: 6.22s	remaining: 816ms
# 884:	learn: 0.4779893	total: 6.22s	remaining: 809ms
# 885:	learn: 0.4779475	total: 6.23s	remaining: 802ms
# 886:	learn: 0.4779092	total: 6.24s	remaining: 795ms
# 887:	learn: 0.4778345	total: 6.25s	remaining: 788ms
# 888:	learn: 0.4777966	total: 6.25s	remaining: 781ms
# 889:	learn: 0.4777441	total: 6.26s	remaining: 774ms
# 890:	learn: 0.4777011	total: 6.27s	remaining: 768ms
# 891:	learn: 0.4776568	total: 6.28s	remaining: 761ms
# 892:	learn: 0.4776168	total: 6.29s	remaining: 754ms
# 893:	learn: 0.4775657	total: 6.29s	remaining: 746ms
# 894:	learn: 0.4775178	total: 6.3s	remaining: 740ms
# 895:	learn: 0.4774793	total: 6.31s	remaining: 732ms
# 896:	learn: 0.4774454	total: 6.32s	remaining: 725ms
# 897:	learn: 0.4773585	total: 6.33s	remaining: 718ms
# 898:	learn: 0.4773427	total: 6.33s	remaining: 711ms
# 899:	learn: 0.4773177	total: 6.34s	remaining: 704ms
# 900:	learn: 0.4772650	total: 6.35s	remaining: 697ms
# 901:	learn: 0.4772156	total: 6.35s	remaining: 690ms
# 902:	learn: 0.4771885	total: 6.36s	remaining: 683ms
# 903:	learn: 0.4771355	total: 6.37s	remaining: 676ms
# 904:	learn: 0.4771129	total: 6.38s	remaining: 669ms
# 905:	learn: 0.4770928	total: 6.38s	remaining: 662ms
# 906:	learn: 0.4770530	total: 6.39s	remaining: 655ms
# 907:	learn: 0.4770020	total: 6.4s	remaining: 648ms
# 908:	learn: 0.4769777	total: 6.41s	remaining: 641ms
# 909:	learn: 0.4769635	total: 6.41s	remaining: 634ms
# 910:	learn: 0.4769080	total: 6.42s	remaining: 627ms
# 911:	learn: 0.4768566	total: 6.43s	remaining: 621ms
# 912:	learn: 0.4768414	total: 6.44s	remaining: 614ms
# 913:	learn: 0.4768122	total: 6.45s	remaining: 607ms
# 914:	learn: 0.4767493	total: 6.46s	remaining: 600ms
# 915:	learn: 0.4767221	total: 6.47s	remaining: 593ms
# 916:	learn: 0.4766817	total: 6.48s	remaining: 586ms
# 917:	learn: 0.4766377	total: 6.48s	remaining: 579ms
# 918:	learn: 0.4766026	total: 6.49s	remaining: 572ms
# 919:	learn: 0.4765670	total: 6.5s	remaining: 565ms
# 920:	learn: 0.4765224	total: 6.51s	remaining: 558ms
# 921:	learn: 0.4764776	total: 6.51s	remaining: 551ms
# 922:	learn: 0.4764336	total: 6.52s	remaining: 544ms
# 923:	learn: 0.4763432	total: 6.53s	remaining: 537ms
# 924:	learn: 0.4762827	total: 6.54s	remaining: 530ms
# 925:	learn: 0.4762060	total: 6.55s	remaining: 523ms
# 926:	learn: 0.4761608	total: 6.56s	remaining: 516ms
# 927:	learn: 0.4761287	total: 6.56s	remaining: 509ms
# 928:	learn: 0.4761032	total: 6.57s	remaining: 502ms
# 929:	learn: 0.4760469	total: 6.58s	remaining: 495ms
# 930:	learn: 0.4760158	total: 6.59s	remaining: 488ms
# 931:	learn: 0.4759866	total: 6.6s	remaining: 481ms
# 932:	learn: 0.4759576	total: 6.61s	remaining: 474ms
# 933:	learn: 0.4758960	total: 6.61s	remaining: 467ms
# 934:	learn: 0.4757946	total: 6.62s	remaining: 460ms
# 935:	learn: 0.4757379	total: 6.63s	remaining: 453ms
# 936:	learn: 0.4756663	total: 6.63s	remaining: 446ms
# 937:	learn: 0.4756483	total: 6.64s	remaining: 439ms
# 938:	learn: 0.4755914	total: 6.66s	remaining: 433ms
# 939:	learn: 0.4755426	total: 6.67s	remaining: 426ms
# 940:	learn: 0.4755005	total: 6.67s	remaining: 419ms
# 941:	learn: 0.4754378	total: 6.68s	remaining: 411ms
# 942:	learn: 0.4753903	total: 6.69s	remaining: 404ms
# 943:	learn: 0.4753688	total: 6.7s	remaining: 397ms
# 944:	learn: 0.4753423	total: 6.7s	remaining: 390ms
# 945:	learn: 0.4753068	total: 6.71s	remaining: 383ms
# 946:	learn: 0.4752593	total: 6.71s	remaining: 376ms
# 947:	learn: 0.4752192	total: 6.72s	remaining: 369ms
# 948:	learn: 0.4751772	total: 6.73s	remaining: 361ms
# 949:	learn: 0.4751436	total: 6.73s	remaining: 354ms
# 950:	learn: 0.4750994	total: 6.74s	remaining: 347ms
# 951:	learn: 0.4750390	total: 6.75s	remaining: 340ms
# 952:	learn: 0.4749877	total: 6.75s	remaining: 333ms
# 953:	learn: 0.4749544	total: 6.76s	remaining: 326ms
# 954:	learn: 0.4749203	total: 6.77s	remaining: 319ms
# 955:	learn: 0.4749031	total: 6.78s	remaining: 312ms
# 956:	learn: 0.4748651	total: 6.79s	remaining: 305ms
# 957:	learn: 0.4748317	total: 6.79s	remaining: 298ms
# 958:	learn: 0.4747947	total: 6.8s	remaining: 291ms
# 959:	learn: 0.4747620	total: 6.81s	remaining: 284ms
# 960:	learn: 0.4747499	total: 6.82s	remaining: 277ms
# 961:	learn: 0.4747069	total: 6.83s	remaining: 270ms
# 962:	learn: 0.4746865	total: 6.83s	remaining: 263ms
# 963:	learn: 0.4746685	total: 6.84s	remaining: 255ms
# 964:	learn: 0.4746525	total: 6.84s	remaining: 248ms
# 965:	learn: 0.4746143	total: 6.85s	remaining: 241ms
# 966:	learn: 0.4745634	total: 6.86s	remaining: 234ms
# 967:	learn: 0.4745350	total: 6.86s	remaining: 227ms
# 968:	learn: 0.4745028	total: 6.87s	remaining: 220ms
# 969:	learn: 0.4744732	total: 6.88s	remaining: 213ms
# 970:	learn: 0.4744436	total: 6.88s	remaining: 206ms
# 971:	learn: 0.4743993	total: 6.89s	remaining: 198ms
# 972:	learn: 0.4743666	total: 6.89s	remaining: 191ms
# 973:	learn: 0.4743252	total: 6.9s	remaining: 184ms
# 974:	learn: 0.4742871	total: 6.9s	remaining: 177ms
# 975:	learn: 0.4742221	total: 6.91s	remaining: 170ms
# 976:	learn: 0.4741951	total: 6.92s	remaining: 163ms
# 977:	learn: 0.4741668	total: 6.92s	remaining: 156ms
# 978:	learn: 0.4741618	total: 6.93s	remaining: 149ms
# 979:	learn: 0.4740925	total: 6.94s	remaining: 142ms
# 980:	learn: 0.4740681	total: 6.95s	remaining: 135ms
# 981:	learn: 0.4740398	total: 6.95s	remaining: 127ms
# 982:	learn: 0.4740261	total: 6.96s	remaining: 120ms
# 983:	learn: 0.4739858	total: 6.96s	remaining: 113ms
# 984:	learn: 0.4739520	total: 6.97s	remaining: 106ms
# 985:	learn: 0.4739151	total: 6.98s	remaining: 99.1ms
# 986:	learn: 0.4738697	total: 6.98s	remaining: 92ms
# 987:	learn: 0.4738128	total: 6.99s	remaining: 84.9ms
# 988:	learn: 0.4737885	total: 7s	remaining: 77.8ms
# 989:	learn: 0.4737221	total: 7.01s	remaining: 70.8ms
# 990:	learn: 0.4737052	total: 7.01s	remaining: 63.7ms
# 991:	learn: 0.4736606	total: 7.03s	remaining: 56.7ms
# 992:	learn: 0.4736205	total: 7.04s	remaining: 49.6ms
# 993:	learn: 0.4735797	total: 7.04s	remaining: 42.5ms
# 994:	learn: 0.4735285	total: 7.05s	remaining: 35.4ms
# 995:	learn: 0.4734998	total: 7.05s	remaining: 28.3ms
# 996:	learn: 0.4734682	total: 7.06s	remaining: 21.3ms
# 997:	learn: 0.4734319	total: 7.07s	remaining: 14.2ms
# 998:	learn: 0.4733795	total: 7.08s	remaining: 7.08ms
# 999:	learn: 0.4733543	total: 7.08s	remaining: 0us
# [LightGBM] [Info] Number of positive: 26533, number of negative: 45100
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.001025 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 555
# [LightGBM] [Info] Number of data points in the train set: 71633, number of used features: 5
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.370402 -> initscore=-0.530493
# [LightGBM] [Info] Start training from score -0.530493
# [LightGBM] [Info] Number of positive: 26533, number of negative: 45100
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.000933 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 553
# [LightGBM] [Info] Number of data points in the train set: 71633, number of used features: 5
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.370402 -> initscore=-0.530493
# [LightGBM] [Info] Start training from score -0.530493
# /home/edyn/Documentos/obsidian-doc/Projects/MachineLearningEngineer/Curso2/Proyecto/Repo/ml2_class4_mlsupervisadoavanzado/.venv/lib/python3.12/site-packages/sklearn/utils/validation.py:2749: UserWarning: X does not have valid feature names, but LGBMClassifier was fitted with feature names
#   warnings.warn(
# /home/edyn/Documentos/obsidian-doc/Projects/MachineLearningEngineer/Curso2/Proyecto/Repo/ml2_class4_mlsupervisadoavanzado/.venv/lib/python3.12/site-packages/sklearn/utils/validation.py:2749: UserWarning: X does not have valid feature names, but LGBMClassifier was fitted with feature names
#   warnings.warn(
# [LightGBM] [Info] Number of positive: 26534, number of negative: 45100
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.000842 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 554
# [LightGBM] [Info] Number of data points in the train set: 71634, number of used features: 5
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.370411 -> initscore=-0.530455
# [LightGBM] [Info] Start training from score -0.530455
# [LightGBM] [Info] Number of positive: 26534, number of negative: 45100
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.000823 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 555
# [LightGBM] [Info] Number of data points in the train set: 71634, number of used features: 5
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.370411 -> initscore=-0.530455
# [LightGBM] [Info] Start training from score -0.530455
# /home/edyn/Documentos/obsidian-doc/Projects/MachineLearningEngineer/Curso2/Proyecto/Repo/ml2_class4_mlsupervisadoavanzado/.venv/lib/python3.12/site-packages/sklearn/utils/validation.py:2749: UserWarning: X does not have valid feature names, but LGBMClassifier was fitted with feature names
#   warnings.warn(
# /home/edyn/Documentos/obsidian-doc/Projects/MachineLearningEngineer/Curso2/Proyecto/Repo/ml2_class4_mlsupervisadoavanzado/.venv/lib/python3.12/site-packages/sklearn/utils/validation.py:2749: UserWarning: X does not have valid feature names, but LGBMClassifier was fitted with feature names
#   warnings.warn(
# [LightGBM] [Info] Number of positive: 26534, number of negative: 45100
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.001115 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 554
# [LightGBM] [Info] Number of data points in the train set: 71634, number of used features: 5
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.370411 -> initscore=-0.530455
# [LightGBM] [Info] Start training from score -0.530455
# /home/edyn/Documentos/obsidian-doc/Projects/MachineLearningEngineer/Curso2/Proyecto/Repo/ml2_class4_mlsupervisadoavanzado/.venv/lib/python3.12/site-packages/sklearn/utils/validation.py:2749: UserWarning: X does not have valid feature names, but LGBMClassifier was fitted with feature names
#   warnings.warn(
# /home/edyn/Documentos/obsidian-doc/Projects/MachineLearningEngineer/Curso2/Proyecto/Repo/ml2_class4_mlsupervisadoavanzado/.venv/lib/python3.12/site-packages/sklearn/utils/validation.py:2749: UserWarning: X does not have valid feature names, but LGBMClassifier was fitted with feature names
#   warnings.warn(
# /home/edyn/Documentos/obsidian-doc/Projects/MachineLearningEngineer/Curso2/Proyecto/Repo/ml2_class4_mlsupervisadoavanzado/.venv/lib/python3.12/site-packages/sklearn/utils/validation.py:2749: UserWarning: X does not have valid feature names, but LGBMClassifier was fitted with feature names
#   warnings.warn(
# /home/edyn/Documentos/obsidian-doc/Projects/MachineLearningEngineer/Curso2/Proyecto/Repo/ml2_class4_mlsupervisadoavanzado/.venv/lib/python3.12/site-packages/sklearn/utils/validation.py:2749: UserWarning: X does not have valid feature names, but LGBMClassifier was fitted with feature names
#   warnings.warn(
# /home/edyn/Documentos/obsidian-doc/Projects/MachineLearningEngineer/Curso2/Proyecto/Repo/ml2_class4_mlsupervisadoavanzado/.venv/lib/python3.12/site-packages/sklearn/utils/validation.py:2749: UserWarning: X does not have valid feature names, but LGBMClassifier was fitted with feature names
#   warnings.warn(
# /home/edyn/Documentos/obsidian-doc/Projects/MachineLearningEngineer/Curso2/Proyecto/Repo/ml2_class4_mlsupervisadoavanzado/.venv/lib/python3.12/site-packages/sklearn/utils/validation.py:2749: UserWarning: X does not have valid feature names, but LGBMClassifier was fitted with feature names
#   warnings.warn(
# /home/edyn/Documentos/obsidian-doc/Projects/MachineLearningEngineer/Curso2/Proyecto/Repo/ml2_class4_mlsupervisadoavanzado/.venv/lib/python3.12/site-packages/sklearn/utils/validation.py:2749: UserWarning: X does not have valid feature names, but LGBMClassifier was fitted with feature names
#   warnings.warn(
# /home/edyn/Documentos/obsidian-doc/Projects/MachineLearningEngineer/Curso2/Proyecto/Repo/ml2_class4_mlsupervisadoavanzado/.venv/lib/python3.12/site-packages/sklearn/utils/validation.py:2749: UserWarning: X does not have valid feature names, but LGBMClassifier was fitted with feature names
#   warnings.warn(
# 2025/07/22 13:49:07 WARNING mlflow.utils.autologging_utils: MLflow autologging encountered a warning: "/home/edyn/Documentos/obsidian-doc/Projects/MachineLearningEngineer/Curso2/Proyecto/Repo/ml2_class4_mlsupervisadoavanzado/.venv/lib/python3.12/site-packages/mlflow/types/utils.py:452: UserWarning: Hint: Inferred schema contains integer column(s). Integer columns in Python cannot represent missing values. If your input data contains missing values at inference time, it will be encoded as floats and will cause a schema enforcement error. The best way to avoid this problem is to infer the model schema based on a realistic data sample (training dataset) that includes missing values. Alternatively, you can declare integer columns as doubles (float64) whenever these columns may have missing values. See `Handling Integers With Missing Values <https://www.mlflow.org/docs/latest/models.html#handling-integers-with-missing-values>`_ for more details."
# /home/edyn/Documentos/obsidian-doc/Projects/MachineLearningEngineer/Curso2/Proyecto/Repo/ml2_class4_mlsupervisadoavanzado/.venv/lib/python3.12/site-packages/sklearn/utils/validation.py:2749: UserWarning: X does not have valid feature names, but LGBMClassifier was fitted with feature names
#   warnings.warn(
# 2025/07/22 13:51:56 WARNING mlflow.utils.autologging_utils: MLflow autologging encountered a warning: "/home/edyn/Documentos/obsidian-doc/Projects/MachineLearningEngineer/Curso2/Proyecto/Repo/ml2_class4_mlsupervisadoavanzado/.venv/lib/python3.12/site-packages/mlflow/types/utils.py:452: UserWarning: Hint: Inferred schema contains integer column(s). Integer columns in Python cannot represent missing values. If your input data contains missing values at inference time, it will be encoded as floats and will cause a schema enforcement error. The best way to avoid this problem is to infer the model schema based on a realistic data sample (training dataset) that includes missing values. Alternatively, you can declare integer columns as doubles (float64) whenever these columns may have missing values. See `Handling Integers With Missing Values <https://www.mlflow.org/docs/latest/models.html#handling-integers-with-missing-values>`_ for more details."
# 🏃 View run Ensamble de Pilas at: https://dagshub.com/edynsoncoronado/ml_supervisado_avanzado.mlflow/#/experiments/1/runs/5bb522c498db429ca1c517a3780b7733
# 🧪 View experiment at: https://dagshub.com/edynsoncoronado/ml_supervisado_avanzado.mlflow/#/experiments/1
